# %% [markdown]
# Create the index

# %%
# Elasticsearch server details

import requests
from my_credentials import *
base_url = "http://localhost:9200"
index_name = "software_jobs"

# %%
# Index settings and mapping
index_settings = {
    "settings": {
        "number_of_shards": 1,
        "number_of_replicas": 0
    },
    "mappings": {
        "properties": {
            'job_id': {"type": "keyword"},
            'title': {"type": "keyword"},
            'company_name': {"type": "keyword"},
            'location': {"type": "keyword"},
            'via': {"type": "keyword"},
            'description': {"type": "keyword"},
        }
    }
}

# Create the index with authentication
response = requests.put(
    f"{base_url}/{index_name}",
    json=index_settings,
    auth=(username, password)  # Include authentication parameters
)

# Check the response
if response.status_code == 200:
    print(f"Index '{index_name}' created successfully.")
else:
    print(f"Error creating index: {response.content}")
# Out:
# Index 'software_jobs' created successfully.

# %% [markdown]
# Post the job offers to the index

# %%
import json
with open('jobs_jumble.json') as f:
    cleaned = json.load(f)
for c in cleaned:
    print(c)
# Out:
# {'job_id': '...', 'title': 'Remote ServiceNow Administration with Python, R, Advanced SQL...', 'company_name': 'Cube Hub Inc.', 'location': '  Irvine, Californie   ', 'via': 'via SaluteMyJob', 'description': "Position Description: ServiceNow Developer for Asset Management team\n\nhis team is working a hybrid schedule, but fully remote candidates will be considered as well...\n• Recent college graduates are not a good fit for this position.\n• Demonstrated knowledge in various programming languages (Python, R, Advanced SQL, etc.) MUST HAVE\n• 3+ Years experience of ServiceNow Administration MUST HAVE\n• Understanding of ServiceNow development environment, database, data management and infrastructure capabilities and constraints MUST HAVE\n• Business process knowledge of Hardware Asset Management (HAM), Software Asset Management (SAM), and procurement Preferred but not required\n• Ability to analyze, translate, and define business requirements into technical solutions, including advanced problem-solving ability - Preferred but not required\n• Excellence in verbal and written communication forms with emphasis on persuasive communication, tact and negotiation - Preferred but not required\nWhat Makes You Stand Out (Desired Skills/experiences)\n\nExperience with the following technologies:\n• Web technologies HTML, XML, or CSS\n• API integrations with other systems\n• Configuration of ServiceNow's ITSM service catalog\n• UI and SQL\n• Ability to manage many competing priorities/requests in a fast-paced environment.\n• ServiceNow Administration certification\n• Expert ITIL process knowledge\n• ITSM ServiceNow knowledge\n• Candidates who are selected for interviews will be required to complete a Glider assessment***\nResponsibilities\n• Builds the work needed to implement functionality from the product backlog (managed by the product owner).\n• Analyzes assignments and determines software specifications that must be fulfilled to achieve objectives and get appropriate value from packaged solutions.\n• Tests deliverables against a user story's acceptance tests.\n• Completes system configuration settings to enable software functionality that supports business processes.\n• Unit-tests software, creates automated test scripts and executes all other testing-related tasks.\n• Works closely with other team members to ensure that features meet business needs; Works collaboratively with infrastructure, security and other partners", 'skills': {'Coding': ['Python', 'CSS', 'SQL', 'R', 'HTML'], 'WebD': ['Python', 'CSS', 'HTML'], 'DevOps': ['UI'], 'Business': ['ITIL']}}
# {'job_id': '...', 'title': 'Lead Automated Python Tester', 'company_name': 'Lumen', 'location': '  États-Unis   ', 'via': 'via Lumen Jobs', 'description': "About Lumen\nLumen is guided by our belief that humanity is at its best when technology advances the way we live and work. With 450,000 route fiber miles serving customers in more than 60 countries, we deliver the fastest, most secure global platform for applications and data to help businesses, government and communities deliver amazing experiences. Learn more about Lumen’s network, edge cloud... security and communication and collaboration solutions and our purpose to further human progress through technology at news.lumen.com, LinkedIn: /lumentechnologies, Twitter: @lumentechco, Facebook: /lumentechnologies, Instagram: @lumentechnologies and YouTube: /lumentechnologies.\nThe Role\n\nProvides expert technical direction at a project level. This role will be responsible for planning, developing, and executing tests for complex systems and equipment. The individual will collaborate with various teams across IT to identify the impacts of test requirements and improve the overall quality of the final deliverables. As a technical expert, this person will possess strong communication skills and will be expected to partner with business and technical groups in order to anticipate the effects of testing and bring timely resolution to critical issues. Within their area of expertise, this person will provide specialized advice and direction. They will contribute towards the team’s continual process improvement, and will also provide industry knowledge regarding test strategy development, test R&D activities, and technical support when applicable.\n\nThe Main Responsibilities\n• Perform comprehensive QA planning and coordination\n• Perform manual testing of web, mobile & desktop applications\n• Write automated tests for web and mobile apps using various open-source test frameworks\n• Assist sales and account management on product questions and issues\n• Serve as the user advocate within the engineering team\n• Implement QA metrics, including benchmarking and identification of areas for improving overall performance\n• Identify and lead process improvements in QA and agile execution\n\nWhat We Look For in a Candidate\n• Consulting Level Bachelor's degree. Typically with 8+ years of experience.\n• 6+ years of experience QA Testing (Python). Masters Degree preferred.\n• Collect the release features & update test cases in automation to support Deployments.\n• Update Test automation to support CI/CD deployements.\n• Pre & Post Deployement validations on Apps.\n\nCompensation\n\nThe starting salary for this role differs based on the employee's primary work location. Employees typically do not start at the top of the range, though compensation depends on each individual's qualifications.\n\nLocation Based Pay Ranges\n\n$94420 - $118028 in these states: AR, ID, KY, LA, ME, MS, NE, SC, and SD.\n$99390 - $124230 in these states: AZ, FL, GA, IN, IA, KS, MO, MT, NM, ND, OH, OK, PA, TN, UT, VT, WV, WI, and WY.\n$104360 - $130448 in these states: CO, HI, MI, MN, NV, NH, NC, OR, and RI.\n$109330 - $136665 in these states: AK, CA, CT, DE, DC, IL, MD, MA, NJ, NY, TX, VA, and WA.\n\nAs with the pay range variety that's based on the region of a country, specific offers are determined by various factors such as experience, education, skills, certifications and other business needs.\n\nWhat to Expect Next\n\nRequisition #: 331220\n\nWhen applying for a position, you may be subject to a background screen (criminal records check, motor vehicle report, and/or drug screen), depending on the requirements for the position. More information on what’s included in these checks can be found in the Post Offer section of our FAQ page. Job-related concerns noted in the background screen may disqualify you from the new position or your current role. Background results will be evaluated on a case-by-case basis.\n\nEEO  ...
# {'job_id': '', 'title': 'Python Developer', 'company_name': 'Neotech Solutions', 'location': '  San José, Californie   ', 'via': 'via Indeed', 'description': 'Job Role: Python Developer\n\nLocation: San Jose, CA (onsite only...\n\nClient: TechM/ ASML\n\nDuration: Contract\n\nJob Description:\n\nClient requirements are:\n• Skillful in Python/Perl scripting\n• Strong Experience with Unix/Linux and shell scripting\n• Experience on Python-based Robot framework is a plus\n• Very good communication and learning capability.\n• 3+ years of software test experiences\n• Proficient with the tooling: Git, Bamboo, JIRA, Test management tools like qTest,.\n• Proficient with Restful API testing\n• Proficient with robot test framework and python programming\n• Familiar with Linux terminal, docker and Kubernetes usage.\n• Experiences of developing/maintaining regression tests\n• Semiconductor Experience is +..\n\nThe following skills are mandatory:\n• SQL\n• LINUX\n• SDET\n• PYTHON\n• ROBOTICS\n• JIRA\n\nMamatha K | US IT Recruiter\nD: (908) 864-9004 |\nMamatha@neotechusa.com\nOne Cragwood Rd | South Plainfield, NJ 07080\neFax: 888-828-9871|\nwww.neotechusa.com\n\nJob Type: Contract\n\nSalary: $48.00 - $53.00 per hour\n\nSchedule:\n• 8 hour shift\n• Monday to Friday\n\nWork Location: In person', 'skills': {'Coding': ['Python', 'SQL', 'Perl'], 'WebD': ['Python']}}
# {'job_id': '...', 'title': 'Python Engineer– (Manufacturing Software Tools) || San Jose, CA...', 'company_name': 'Zodiac Solutions, Inc', 'location': '  San José, Californie   ', 'via': 'via LinkedIn', 'description': 'Hello,\n\ni Hope you are doing great, my name is Prashant, I am a recruitment specialist at Zodiac solutions. Our client is looking for an Application Engineer(Python), might be this position can good next step towards your carrier, if you are looking for change or interested in this JOB role, please share me your updated resume so I can check your core strength, and we can discuss it further... Please find the Job description Below.\n\nImportant: Please make sure candidate has several iteration of Software development life cycle (SDLC) experience and he/she is well versed with Agile methodology, preferably have Manufacturing App experience..\n\nRole: Application Engineer(Python) – (Manufacturing Software Tools)\n\nLocation: San Jose, CA (Local, Onsite)\n\nDuration: Long-Term\n\nHire Mode: Contract\n\nA Google Cloud Project application that provides traditional application/ETL/relational database and data warehousing.\n\nShould have several iteration of Software development life cycle (SDLC) experience\n\nwell versed Experience working with Agile methodology, preferably have Manufacturing App experience..\n\nQualifications:\n• 8 years’ experience developing with any object-oriented language: e.g., Python, Java, or C++.\n• 3 years’ experience specifically developing in Python.\n• 3 years’ experience in relational or NoSQL database solutions and Web Frameworks such as Flask or Django.\n\nPreferred Qualifications:\n• Experience working in large, structured software development teams\n• Experience working across multiple distinct systems\n• Our Technologies:\n• Google Cloud Project: Spanner, Big Query, Relational Databases Python 3.9+\n• Git\n• Manufacturing Shop Floor Control Systems\n\nIf you are qualified, available, interested, planning to make a change, please feel free to reach me.\n\nThanks & Regards\n\nPrashant Bhardwaj\n\nSenior US IT Recruiter\n\nZodiac Solutions Inc.\n\n2625 N Josey Ln STE 320, Carrollton, TX 75007\n\nwww.zodiac-solutions.com\n\nEmail: prashant.bhardwaj@zodiac-solutions.com\n\nOffice: 484-953-8110', 'skills': {'WebD': ['Python', 'client', 'Django'], 'DevOps': ['Databases', 'NoSQL', 'Software development'], 'Business': ['SDLC'], 'Analytics': ['ETL'], 'Coding': ['Python', 'C++', 'Java'], 'ML/AI': ['Django', 'Flask']}}
# {'job_id': '...', 'title': 'GCP  Lead with Strong Python & SQL coding experience', 'company_name': 'ClifyX', 'location': '  Boston, Massachusetts   ', 'via': 'via SaluteMyJob', 'description': '1252334\nGCP(GCS, BigQuery, BQ SQL, Python, Data Fusion,Cloud Composer) Lead with Strong Python & SQL coding experience)\nBoston,Massachusetts...\nVeolia North America, LLC\nPay rate $90/hr\n\n" Possess In depth knowledge and hands on development experience building end to end data pipeline on GCP including ingestion, processing, and storage of datasets.\nStrong Python & SQL coding experience [Must].\nStrong programming foundation in Python, including debugging and performance analysis.\nGood exposure to GCP data services like GCS, BigQuery, BQ SQL, Python, Data Fusion,Cloud Composer\nDeveloping re-usable code and libraries for future use\nOutstanding analytical and critical thinking skills.\nWell-established experience in all phases of development requirement gathering, system design, implementation, testing, deployment and maintenance, of enterprise-wide application systems.\nKnowledge in AWS (S3, Redshift', 'skills': {'Coding': ['Python', 'SQL'], 'WebD': ['Python'], 'DevOps': ['AWS']}}
# {'job_id': '...', 'title': 'Python Developer', 'company_name': 'Connective Talent', 'location': '  Houston, Texas   ', 'via': 'via LinkedIn', 'description': "• *Join Our Client as a Python Developer in Houston, TX!**\n\nLooking for an exciting Python Developer role in Houston, TX? You're in the right place! Enjoy an on-site position with amazing perks like an 11% annual 401K contribution, catered food, and top-notch healthcare benefits...\n\nRole Highlights:\n\n- Contribute to the development of a cutting-edge data management platform.\n\n- Collaborate with a talented Python developer team to build a robust data processing pipeline.\n\nKey Responsibilities:\n\n- Data Integration: Manage diverse data feeds, move them to the cloud, and distribute globally to support business operations.\n\n- Data Acquisition: Collect data from over 1,000 sources daily, including web scraping and handling various data formats.\n\n- Web Scraping: Efficiently download data into databases through web scraping and propose scraping solutions.\n\n- Python Development: Join a dynamic Python developer team, creating Python-based data processing solutions.\n\n- Solution Development: Collaborate on Python enterprise solutions, including libraries and modules for data processing.\n\nQualifications:\n\n- Python developer with 3-5 years of data-focused Python development experience.\n\n- Proficiency in data manipulation and scripting, with the ability to work independently or as part of a team.\n\n- Experience with ETL processes and data integration.\n\n- Familiarity with enterprise-level Python solutions and libraries.\n\nReady to make a mark in data management? Apply today and be part of our exciting team!\n\nhas context menuComposeParagraph", 'skills': {'Coding': ['Python'], 'WebD': ['Python'], 'Analytics': ['ETL']}}
# {'job_id': '...', 'title': 'Software Engineer - C++ and Python', 'company_name': 'Global Technology Associates, Ltd.', 'location': '  Ann Arbor, Michigan   ', 'via': 'via ZipRecruiter', 'description': "Software engineer for Automated Driving Systems Engineer - C++ and Python\n\nHybrid Schedule. Must be local to work on site in Ann Arbor, MI, as needed. Average days on site estimated: 6-12 days/month...\n\nJob ID: 1266679 - Location: Ann Arbor, MI 48105\n\nPay Rate: Very Competitive w/OT paid over 40 hours in a week, with benefits options: Health, Dental, Vision, 401(k), company paid holidays\nType of hire: Contract, long-term with ongoing potential. No travel anticipated.\n\nPosition Summary:\n\nIntegrated Vehicle Systems Department is looking for a passionate and highly motivated Software Engineer. The primary responsibility of this role is to develop advanced driver system and software in C/C++ and support overall software quality auditing.\n\nIVS department's objective to design and evaluate the next generation of automated driving systems for the company’s vehicles.\n\nPosition Responsibilities:\n• Design ADS systems and software logic in C/C++\n• Complete logic development by making design requirements, confirming/testing logic, and ensuring quality and all safety concepts into software design.\n• Utilize and create support tools with Python code\n• Position Requirements:The schedule will be a hybrid schedule working at least 6 days a month from the office, however there may be times where this candidate will need to report to the office more frequently therefore this candidate must be flexible.\n• B.S. in Computer Science, related fields, or commensurate work experience.\n• Experience as a production software engineer (3 years).\n• Experience building, implementing, and supporting medium to large scale solutions in C/C++ and Python\n• Experience using GIT., Experience performing performance analysis, troubleshooting, and remediation in a software and integration environment (3 year).\n• Self-starter with the ability to work independently or as part of a project team with limited supervision.\n\nWhat you may bring:\n• C/C++ or Python Certification (foundational, associate, professional, or specialty).\n• A valid US drivers’ license.\n• Experience with dynamics-based vehicle simulation (1 year)\n• Experience developing software in a team setting, creating pull requests, conducting peer reviews.\n• Experience using ROS1 or ROS2\n• Familiarity with Docker\n• Experience developing code on Linux platforms, writing shell scripts.\n• Web development experience (html, JavaScript, CSS)\n• Experience using plotting tools like plot.ly, bokeh, matplotlib.\n• Experience using cloud services (AWS, Azure)\n• Time-series database experience\n\nCompany DescriptionGlobal Technology Associates, LTD can take your career search or hiring needs to the next level. As a premier technical and professional staffing company, with over 30 years of industry experience, we have longstanding connections in industries like automotive, aeronautics, information technology, defense, and healthcare. GTA can provide you with a full breadth of diverse candidates from our talent network. GTA is a national full-service provider of direct and contract professionals and top management talent", 'skills': {'Coding': ['Python', 'CSS', 'C++', 'JavaScript', 'C'], 'WebD': ['Python', 'CSS'], 'DevOps': ['Docker', 'AWS'], 'ML/AI': ['matplotlib']}}
# {'job_id': '...', 'title': 'SAS Developer (With Python) @ Reston, VA (Remote, but once in a...', 'company_name': 'Smart IT Frame LLC', 'location': '  Boston, Massachusetts   ', 'via': 'via SaluteMyJob', 'description': 'Role : SAS Developer (With Python)\n\nMode of Hire : Fulltime / Contract...\n\nLocation : Reston, VA (Remote, but once in a month on-site required)\n\nJob Description:\n\nPrimary Skills - Python, Unix, AWS, SAS\n• 8 years of experience in SAS Development.\n• Experience in Base SAS, Advance SAS programming, SAS Macros and SQL and optimization techniques.\n• SAS knowledge to read and understand packages\n• Experience with Pandas, Numpy packages in Python programming\n• Experience with AWS cloud implementation\n• Experience with following AWS services preferred (Step Functions, Lambda, SNS, SQS, S3, EMR, Redshift)\n• Familiar with Release (promote) process, Batch Support (Daily, Weekly, Monthly) and strong SQL/SAS debugging skills\n• Knowledge in Shell scripting good to have.\n\nRegards,\n\nSanjeev\n\nsanjeev', 'skills': {'Coding': ['Python', 'SQL'], 'WebD': ['Python'], 'DevOps': ['AWS']}}
# {'job_id': '...', 'title': 'Java Tech Lead (Spark and Python expertise)', 'company_name': 'V-Solve', 'location': '  Dallas, Texas   ', 'via': 'via SaluteMyJob', 'description': 'Job Description:\n\nTech Lead (Spark and Python expertise...\n\nJob description:\n\nMandatory:\n\n10+ years of experience in solution, design and development of applications using Java 8+/J2EE, Spring, Spring-Boot, Micro Services, RESTful Services and with experience in Big Data and with experience working in heavy data background needed.\n\nDevelop, program, and maintain applications using the Apache Spark open-source framework.\n\nWork with different aspects of the Spark ecosystem, including Spark SQL, DataFrames, Datasets, and streaming.\n\nSpark Developer must have strong programming skills in Java, Scala, or Python.\n\nFamiliar with big data processing tools and techniques.\n\nProven experience as a Spark Developer or a related role.\n\nStrong programming skills in Java, Scala, or Python.\n\nFamiliarity with big data processing tools and techniques.\n\nExperience with the Hadoop ecosystem.\n\nGood understanding of distributed systems.\n\nExperience with streaming data platforms.\n\nMust have strong experience in Big Data and with experience working in heavy data background needed.\n\nMust be strong in Cloud AWS event-based architecture, Kubernetes, ELK (Elasticsearch, Logstash & Kibana).\n\nMust have excellent experience in designing and Implementing cloud-based solutions in various AWS Services (: s3, Lambda, Step Function, AMQ, SNS, SQS, CloudWatch Events, etc.)\n\nMust be well experienced in design and development of Microservice using Spring-Boot and REST API and with GraphQL.\n\nMust have solid knowledge and experience in NoSQL (MongoDB).\n\nGood knowledge and experience in any Queue based implementations.\n\nStrong knowledge/experience in ORM Framework - JPA / Hibernate.\n\nGood knowledge in technical concepts - Security, Transaction, Monitoring, Performance.\n\nShould we well versed with TDD/ATDD.\n\nShould have experience on Java, Python and Spark.\n\n2+ years of experience in designing and Implementing cloud-based solutions in various AWS Services.\n\nStrong experience in DevOps tool chain (Jenkins, Artifactory, Ansible/Chef/Puppet/Spinnaker, Maven/Gradle, Atlassian Tool suite).\n\nVery Good knowledge and experience in Non-Functional (Technical) Requirements like Security, Transaction, Performance, etc.\n\nExcellent analytical and problem-solving skills.\n\nNice to have:\n\nExperience in Experience with OAuth implementation using Ping Identity\n\nExperience in API Management (Apigee) or Service Mesh (Istio)\n\nGood knowledge and experience in Queue/Topic (Active-MQ) based implementations\n\nGood knowledge and experience in Scheduler and Batch Jobs\n\nExperience with scripting languages using Unix\n\nPreferably certified in AWS', 'skills': {'DevOps': ['NoSQL', 'MongoDB', 'Spark', 'Hadoop', 'AWS', 'DevOps'], 'Coding': ['Python', 'SQL', 'Scala', 'Java'], 'WebD': ['Python']}}
# {'job_id': '...', 'title': 'Sr Python Developer / Senior Python Full Stack Developer', 'company_name': 'Makro Technologies Inc', 'location': '  Princeton, New Jersey   ', 'via': 'via ZipRecruiter', 'description': "Description:\n\nJob Description and nbsp...\n• Develop, test, and debug software applications using Python. and nbsp;\n• and nbsp;Write scalable and reusable code that adheres to best practices. and nbsp;\n• Strong knowledge with utilizing libraries such as Pandas, NumPy, and ORM's like SQL Alchemy.\n• Work with Object-Oriented Programming principles. and nbsp;\n• Proficiently use SQL and interact with RDBMS systems like SQL Server. and nbsp;\n• Collaborate with teams using Git and JIRA for version control and project management. and nbsp;\n• Take full ownership of tasks, work independently, and meet project deadlines. and nbsp;\n• Foster effective teamwork and communication within the development team. and nbsp;\n• API development using RESTful or GraphQL standards. and nbsp;\n• Develop Data Interfaces using Python, Data Frames, Pandas etc. and nbsp;\n• Integration with back-end technologies and frameworks, such as Node.js, .NET, or Java. and nbsp;\n• Build Data Access Layer and metadata-driven data query tool. and nbsp;\n• Write clean, reusable, and well-documented code that follows best practices and coding standards. and nbsp;\n• Collaborate with back-end developers to integrate UI components with server-side systems and APIs. Ensure efficient data retrieval and synchronization, handle data validation and error handling, and optimize API performance. and nbsp;\n• Work in an iterative/Agile environment as a good team player. and nbsp;\n• Ability to manage multiple tasks and projects simultaneously.\n• Work with the latest CI/CD DevOps deployment model\u200b\n\nRequirements and nbsp;\n• 7+ years of experience in Python programming and nbsp;\n• Strong knowledge of Python libraries like Pandas and NumPy and nbsp;\n• Experience in frameworks like Django, Flask, or any other web frameworks and nbsp;\n• Experience in UI library or Framework such as React, Angular or Vue (Preferred React) and nbsp;\n• Proficient with Data structures and Collections and nbsp;\n• Experience in Relational (MySQL, Postgres) and No SQL (Cassandra, Mongo) database technologies and nbsp;\n• Experience in designing and developing distributed and amp; scalable systems using OOPS and/or Functional programming and nbsp;\n• Experience in Distributed Computing and High Velocity data processing and nbsp;\n• Exposure to CI/CD tools like Jenkins, Maven, Git etc. and nbsp", 'skills': {'Coding': ['Python', 'SQL', 'Java', 'NumPy'], 'WebD': ['Python', 'Django', 'server'], 'DevOps': ['Node.js', 'DevOps', 'UI'], 'ML/AI': ['Django', 'Flask']}}
# {'job_id': '...', 'title': 'Web Developer (Angular)', 'company_name': 'TEKsystems', 'location': '  Chesapeake, Virginie   ', 'via': 'via TEKsystems Careers', 'description': "• **W2 ONLY\n• **100% Remote (EST), Direct Placement\n...\nSkills:\n\nAngular, Front end, full stack development, .net framework, Web Development, Angular 16, web api, c#, application security, Azure, .net\n\nAdditional Skills & Qualifications:\n\nCommunication must be good, they will be in front of the clients often. Position is remote so they will need to be highly communicative with the team\n\nRequired Experience\n\n• Bachelor’s Degree in a STEM Major and/or 5+ years equivalent work experience\n\n• Experience in these Technology Stacks:\n\n• ***Angular (14/15/16) preferred\n\n• TypeScript (and/or JavaScript)\n\n• C#, .NET with emphasis on Web API (& REST architecture)\n\n• CSS3 / HTML5\n\n• Outstanding verbal and written communication skills\n\n• Able to troubleshoot and adapt to challenges quickly\n\n• Fluent in Microsoft Windows operating systems\n\nAdditional Experience:\n\n• TypeScript experience a plus (ES6, ES2015, ECMAScript)\n\n• SCSS (or SASS/LESS)\n\n• .NET Core development\n\n• Engineering systems experience\n\n• Technical Writing experience\n\n• iOS Mobile Development (Ionic Framework/Cordova)\n\n• Android Mobile Development\n\nDuties include, but are not limited to:\n\n• Obtaining a high level of knowledge with company’s proprietary software application\n\n• Interface with our tight team of developers\n\n• Comfortable in Agile & Kanban development practices\n\nJob Type: Full-time\n\nExperience Level:\n\nExpert Level\n\nAbout TEKsystems:\n\nWe're partners in transformation. We help clients activate ideas and solutions to take advantage of a new world of opportunity. We are a team of 80,000 strong, working with over 6,000 clients, including 80% of the Fortune 500, across North America, Europe and Asia. As an industry leader in Full-Stack Technology Services, Talent Services, and real-world application, we work with progressive leaders to drive change. That's the power of true partnership. TEKsystems is an Allegis Group company.\n\nThe company is an equal opportunity employer and will consider all applications without regards to race, sex, age, color, religion, national origin, veteran status, disability, sexual orientation, gender identity, genetic information or any characteristic protected by law", 'skills': {'WebD': ['api', '.net'], 'Coding': ['JavaScript', 'C']}}
# {'job_id': '...', 'title': 'Développeur(euse) JavaScript', 'company_name': 'Airudi', 'location': '  Remote, Oregon   ', 'via': 'via Workopolis', 'description': 'Airudi : partenaire de votre virage IA-RH\n\nDéveloppeur(euse) JavaScript\n\nLocalisation :\n\nTélétravail, Canada\n\nÀ propos d’Airudi\n\nAirudi est à la recherche d’un Développeur Javascript qui est talentueux et créatifs pour nous aider à faire évoluer et à développer notre plateforme.\n\nLe candidat parfait est stimulé par un environnement dynamique, caractérisé par un contexte de « startup » ou les choses bougent vite! Nous recherchons des gens passionnés par la technologie pour rejoindre Airudi! Les membres de l’équipe aident à concevoir, construire et développer notre plate-forme en participant à tous les aspects du développement du produit.\n\nÀ propos du rôle\n\nEn tant que développeur JavaScript chez Airudi, vous contribuerez au développement frontal de systèmes cloud natifs qui tirent parti de l’IA de pointe pour alimenter des systèmes innovants d’aide à la décision RH. Vous ferez partie d’une équipe diversifiée et multidisciplinaire composée de développeurs de logiciels, de spécialistes... des ressources humaines, de concepteurs, de scientifiques des données et de chercheurs en IA.\n\nResponsabilités\n\nConcevoir, coder et déboguer des applications principalement en JavaScript et les technologies associées\n\nDévelopper des procédures opérationnelles standard\n\nAssurer la liaison avec les collègues pour mettre en œuvre les conceptions techniques\n\nModifications du code d’examen par les pairs\n\nAnalyser, concevoir et développer des tests\n\nExaminer les domaines problématiques et trouver des solutions\n\nMaintenir et améliorer les bases de code existantes\n\nFournir du matériel de transfert de connaissances écrit\n\nDévelopper des solutions logicielles en étudiant les besoins d’information\n\nModélisation et simulation de logiciels\n\nCollaborez de manière interfonctionnelle avec les utilisateurs métier, les data scientists et les chefs de projet\n\nAnalyse des logiciels, du code, des exigences, des risques système et de la fiabilité des logiciels\n\nTests logiciels et assurance qualité\n\nRester à l’affût des dernières tendances technologiques afin de fournir des recommandations avant-gardistes à l’entreprise\n\nExigences\n\n5 ans et plus d’expérience en tant que développeur frontend\n\nExpérience dans le déploiement d’applications Web;\n\nAxé sur les résultats et autonome;\n\nPenseur créatif et capacité à concevoir des interfaces «prêtes à l’emploi»;\n\nFonctionnel dans un environnement de travail à distance;\n\nApprenant rapide, penseur critique, motivé, esprit d’équipe, bonnes compétences en communication\n\nSolide connaissance de JavaScript et des frameworks frontend (idéalement vue.js)\n\nHTML 5, CSS\n\nGit SCM\n\nDU REPOS\n\nOpen cloud platforms (c’est-à-dire Azure, AWS)\n\nAtout\n\nExpérience avec les systèmes d’IA, les microservices, CI / CD,\n\nMicrosoft Azure (c’est-à-dire Devops, Recherche cognitive, LUIS, Bot Framework, App service, ML studio)\n\nExpérience de développement backend\n\nCertification Azure\n\nLe bilinguisme (français / anglais) est un atout majeur\n\nSens de l’humour\n\nFaire partie de l’équipe des Airudis c’est :\n\nParticiper à des projets spéciaux passionnants et missions de développement;\n\nBénéficier d’excellents avantages en matière de soins de santé;\n\nAvoir la possibilité de faire du télétravail en permanence;\n\nProfiter d’une semaine de travail de 4 ½ jours (passez votre vendredi après-midi en famille ou entre amis);\n\nObtenir du coaching, formation et programmes éducatifs continus', 'skills': {'Coding': ['CSS', 'HTML', 'JavaScript'], 'WebD': ['CSS', 'HTML', 'Javascript'], 'DevOps': ['AWS']}}
# {'job_id': '...', 'title': 'Full Stack JavaScript Developer', 'company_name': 'Choice OMG', 'location': '  Remote, Oregon   ', 'via': 'via Workopolis', 'description': "Location: 8739 53 Ave NW, Edmonton, AB T6E 5G2\n\nPhysical space available - however, most team members work from home offices at various locations across Canada...\n\nResponsibilities:\n\nDevelop and maintain web applications using Next.js, React, Redux, and other modern JavaScript frameworks and libraries.\n\nWork with Prisma for database management and AWS SDK for cloud services integration.\n\nImplement payment solutions using Stripe and handle email services with SendGrid.\n\nCollaborate with the design team to implement responsive and visually appealing UI/UX using Tailwind CSS and other styling libraries.\n\nWrite and maintain unit tests, and ensure code quality through linting and prettier.\n\nCollaborate with cross-functional teams to define, design, and ship new features.\n\nContinuously discover, evaluate, and implement new technologies to maximize development efficiency.\n\nQualifications:\n\nStrong experience with Next.js, React, Redux, and other related technologies.\n\nFamiliarity with Prisma, AWS SDK, Stripe, and other third-party integrations.\n\nExperience with Tailwind CSS and other styling frameworks.\n\nKnowledge of modern development tools such as ESLint, Prettier, TypeScript, and others.\n\nStrong understanding of version control systems, preferably Git.\n\nExcellent problem-solving skills, attention to detail, and ability to work independently or as part of a team.\n\nBachelor's degree in Computer Science or related field, or equivalent work experience.\n\nPreferred Skills:\n\nExperience with Editor.js and other content editing tools.\n\nFamiliarity with deployment and process management tools like PM2.\n\nKnowledge of email handling libraries like Nodemailer.\n\nSuggested Salary Requests:\n• Entry-Level: $60,000 - $80,000 per year\n• Mid-Level: $80,000 - $90,000 per year\n• Senior-Level: $90,000 - $115,000 per year\n\nJob Types: Full-time, Fixed term contract\nContract length: 6 months\n\nSalary: $85,755.00-$94,023.90 per year\n\nBenefits:\n• Dental care\n• Extended health care\n• Flexible schedule\n• Paid time off\n• Vision care\n• Work from home\n\nFlexible Language Requirement:\n• French not required\n\nSchedule:\n• Monday to Friday\n• Weekends as needed\n\nEducation:\n• Bachelor's Degree (preferred)\n\nLanguage:\n• English (required)\n\nWork Location: Remote\n\nApplication deadline: 2023-09-12\nExpected start date: 2023-09-18", 'skills': {'Coding': ['CSS', 'JavaScript'], 'DevOps': ['UX', 'AWS', 'UI'], 'WebD': ['CSS'], 'Soft_Skills': ['Flexible']}}
# {'job_id': '...', 'title': 'Développeur Full Stack senior - IBMiX, IBM Consulting', 'company_name': 'IBM Interactive', 'location': '  États-Unis   ', 'via': 'via Jora', 'description': 'Introduction\nUne carrière avec IBM Consulting englobe des relations à long terme et une collaboration étroite avec des clients du monde entier.\n\nVous travaillerez avec des visionnaires de plusieurs secteurs pour améliorer le parcours de l’IA et du nuage hybride des entreprises les plus innovantes et les plus prestigieuses au monde. Votre capacité à accélérer l’impact et à apporter des changements significatifs pour vos clients est rendue possible par notre écosystème d’associés stratégiques et nos plateformes technologiques robustes à travers le portfolio d’IBM; y compris les logiciels IBM et Red Hat.\nLa curiosité et la quête constante de connaissances sont les fondements du succès d’IBM Consulting. Dans votre rôle, vous serez encouragé à défier la norme, à rechercher des idées en dehors de votre rôle et à proposer des solutions créatives résultant en un impact révolutionnaire pour un large réseau de clients. Notre culture d’évolution et d’empathie est centrée sur les opportunités de... croissance professionnelle et de développement à long terme dans un environnement qui englobe vos compétences et vos expériences uniques.\n\nChez IBMiX, le groupe de transformation client et expérience d’IBM Consulting, nous sommes des renégats et des réalistes qui se concentrent sur la vision et la création de solutions numériques de bout en bout axées sur le client final. Nous incarnons une conception centrée sur l’humain et des méthodologies agiles pour repenser la façon dont nos clients travaillent et interagissent avec leurs clients et donnent rapidement vie à ces solutions numériques axées sur l’expérience. Chez IBMiX, vous pouvez faire partie d’une équipe où tout ce que nous faisons a un impact mesurable à grande échelle.\n\nVotre rôle et vos responsabilités\nEn tant que développeur senior Full-Stack chez IBMiX (sous IBM Consulting), vous êtes un joueur d’équipe qui permet à la vision produit de notre client de se concrétiser dans les délais et de manière sécurisée, fiable, réutilisable et évolutive.Grâce à votre expérience agile de travail dans des organisations centrées sur les produits, vous êtes un joueur d’équipe travaillant aux côtés d’une équipe de livraison pour assurer la livraison réussie d’applications Web et mobiles et d’autres expériences numériques de première sur le marché\n\nVos principales responsabilités incluent :\n• Gérer le développement logiciel complet pour nos clients, du concept au déploiement dans le contexte de leur transformation numérique, en assurant l’alignement à la fois sur l’architecture actuelle et en développement\n• Contribuer aux réunions Scrum quotidiennes et fournir une orientation technique aux autres membres de l’équipe\n• Collaborer avec les parties prenantes et les architectes de l’entreprise pour garantir que la solution s’aligne sur les exigences et la stratégie. Participer au contrôle et à la sélection des technologies (langages/cadriciel/librairies)\n• Appliquer des modèles de conception, des normes de codage et les meilleures pratiques pour produire un code sécurisé, fiable, réutilisable et évolutif\n• Identifier, trier et effectuer une analyse des causes profondes des problèmes spécifiques au développement\n• Intégrer les implémentations de l’interface utilisateur avec des API sécurisées et non sécurisées\n• Travailler avec les intervenants internes et clients pour définir et clarifier les exigences fonctionnelles et non fonctionnelles\n• Contribuer à l’estimation et à l’effort requis pour construire des composants clés\n• Préparer, consigner par écrit et présenter la conception technique et le matériel de spécification\n• Exercer un leadership technique grâce à l’expertise en la matière et à la connaissance du domaine\n• Contribuer aux améliorations des processus, exprimer toute préoccupation et contri ...
# {'job_id': '...', 'title': 'Developer – Full Stack', 'company_name': 'UNFCU', 'location': '  États-Unis   ', 'via': 'via BeBee', 'description': "Why join this team\n\nSupports the organization's business operations and growth by providing online communications and solutions through an enhanced user experience to our members and employees. Responsible for creating, enhancing, maintaining, and administrating the organization's internal and external web/mobile applications according to business needs. Develops applications using web & mobile... based frameworks/languages and scripting tools like ASP.NET (C#, VB), ASP.NET Core, MVC.NET, ADO.NET, Razor, Web API, WCF, TSQL (MSSQL, Oracle), Java, Mule ESB, Classic ASP, AJAX, JQuery, JavaScript, JSON, ReactJS, Bootstrap, CSS, HTML and other relevant front-end and back-end technologies. Required to participate in requirements gathering, design/architecture discussions, and research and create proof of concepts or solutions within agreed upon timelines in an agile environment.\n\nThis position is expected to be hybrid.\n\nNYC Salary Range - $88,170 - $130,000 annually; compensation is commensurate to geographic location.\n\nWhat You'll Do\n• Regardless of seniority or role, uphold UNFCU's mission, core values, and guiding principles by providing an exceptional service experience to colleagues and members alike through consistent demonstration of our service excellence behaviors.\n• Develop web & mobile applications leveraging Agile Scrum methodology and processes in Microsoft's Team Foundation Server environment. Build and support applications on .NET, .Net Core & Java platforms.\n• Build foundational structure of the application using back-end programming languages such as C#, VB, VB.NET and industry standard database APIs like OLE DB, ADO, ADO.NET, etc.\n• Design and develop Rich User Interfaces/Experience using client side technologies/frameworks such as JavaScript, JQuery, JSON, ReactJS, Bootstrap, CSS & HTML as well as knowledge in graphic design related tools such as Photoshop and Illustrator.\n• Build, deploy, and maintain SOAP and/or REST compliant Web Services on Microsoft Technologies including WCF & Web API.\n• Perform application testing and optimization, including performance tuning and code refactoring, to ensure a quality product.\n• Create and maintain proper coding standards through comments, documentation and code refactoring practices as per our policy.\n\nWhat We're Seeking\n• Bachelor's degree in Engineering or Computer Science and at least five years of progressive professional IT work experience, the majority of which should be in web application development\n• Extensive application design and development knowledge\n• 5+ years software development experience on Microsoft Platform\n• 5+ years of server-side development experience in ASP.NET (C#), MVC.NET, Razor, and ADO.NET\n• 5+ years of designing and building applications with rich user interface for overall experience (UI/UX)\n• 5+ years of client-end development experience in JavaScript, JQuery, AJAX, JSON, HTML 5, CSS 3, Bootstrap (or similar)\n• 3+ years of Database Development in TSQL(MS SQL)\n• 2 years of development experience in Web Services (WCF/Web API)\n\nWhat Makes You Stand Out\n• Experience with React JS, Angular or related libraries/frameworks.\n• Experience in UI/UX design and HTML Prototyping\n• Experience with modern development tools and techniques for Package Manager (NPM), Module Loader/Bundler (webpack, requireJS, browserify), Transpilers (Css-Sass/Less/Stylus, JS-babel, typescript), Task Runners (npm scripts, gulp, grunt).\n\nWho We Are\n\nUNFCU is a global not-for-profit financial institution that serves the UN community. We are committed to providing peace of mind to our members and colleagues and strive to achieve service excellence in all that we do. The best part of UNFCU is the people. Those that choose to work with us often find personal fulfillment, professional growth and a purpose ...
# {'job_id': '...', 'title': 'Developpeur Fullstack php/angular app/website - Contract to Hire', 'company_name': 'Upwork', 'location': '  États-Unis   ', 'via': 'via Upwork', 'description': "Nous sommes dédiés à réinventer la nutrition sportive. Nous combinons technologie de pointe et expertise nutritionnelle pour offrir des solutions protéinées innovantes. Notre distributeur révolutionnaire qui n'existe pas dans le monde rend l'accès aux compléments alimentaires facile et pratique, soutenant ainsi les modes de vie actifs de nos utilisateurs.\n\nNous recherchons un collaborateur pour assister notre informaticien dans le développement de notre site et de notre application. L'objectif est de le soutenir dans la poursuite de la création de notre application, du site internet destiné aux professionnels ainsi que du site de gestion interne de la société.\n\nChez Shake'it Prot, nous sommes en train de changer les règles du jeu dans l'industrie des compléments alimentaires pour le sport. Si vous êtes passionné par l'innovation et la transformation, envoyez-nous votre CV.\n\nLes compétences que nous recherchons précisément sont :\n\nPHP\n\nAngular\n\nGit\n\nCompétences non obligatoires, mais... seraient un plus :\n\nSymfony\n\nIonic\n\nSQL", 'skills': {'Coding': ['SQL', 'PHP'], 'WebD': ['PHP']}}
# {'job_id': '...', 'title': 'Intégration développement web', 'company_name': 'LeaWeb', 'location': '  Caroline du Nord   ', 'via': 'via JOB Freelance', 'description': 'Recherche intégrateur et codeur pour la création de sites internet.\n\nLa partie intégration comprend des éléments graphiques (builder type elementor) mais aussi des éléments de bases de données dont les fonctions seront à créer ( Queries ) .\n\nTechnologie utilisée : Wordpress.\n\nLanguages : PHP/JS\n\nA terme nous voudrions utiliser un front end javascript comme ReactJS. Si vous avez des conseils ils seront les bienvenus.\n\nBonne journée freelances', 'skills': {'Coding': ['PHP'], 'WebD': ['PHP']}}
# {'job_id': '', 'title': 'Développeur Full Stack', 'company_name': 'DIALOG INSIGHT', 'location': '  Remote, Oregon   ', 'via': 'via Indeed', 'description': 'Notre environnement : C#, Vue.Js, Javascript .Net Core, Web API, Docker, Microservices, Langage SQL, test unitaire, Git, Azure DevOps, MongoDB, Visual Studio, etc.!\n\nTa mission\n• Assurer le développement d’une plateforme de grande envergure qui opère dans un environnement a forte capacité et haute concurrence sur les bases de données (Big Data);\n• Participer à l’élaboration de solutions technologiques et aux analyses;\n• Concevoir et programmer les fonctionnalités systèmes et les interfaces web pour interagir avec celles-ci;\n• Participer à la maintenance et l’amélioration de notre plateforme;\n• Participer aux phases de test afin d’assurer la qualité des développements;\n• Amener ta contribution à la réussite de l’entreprise.\n\nTon profil\n• Formation universitaire en informatique ou génie logiciel;\n• Maîtrise des langages de programmation tels que C# et Javascript;\n• Bonne connaissance d’un framework de développement web comme Vue.JS ou équivalent;\n• Bonne connaissance des bases de... données relationnelles (SQL);\n• Sens de l’écoute, débrouillardise et capacité de travailler en équipe.\n\nLa culture et vie sociale chez DI\n• Passion, engagement et dépassement sont au cœur de notre culture;\n• Orientation client, souplesse, excellence, distinction et intégrité ; cinq valeurs qui guident nos décisions au quotidien;\n• Travailler avec une équipe multidisciplinaire sur des projets challengeant et surtout stimulants;\n• Des activités sportives, 5 à 7 et autres activités sociales.\n\nÀ propos de Dialog Insight\n• Entreprise née à Québec qui œuvre dans le marketing personnalisé depuis maintenant plus de 20 ans;\n• Plus de 60 employés répartis dans trois bureaux (Québec, Montréal et Marseille);\n• Un fonctionnement en télétravail avec Teams de partout;\n• Des défis quotidiens et une équipe pour t’appuyer', 'skills': {'Coding': ['SQL', 'C'], 'WebD': ['Javascript', 'client'], 'DevOps': ['Docker', 'DevOps', 'MongoDB']}}
# ...
# {'job_id': '...', 'title': 'Full Stack Developer - ReactJS, Python, NodeJS, PostgreSQL', 'company_name': 'BCAA', 'location': '  Canada   ', 'via': 'via Workopolis', 'description': "Work at an award-winning top employer! If you are looking for an empowering and progressive place to shape your future, then you’ve landed in the right place at BCAA. With our corporate Head Office in Burnaby and locations around BC, we offer a wide variety of opportunities all across the province. Share our purpose to empower British Columbians to move forward.\n\nBCAA has been named one of BC’s Top Employers 2022!\n\nWhat BCAA offers you:\n• It’s not in our nature to brag but we are proud of some of our achievements that recognize great employee culture. Some of our latest awards include being named as one of BC's Top Employers 2022, 2021, 2019 Platinum level Best Employer by AON and being recognized as a 2018 Outstanding Workplace by YWCA.\n• Our team members get to make a difference in the lives of our Members and their communities every day.\n• We pride ourselves in being open and transparent and in empowering our people to do great work while serving our Members.\n• We enthusiastically... support learning and advancement opportunities for our team members.\n• We are an equal opportunity employer that’s committed to accessible, inclusive employment.\n• Our Regular Full-Time & Part-Time+ (working 20 hours or more per week) status team members are eligible to participate in our amazing Total Rewards Program which offers: Extended Health and Dental, Vision Care, Life Insurance, RRSP matching with company contribution to your pension, access to Incentive Programs, Team Profit Sharing, Employee & Family Assistance Program and more.\n• Team members at our Home Office will have access to our cafeteria onsite, we also have a number of coffee stations throughout the building stocked with complimentary tea & coffee options.\n\nBCAA is looking for a Regular Full-Time Full Stack Developer!\n\nPlease note the BCAA supports a hybrid work model which requires a commute to our Head Office in Burnaby, BC two days a week.\n\nThis is an exciting opportunity for someone enthusiastic about the future of mobility and micro-mobility. The ideal candidate will have an inquisitive and learning mindset to work with the latest innovative technologies to bring game changing alternate transportation options to the lower mainland. You will be working with the next generation of mobility vehicles and software systems to bring the offerings to life.\n\nWe are looking for Intermediate Full Stack Developer (FSD) who can pick up any technology quickly and is comfortable jumping into platforms and various code bases.\n\nAs a member of the Mobility Technology team, the FSD is responsible for the development and delivery of BCAA’s mobility and micro-mobility solutions, including enhancements, POCs and collaborative design with business areas.\n\nThe FSD understands the importance of teamwork and can lead by example when working collaboratively with business areas across the organization, vendor partners, and direct team members.\n\nThe FSD designs, implements, tests and debugs software programs and documents, and maintains applications. The FSD is expected to be able to work with a variety of technology, and will be working closely with the solution and data architects in implementation, design, and troubleshooting across the systems to identify and resolve issues.\n\nWe value independent thinking, initiative, teamwork, a relentless pursuit of quality, a playful spirit, and a sense of humour. We like smart people – IQ and EQ – change-makers with strong shared values that want to positively impact lives of British Columbians and our communities.\n\nSuccess in this role looks like: Effectively building and deploying solutions to business objectives and customer experience in a start-up like environment.\n\nThe FSD will spend 50% or more of the time on UI development and troubleshootin ...
# {'job_id': '...', 'title': 'Python Application Developers- Full stack - REMOTE', 'company_name': 'Software International', 'location': ' Anywhere ', 'via': 'via ZipRecruiter', 'description': 'Our company Software International (SI) supplies technical talent to Fortune 100 & 500 companies such as Ericsson, Huawei, CapGemini and many other small/midsized organizations across Canada/US.\n\nRole: Python Application Developers- Full stack\n\nLocation: Mississauga, ON (Remote)\n\nStart date: Immediate availability\n\nDuration: 4.5 months to start\n\nRate: $55-65/hr C2C\n\nBackground check MANDA TORY\n\nRequest ID: 12225773\n\nPYTHON IS MANDATORY.\n\nJob Description:\n\nComputer Science degree or equivalent education and experience\n\nHighly developed skills in Python and/or Node.js\n\nExpertise with web frameworks such as React, Angular, or Vue\n\nInfrastructure knowledge including RESTful API frameworks (Flask, Express.Js) and Single Sign On\n\nExperience with TDD and unit and functional/acceptance test frameworks and automation technologies, such as unittest, py.test, Mocha, Jest, Selenium\n\nExperience developing data-intensive applications in a cloud-based environment\n\nStrong understanding of Agile... methodologies and professional experience on an agile team, including pair programming\n\nKeen collaborator and clear communicator, responsive to service needs and operational demands\n\nPassionate about the impact of emerging technologies and learning new skills and ideas\n\nSelf-starter who embraces a culture of transparency and trust, and thrives in an environment of rapid change and growth\n\nFront End – React , Javascript, Angular\n\nMiddle layer – REST APIs, GraphQL, Microservices concepts, Node.js microservices\n\nBack End – Node.js, Python, Python Framworks Django etc.\n\nFamiliarity with Azure DevOps', 'skills': {'Coding': ['Python'], 'WebD': ['Python', 'Javascript', 'Django'], 'DevOps': ['Node.js', 'DevOps'], 'ML/AI': ['Django', 'Flask']}}
# {'job_id': '...', 'title': 'Jr. Python (Django, Flask) and JavaScript (React, NodeJS...', 'company_name': 'S.i. Systems', 'location': '  Toronto, ON, Canada   ', 'via': 'via Talent.com', 'description': 'Jr. Python (Django, Flask) and JavaScript (React, NodeJS) Developer to design, develop and maintain cloud hosted web applications built on top of machine learning systems for our large Telecom client - 3272\n\nDuration : 6 Months (Possible extension / FTE)\n\nLocation : Remote\n\nJob ID : 3272\n\nResponsibilities :\n• Design, Develop and maintain Web Applications hosted on the cloud\n• Triage and debug defects and issues with production-grade applications on the cloud\n• Implement UI / UX requirements using the necessary web development frameworks\n• Implement appropriate authentication, front end and backend layers as required\n• Work with product requirements team to evaluate and implement web application\n• Develop and maintain CI / CD pipelines for web applications\n\nMust Haves :\n• 2+ years experience of web application development using JavaScript (NodeJS, React, AngularJS)\n• 2+ years experience of web application development using Python (Flask, Django)\n• Cloud platform experience (GCP... preferred)\n• Experience developing and maintaining CI / CD pipelines for web applications\n\nNice to Have :\n• Experience with SQL and NoSQL based databases and data warehouses with experience in building applications that connect to and from these databases\n• Proven experience with Docker, Kubernetes and containerized applications\n• Familiarity with git for version control\n• Familiarity with LLM application development frameworks such as Langchain a big plus', 'skills': {'Coding': ['Python', 'SQL', 'JavaScript'], 'WebD': ['Python', 'client', 'Django'], 'ML/AI': ['Django', 'Flask'], 'DevOps': ['Docker', 'NoSQL', 'UX', 'UI']}}
# {'job_id': '...', 'title': 'Node.JS Developer', 'company_name': 'Mindpal', 'location': '  Ottawa, ON, Canada   ', 'via': 'via Talent.com', 'description': 'We are currently seeking a talented and experienced Node.js Developer\n\nResponsibilities :\n\nDevelop and maintain server-side web applications using Node.js\n\nCollaborate with cross-functional teams to design and implement robust APIs and backend systems\n\nWrite clean and efficient code, following best practices and coding standards\n\nConduct thorough testing and debugging of applications to ensure high-quality deliverables\n\nOptimize application performance and scalability\n\nStay up-to-date with the latest trends and advancements in Node.js development\n\nRequirements :\n\nProven experience as a Node.js Developer, with a solid understanding of Node.js and its core principles\n\nProficiency in JavaScript\n\nKnowledge of Express.js or similar web application frameworks\n\nExperience with NoSQL databases, such as MongoDB\n\nUnderstanding of asynchronous programming and event-driven architectures\n\nExperience with version control systems, preferably Git\n\nStrong problem-solving skills and the ability to work... in a collaborative team environment\n\nExcellent communication and interpersonal skills\n\nNice to have : Familiarity with front-end technologies such as HTML, CSS, and JavaScript frameworks (e.g., React, Angular, Vue.js)\n\nWe offer : Flexible work-hours\n\nFlexible work-hours\n\npart-time / full-time\n\nCompetitive salary\n\nRequirements\n\nResponsibilities\n\nBenefits', 'skills': {'DevOps': ['Node.js', 'NoSQL', 'MongoDB'], 'WebD': ['Express.js', 'HTML', 'CSS', 'server'], 'Coding': ['CSS', 'HTML', 'JavaScript'], 'Soft_Skills': ['Flexible']}}
# {'job_id': '...', 'title': 'Jr. Python', 'company_name': 'S.i. Systems', 'location': '  Montreal, QC, Canada   ', 'via': 'via BeBee Canada', 'description': 'Jr. Python (Django, Flask) and JavaScript (React, NodeJS) Developer to design, develop and maintain cloud hosted web applications built on top of machine learning systems for our large Telecom client - 3272\n\nDuration: 6 Months (Possible extension/FTE)\nLocation: Remote\nJob ID : 3272\n\nResponsibilities:\n• Design, Develop and maintain Web Applications hosted on the cloud\n• Triage and debug defects and issues with production-grade applications on the cloud\n• Implement UI/UX requirements using the necessary web development frameworks\n• Implement appropriate authentication, front end and backend layers as required\n• Work with product requirements team to evaluate and implement web application\n• Develop and maintain CI/CD pipelines for web applications Must Haves:\n• 2+ years experience of web application development using JavaScript (NodeJS, React, AngularJS)\n• 2+ years experience of web application development using Python (Flask, Django)\n• Cloud platform experience (GCP preferred)\n•... Experience developing and maintaining CI/CD pipelines for web applications Nice to Have:\n• Experience with SQL and NoSQL based databases and data warehouses with experience in building applications that connect to and from these databases\n• Proven experience with Docker, Kubernetes and containerized applications\n• Familiarity with git for version control\n• Familiarity with LLM application development frameworks such as Langchain a big plus', 'skills': {'Coding': ['Python', 'SQL', 'JavaScript'], 'WebD': ['Python', 'client', 'Django'], 'ML/AI': ['Django', 'Flask'], 'DevOps': ['Docker', 'NoSQL', 'UX', 'UI']}}
# {'job_id': '...', 'title': 'Jr. Python (Django, Flask) and JavaScript (React, NodeJS...', 'company_name': 'S.i. Systems', 'location': '  Edmonton, AB, Canada   ', 'via': 'via Talent.com', 'description': 'Jr. Python (Django, Flask) and JavaScript (React, NodeJS) Developer to design, develop and maintain cloud hosted web applications built on top of machine learning systems for our large Telecom client - 3272\n\nDuration : 6 Months (Possible extension / FTE)\n\nLocation : Remote\n\nJob ID : 3272\n\nResponsibilities :\n• Design, Develop and maintain Web Applications hosted on the cloud\n• Triage and debug defects and issues with production-grade applications on the cloud\n• Implement UI / UX requirements using the necessary web development frameworks\n• Implement appropriate authentication, front end and backend layers as required\n• Work with product requirements team to evaluate and implement web application\n• Develop and maintain CI / CD pipelines for web applications\n\nMust Haves :\n• 2+ years experience of web application development using JavaScript (NodeJS, React, AngularJS)\n• 2+ years experience of web application development using Python (Flask, Django)\n• Cloud platform experience (GCP... preferred)\n• Experience developing and maintaining CI / CD pipelines for web applications\n\nNice to Have :\n• Experience with SQL and NoSQL based databases and data warehouses with experience in building applications that connect to and from these databases\n• Proven experience with Docker, Kubernetes and containerized applications\n• Familiarity with git for version control\n• Familiarity with LLM application development frameworks such as Langchain a big plus', 'skills': {'Coding': ['Python', 'SQL', 'JavaScript'], 'WebD': ['Python', 'client', 'Django'], 'ML/AI': ['Django', 'Flask'], 'DevOps': ['Docker', 'NoSQL', 'UX', 'UI']}}
# {'job_id': '...', 'title': 'Jr. Python (Django, Flask) and JavaScript (React, NodeJS...', 'company_name': 'S.i. Systems', 'location': '  Calgary, AB, Canada   ', 'via': 'via Talent.com', 'description': 'Jr. Python (Django, Flask) and JavaScript (React, NodeJS) Developer to design, develop and maintain cloud hosted web applications built on top of machine learning systems for our large Telecom client - 3272\n\nDuration : 6 Months (Possible extension / FTE)\n\nLocation : Remote\n\nJob ID : 3272\n\nResponsibilities :\n• Design, Develop and maintain Web Applications hosted on the cloud\n• Triage and debug defects and issues with production-grade applications on the cloud\n• Implement UI / UX requirements using the necessary web development frameworks\n• Implement appropriate authentication, front end and backend layers as required\n• Work with product requirements team to evaluate and implement web application\n• Develop and maintain CI / CD pipelines for web applications\n\nMust Haves :\n• 2+ years experience of web application development using JavaScript (NodeJS, React, AngularJS)\n• 2+ years experience of web application development using Python (Flask, Django)\n• Cloud platform experience (GCP... preferred)\n• Experience developing and maintaining CI / CD pipelines for web applications\n\nNice to Have :\n• Experience with SQL and NoSQL based databases and data warehouses with experience in building applications that connect to and from these databases\n• Proven experience with Docker, Kubernetes and containerized applications\n• Familiarity with git for version control\n• Familiarity with LLM application development frameworks such as Langchain a big plus', 'skills': {'Coding': ['Python', 'SQL', 'JavaScript'], 'WebD': ['Python', 'client', 'Django'], 'ML/AI': ['Django', 'Flask'], 'DevOps': ['Docker', 'NoSQL', 'UX', 'UI']}}

# %%
import json
with open('entreprise_data.json') as f:
    cleaned = json.load(f)
for c in cleaned:
    print(c)
# Out:
# Nom
# Type
# Region
# Arrondissement
# Commune
# Quartier
# Tél
# Statut ligne

# %%
import json
elasticsearch_url = "http://localhost:9200"
with open('jobs_jumble.json') as f:
    cleaned = json.load(f)
for c in cleaned:
        response = requests.post(
            f"{elasticsearch_url}/software_jobs/_doc",
            json=c,
            auth=(username, password)  # Include authentication parameters

        )

        if response.status_code == 201:
            print(f"Job uploaded successfully: {response.json()}")
        else:
            print(f"Error uploading job: {response.json()}")
# Out:
# Job uploaded successfully: {'_index': 'software_jobs', '_id': 'z2-egI0BYlVpQ6ja1zhs', '_version': 1, 'result': 'created', '_shards': {'total': 1, 'successful': 1, 'failed': 0}, '_seq_no': 0, '_primary_term': 1}
# Job uploaded successfully: {'_index': 'software_jobs', '_id': '0G-egI0BYlVpQ6ja1zil', '_version': 1, 'result': 'created', '_shards': {'total': 1, 'successful': 1, 'failed': 0}, '_seq_no': 1, '_primary_term': 1}
# Job uploaded successfully: {'_index': 'software_jobs', '_id': '0W-egI0BYlVpQ6ja1zit', '_version': 1, 'result': 'created', '_shards': {'total': 1, 'successful': 1, 'failed': 0}, '_seq_no': 2, '_primary_term': 1}
# Job uploaded successfully: {'_index': 'software_jobs', '_id': '0m-egI0BYlVpQ6ja1zi2', '_version': 1, 'result': 'created', '_shards': {'total': 1, 'successful': 1, 'failed': 0}, '_seq_no': 3, '_primary_term': 1}
# Job uploaded successfully: {'_index': 'software_jobs', '_id': '02-egI0BYlVpQ6ja1zjT', '_version': 1, 'result': 'created', '_shards': {'total': 1, 'successful': 1, 'failed': 0}, '_seq_no': 4, '_primary_term': 1}
# Job uploaded successfully: {'_index': 'software_jobs', '_id': '1G-egI0BYlVpQ6ja1zjb', '_version': 1, 'result': 'created', '_shards': {'total': 1, 'successful': 1, 'failed': 0}, '_seq_no': 5, '_primary_term': 1}
# Job uploaded successfully: {'_index': 'software_jobs', '_id': '1W-egI0BYlVpQ6ja1zjk', '_version': 1, 'result': 'created', '_shards': {'total': 1, 'successful': 1, 'failed': 0}, '_seq_no': 6, '_primary_term': 1}
# Job uploaded successfully: {'_index': 'software_jobs', '_id': '1m-egI0BYlVpQ6ja1zjs', '_version': 1, 'result': 'created', '_shards': {'total': 1, 'successful': 1, 'failed': 0}, '_seq_no': 7, '_primary_term': 1}
# Job uploaded successfully: {'_index': 'software_jobs', '_id': '12-egI0BYlVpQ6ja1zjz', '_version': 1, 'result': 'created', '_shards': {'total': 1, 'successful': 1, 'failed': 0}, '_seq_no': 8, '_primary_term': 1}
# Job uploaded successfully: {'_index': 'software_jobs', '_id': '2G-egI0BYlVpQ6ja1zj6', '_version': 1, 'result': 'created', '_shards': {'total': 1, 'successful': 1, 'failed': 0}, '_seq_no': 9, '_primary_term': 1}
# Job uploaded successfully: {'_index': 'software_jobs', '_id': '2W-egI0BYlVpQ6ja2DgD', '_version': 1, 'result': 'created', '_shards': {'total': 1, 'successful': 1, 'failed': 0}, '_seq_no': 10, '_primary_term': 1}
# Job uploaded successfully: {'_index': 'software_jobs', '_id': '2m-egI0BYlVpQ6ja2DgM', '_version': 1, 'result': 'created', '_shards': {'total': 1, 'successful': 1, 'failed': 0}, '_seq_no': 11, '_primary_term': 1}
# Job uploaded successfully: {'_index': 'software_jobs', '_id': '22-egI0BYlVpQ6ja2DgX', '_version': 1, 'result': 'created', '_shards': {'total': 1, 'successful': 1, 'failed': 0}, '_seq_no': 12, '_primary_term': 1}
# Job uploaded successfully: {'_index': 'software_jobs', '_id': '3G-egI0BYlVpQ6ja2Dg3', '_version': 1, 'result': 'created', '_shards': {'total': 1, 'successful': 1, 'failed': 0}, '_seq_no': 13, '_primary_term': 1}
# Job uploaded successfully: {'_index': 'software_jobs', '_id': '3W-egI0BYlVpQ6ja2Dg_', '_version': 1, 'result': 'created', '_shards': {'total': 1, 'successful': 1, 'failed': 0}, '_seq_no': 14, '_primary_term': 1}
# Job uploaded successfully: {'_index': 'software_jobs', '_id': '3m-egI0BYlVpQ6ja2DhI', '_version': 1, 'result': 'created', '_shards': {'total': 1, 'successful': 1, 'failed': 0}, '_seq_no': 15, '_primary_term': 1}
# Job uploaded successfully: {'_index': 'software_jobs', '_id': '32-egI0BYlVpQ6ja2DhP', '_version': 1, 'result': 'created', '_shards': {'total': 1, 'successful': 1, 'failed': 0}, '_seq_no': 16, '_primary_term': 1}
# Job uploaded successfully: {'_index': 'software_jobs', '_id': '4G-egI0BYlVpQ6ja2DhW', '_version': 1, 'result': 'created', '_shards': {'total': 1, 'successful': 1, 'failed': 0}, '_seq_no': 17, '_primary_term': 1}
# Job uploaded successfully: {'_index': 'software_jobs', '_id': '4W-egI0BYlVpQ6ja2Dhe', '_version': 1, 'result': 'created', '_shards': {'total': 1, 'successful': 1, 'failed': 0}, '_seq_no': 18, '_primary_term': 1}
# Job uploaded successfully: {'_index': 'software_jobs', '_id': '4m-egI0BYlVpQ6ja2Dhm', '_version': 1, 'result': 'created', '_shards': {'total': 1, 'successful': 1, 'failed': 0}, '_seq_no': 19, '_primary_term': 1}
# Job uploaded successfully: {'_index': 'software_jobs', '_id': '42-egI0BYlVpQ6ja2Dhu', '_version': 1, 'result': 'created', '_shards': {'total': 1, 'successful': 1, 'failed': 0}, '_seq_no': 20, '_primary_term': 1}
# Job uploaded successfully: {'_index': 'software_jobs', '_id': '5G-egI0BYlVpQ6ja2Dh2', '_version': 1, 'result': 'created', '_shards': {'total': 1, 'successful': 1, 'failed': 0}, '_seq_no': 21, '_primary_term': 1}
# Job uploaded successfully: {'_index': 'software_jobs', '_id': '5W-egI0BYlVpQ6ja2DiB', '_version': 1, 'result': 'created', '_shards': {'total': 1, 'successful': 1, 'failed': 0}, '_seq_no': 22, '_primary_term': 1}
# Job uploaded successfully: {'_index': 'software_jobs', '_id': '5m-egI0BYlVpQ6ja2DiL', '_version': 1, 'result': 'created', '_shards': {'total': 1, 'successful': 1, 'failed': 0}, '_seq_no': 23, '_primary_term': 1}
# Job uploaded successfully: {'_index': 'software_jobs', '_id': '52-egI0BYlVpQ6ja2DiS', '_version': 1, 'result': 'created', '_shards': {'total': 1, 'successful': 1, 'failed': 0}, '_seq_no': 24, '_primary_term': 1}
# Job uploaded successfully: {'_index': 'software_jobs', '_id': '6G-egI0BYlVpQ6ja2Did', '_version': 1, 'result': 'created', '_shards': {'total': 1, 'successful': 1, 'failed': 0}, '_seq_no': 25, '_primary_term': 1}
# Job uploaded successfully: {'_index': 'software_jobs', '_id': '6W-egI0BYlVpQ6ja2Dik', '_version': 1, 'result': 'created', '_shards': {'total': 1, 'successful': 1, 'failed': 0}, '_seq_no': 26, '_primary_term': 1}
# Job uploaded successfully: {'_index': 'software_jobs', '_id': '6m-egI0BYlVpQ6ja2Dis', '_version': 1, 'result': 'created', '_shards': {'total': 1, 'successful': 1, 'failed': 0}, '_seq_no': 27, '_primary_term': 1}
# Job uploaded successfully: {'_index': 'software_jobs', '_id': '62-egI0BYlVpQ6ja2Diz', '_version': 1, 'result': 'created', '_shards': {'total': 1, 'successful': 1, 'failed': 0}, '_seq_no': 28, '_primary_term': 1}
# Job uploaded successfully: {'_index': 'software_jobs', '_id': '7G-egI0BYlVpQ6ja2Di7', '_version': 1, 'result': 'created', '_shards': {'total': 1, 'successful': 1, 'failed': 0}, '_seq_no': 29, '_primary_term': 1}
# Job uploaded successfully: {'_index': 'software_jobs', '_id': '7W-egI0BYlVpQ6ja2DjD', '_version': 1, 'result': 'created', '_shards': {'total': 1, 'successful': 1, 'failed': 0}, '_seq_no': 30, '_primary_term': 1}
# Job uploaded successfully: {'_index': 'software_jobs', '_id': '7m-egI0BYlVpQ6ja2DjM', '_version': 1, 'result': 'created', '_shards': {'total': 1, 'successful': 1, 'failed': 0}, '_seq_no': 31, '_primary_term': 1}
# Job uploaded successfully: {'_index': 'software_jobs', '_id': '72-egI0BYlVpQ6ja2DjT', '_version': 1, 'result': 'created', '_shards': {'total': 1, 'successful': 1, 'failed': 0}, '_seq_no': 32, '_primary_term': 1}
# Job uploaded successfully: {'_index': 'software_jobs', '_id': '8G-egI0BYlVpQ6ja2Djc', '_version': 1, 'result': 'created', '_shards': {'total': 1, 'successful': 1, 'failed': 0}, '_seq_no': 33, '_primary_term': 1}
# Job uploaded successfully: {'_index': 'software_jobs', '_id': '8W-egI0BYlVpQ6ja2Djk', '_version': 1, 'result': 'created', '_shards': {'total': 1, 'successful': 1, 'failed': 0}, '_seq_no': 34, '_primary_term': 1}
# Job uploaded successfully: {'_index': 'software_jobs', '_id': '8m-egI0BYlVpQ6ja2Djs', '_version': 1, 'result': 'created', '_shards': {'total': 1, 'successful': 1, 'failed': 0}, '_seq_no': 35, '_primary_term': 1}
# Job uploaded successfully: {'_index': 'software_jobs', '_id': '82-egI0BYlVpQ6ja2Djz', '_version': 1, 'result': 'created', '_shards': {'total': 1, 'successful': 1, 'failed': 0}, '_seq_no': 36, '_primary_term': 1}
# Job uploaded successfully: {'_index': 'software_jobs', '_id': '9G-egI0BYlVpQ6ja2Dj5', '_version': 1, 'result': 'created', '_shards': {'total': 1, 'successful': 1, 'failed': 0}, '_seq_no': 37, '_primary_term': 1}
# Job uploaded successfully: {'_index': 'software_jobs', '_id': '9W-egI0BYlVpQ6ja2TgC', '_version': 1, 'result': 'created', '_shards': {'total': 1, 'successful': 1, 'failed': 0}, '_seq_no': 38, '_primary_term': 1}
# Job uploaded successfully: {'_index': 'software_jobs', '_id': '9m-egI0BYlVpQ6ja2TgJ', '_version': 1, 'result': 'created', '_shards': {'total': 1, 'successful': 1, 'failed': 0}, '_seq_no': 39, '_primary_term': 1}
# Job uploaded successfully: {'_index': 'software_jobs', '_id': '92-egI0BYlVpQ6ja2TgR', '_version': 1, 'result': 'created', '_shards': {'total': 1, 'successful': 1, 'failed': 0}, '_seq_no': 40, '_primary_term': 1}
# Job uploaded successfully: {'_index': 'software_jobs', '_id': '-G-egI0BYlVpQ6ja2TgZ', '_version': 1, 'result': 'created', '_shards': {'total': 1, 'successful': 1, 'failed': 0}, '_seq_no': 41, '_primary_term': 1}
# Job uploaded successfully: {'_index': 'software_jobs', '_id': '-W-egI0BYlVpQ6ja2Tgj', '_version': 1, 'result': 'created', '_shards': {'total': 1, 'successful': 1, 'failed': 0}, '_seq_no': 42, '_primary_term': 1}
# Job uploaded successfully: {'_index': 'software_jobs', '_id': '-m-egI0BYlVpQ6ja2Tgr', '_version': 1, 'result': 'created', '_shards': {'total': 1, 'successful': 1, 'failed': 0}, '_seq_no': 43, '_primary_term': 1}
# Job uploaded successfully: {'_index': 'software_jobs', '_id': '-2-egI0BYlVpQ6ja2Tgz', '_version': 1, 'result': 'created', '_shards': {'total': 1, 'successful': 1, 'failed': 0}, '_seq_no': 44, '_primary_term': 1}
# Job uploaded successfully: {'_index': 'software_jobs', '_id': '_G-egI0BYlVpQ6ja2Tg7', '_version': 1, 'result': 'created', '_shards': {'total': 1, 'successful': 1, 'failed': 0}, '_seq_no': 45, '_primary_term': 1}
# Job uploaded successfully: {'_index': 'software_jobs', '_id': '_W-egI0BYlVpQ6ja2ThD', '_version': 1, 'result': 'created', '_shards': {'total': 1, 'successful': 1, 'failed': 0}, '_seq_no': 46, '_primary_term': 1}
# Job uploaded successfully: {'_index': 'software_jobs', '_id': '_m-egI0BYlVpQ6ja2ThJ', '_version': 1, 'result': 'created', '_shards': {'total': 1, 'successful': 1, 'failed': 0}, '_seq_no': 47, '_primary_term': 1}
# Job uploaded successfully: {'_index': 'software_jobs', '_id': '_2-egI0BYlVpQ6ja2ThT', '_version': 1, 'result': 'created', '_shards': {'total': 1, 'successful': 1, 'failed': 0}, '_seq_no': 48, '_primary_term': 1}
# Job uploaded successfully: {'_index': 'software_jobs', '_id': 'AG-egI0BYlVpQ6ja2TlZ', '_version': 1, 'result': 'created', '_shards': {'total': 1, 'successful': 1, 'failed': 0}, '_seq_no': 49, '_primary_term': 1}
# Job uploaded successfully: {'_index': 'software_jobs', '_id': 'AW-egI0BYlVpQ6ja2Tlh', '_version': 1, 'result': 'created', '_shards': {'total': 1, 'successful': 1, 'failed': 0}, '_seq_no': 50, '_primary_term': 1}
# Job uploaded successfully: {'_index': 'software_jobs', '_id': 'Am-egI0BYlVpQ6ja2Tls', '_version': 1, 'result': 'created', '_shards': {'total': 1, 'successful': 1, 'failed': 0}, '_seq_no': 51, '_primary_term': 1}
# Job uploaded successfully: {'_index': 'software_jobs', '_id': 'A2-egI0BYlVpQ6ja2TmL', '_version': 1, 'result': 'created', '_shards': {'total': 1, 'successful': 1, 'failed': 0}, '_seq_no': 52, '_primary_term': 1}
# Job uploaded successfully: {'_index': 'software_jobs', '_id': 'BG-egI0BYlVpQ6ja2TmT', '_version': 1, 'result': 'created', '_shards': {'total': 1, 'successful': 1, 'failed': 0}, '_seq_no': 53, '_primary_term': 1}
# Job uploaded successfully: {'_index': 'software_jobs', '_id': 'BW-egI0BYlVpQ6ja2Tmc', '_version': 1, 'result': 'created', '_shards': {'total': 1, 'successful': 1, 'failed': 0}, '_seq_no': 54, '_primary_term': 1}
# Job uploaded successfully: {'_index': 'software_jobs', '_id': 'Bm-egI0BYlVpQ6ja2Tmk', '_version': 1, 'result': 'created', '_shards': {'total': 1, 'successful': 1, 'failed': 0}, '_seq_no': 55, '_primary_term': 1}
# Job uploaded successfully: {'_index': 'software_jobs', '_id': 'B2-egI0BYlVpQ6ja2Tms', '_version': 1, 'result': 'created', '_shards': {'total': 1, 'successful': 1, 'failed': 0}, '_seq_no': 56, '_primary_term': 1}
# Job uploaded successfully: {'_index': 'software_jobs', '_id': 'CG-egI0BYlVpQ6ja2Tm1', '_version': 1, 'result': 'created', '_shards': {'total': 1, 'successful': 1, 'failed': 0}, '_seq_no': 57, '_primary_term': 1}
# Job uploaded successfully: {'_index': 'software_jobs', '_id': 'CW-egI0BYlVpQ6ja2Tm-', '_version': 1, 'result': 'created', '_shards': {'total': 1, 'successful': 1, 'failed': 0}, '_seq_no': 58, '_primary_term': 1}
# Job uploaded successfully: {'_index': 'software_jobs', '_id': 'Cm-egI0BYlVpQ6ja2TnH', '_version': 1, 'result': 'created', '_shards': {'total': 1, 'successful': 1, 'failed': 0}, '_seq_no': 59, '_primary_term': 1}
# Job uploaded successfully: {'_index': 'software_jobs', '_id': 'C2-egI0BYlVpQ6ja2TnP', '_version': 1, 'result': 'created', '_shards': {'total': 1, 'successful': 1, 'failed': 0}, '_seq_no': 60, '_primary_term': 1}
# Job uploaded successfully: {'_index': 'software_jobs', '_id': 'DG-egI0BYlVpQ6ja2TnX', '_version': 1, 'result': 'created', '_shards': {'total': 1, 'successful': 1, 'failed': 0}, '_seq_no': 61, '_primary_term': 1}
# Job uploaded successfully: {'_index': 'software_jobs', '_id': 'DW-egI0BYlVpQ6ja2Tnf', '_version': 1, 'result': 'created', '_shards': {'total': 1, 'successful': 1, 'failed': 0}, '_seq_no': 62, '_primary_term': 1}
# Job uploaded successfully: {'_index': 'software_jobs', '_id': 'Dm-egI0BYlVpQ6ja2Tnm', '_version': 1, 'result': 'created', '_shards': {'total': 1, 'successful': 1, 'failed': 0}, '_seq_no': 63, '_primary_term': 1}
# Job uploaded successfully: {'_index': 'software_jobs', '_id': 'D2-egI0BYlVpQ6ja2Tnu', '_version': 1, 'result': 'created', '_shards': {'total': 1, 'successful': 1, 'failed': 0}, '_seq_no': 64, '_primary_term': 1}
# Job uploaded successfully: {'_index': 'software_jobs', '_id': 'EG-egI0BYlVpQ6ja2Tn1', '_version': 1, 'result': 'created', '_shards': {'total': 1, 'successful': 1, 'failed': 0}, '_seq_no': 65, '_primary_term': 1}
# Job uploaded successfully: {'_index': 'software_jobs', '_id': 'EW-egI0BYlVpQ6ja2Tn7', '_version': 1, 'result': 'created', '_shards': {'total': 1, 'successful': 1, 'failed': 0}, '_seq_no': 66, '_primary_term': 1}
# Job uploaded successfully: {'_index': 'software_jobs', '_id': 'Em-egI0BYlVpQ6ja2jkB', '_version': 1, 'result': 'created', '_shards': {'total': 1, 'successful': 1, 'failed': 0}, '_seq_no': 67, '_primary_term': 1}
# Job uploaded successfully: {'_index': 'software_jobs', '_id': 'E2-egI0BYlVpQ6ja2jkJ', '_version': 1, 'result': 'created', '_shards': {'total': 1, 'successful': 1, 'failed': 0}, '_seq_no': 68, '_primary_term': 1}
# Job uploaded successfully: {'_index': 'software_jobs', '_id': 'FG-egI0BYlVpQ6ja2jkP', '_version': 1, 'result': 'created', '_shards': {'total': 1, 'successful': 1, 'failed': 0}, '_seq_no': 69, '_primary_term': 1}
# Job uploaded successfully: {'_index': 'software_jobs', '_id': 'FW-egI0BYlVpQ6ja2jka', '_version': 1, 'result': 'created', '_shards': {'total': 1, 'successful': 1, 'failed': 0}, '_seq_no': 70, '_primary_term': 1}
# Job uploaded successfully: {'_index': 'software_jobs', '_id': 'Fm-egI0BYlVpQ6ja2jkk', '_version': 1, 'result': 'created', '_shards': {'total': 1, 'successful': 1, 'failed': 0}, '_seq_no': 71, '_primary_term': 1}
# Job uploaded successfully: {'_index': 'software_jobs', '_id': 'F2-egI0BYlVpQ6ja2jkt', '_version': 1, 'result': 'created', '_shards': {'total': 1, 'successful': 1, 'failed': 0}, '_seq_no': 72, '_primary_term': 1}
# Job uploaded successfully: {'_index': 'software_jobs', '_id': 'GG-egI0BYlVpQ6ja2jkz', '_version': 1, 'result': 'created', '_shards': {'total': 1, 'successful': 1, 'failed': 0}, '_seq_no': 73, '_primary_term': 1}
# Job uploaded successfully: {'_index': 'software_jobs', '_id': 'GW-egI0BYlVpQ6ja2jk6', '_version': 1, 'result': 'created', '_shards': {'total': 1, 'successful': 1, 'failed': 0}, '_seq_no': 74, '_primary_term': 1}
# Job uploaded successfully: {'_index': 'software_jobs', '_id': 'Gm-egI0BYlVpQ6ja2jlD', '_version': 1, 'result': 'created', '_shards': {'total': 1, 'successful': 1, 'failed': 0}, '_seq_no': 75, '_primary_term': 1}
# Job uploaded successfully: {'_index': 'software_jobs', '_id': 'G2-egI0BYlVpQ6ja2jlJ', '_version': 1, 'result': 'created', '_shards': {'total': 1, 'successful': 1, 'failed': 0}, '_seq_no': 76, '_primary_term': 1}
# Job uploaded successfully: {'_index': 'software_jobs', '_id': 'HG-egI0BYlVpQ6ja2jlQ', '_version': 1, 'result': 'created', '_shards': {'total': 1, 'successful': 1, 'failed': 0}, '_seq_no': 77, '_primary_term': 1}
# Job uploaded successfully: {'_index': 'software_jobs', '_id': 'HW-egI0BYlVpQ6ja2jlW', '_version': 1, 'result': 'created', '_shards': {'total': 1, 'successful': 1, 'failed': 0}, '_seq_no': 78, '_primary_term': 1}
# Job uploaded successfully: {'_index': 'software_jobs', '_id': 'Hm-egI0BYlVpQ6ja2jlx', '_version': 1, 'result': 'created', '_shards': {'total': 1, 'successful': 1, 'failed': 0}, '_seq_no': 79, '_primary_term': 1}
# Job uploaded successfully: {'_index': 'software_jobs', '_id': 'H2-egI0BYlVpQ6ja2jl3', '_version': 1, 'result': 'created', '_shards': {'total': 1, 'successful': 1, 'failed': 0}, '_seq_no': 80, '_primary_term': 1}
# Job uploaded successfully: {'_index': 'software_jobs', '_id': 'IG-egI0BYlVpQ6ja2jl-', '_version': 1, 'result': 'created', '_shards': {'total': 1, 'successful': 1, 'failed': 0}, '_seq_no': 81, '_primary_term': 1}
# Job uploaded successfully: {'_index': 'software_jobs', '_id': 'IW-egI0BYlVpQ6ja2jmF', '_version': 1, 'result': 'created', '_shards': {'total': 1, 'successful': 1, 'failed': 0}, '_seq_no': 82, '_primary_term': 1}
# Job uploaded successfully: {'_index': 'software_jobs', '_id': 'Im-egI0BYlVpQ6ja2jmN', '_version': 1, 'result': 'created', '_shards': {'total': 1, 'successful': 1, 'failed': 0}, '_seq_no': 83, '_primary_term': 1}
# Job uploaded successfully: {'_index': 'software_jobs', '_id': 'I2-egI0BYlVpQ6ja2jmT', '_version': 1, 'result': 'created', '_shards': {'total': 1, 'successful': 1, 'failed': 0}, '_seq_no': 84, '_primary_term': 1}
# Job uploaded successfully: {'_index': 'software_jobs', '_id': 'JG-egI0BYlVpQ6ja2jmZ', '_version': 1, 'result': 'created', '_shards': {'total': 1, 'successful': 1, 'failed': 0}, '_seq_no': 85, '_primary_term': 1}
# Job uploaded successfully: {'_index': 'software_jobs', '_id': 'JW-egI0BYlVpQ6ja2jmf', '_version': 1, 'result': 'created', '_shards': {'total': 1, 'successful': 1, 'failed': 0}, '_seq_no': 86, '_primary_term': 1}
# Job uploaded successfully: {'_index': 'software_jobs', '_id': 'Jm-egI0BYlVpQ6ja2jml', '_version': 1, 'result': 'created', '_shards': {'total': 1, 'successful': 1, 'failed': 0}, '_seq_no': 87, '_primary_term': 1}
# Job uploaded successfully: {'_index': 'software_jobs', '_id': 'J2-egI0BYlVpQ6ja2jmr', '_version': 1, 'result': 'created', '_shards': {'total': 1, 'successful': 1, 'failed': 0}, '_seq_no': 88, '_primary_term': 1}
# Job uploaded successfully: {'_index': 'software_jobs', '_id': 'KG-egI0BYlVpQ6ja2jmy', '_version': 1, 'result': 'created', '_shards': {'total': 1, 'successful': 1, 'failed': 0}, '_seq_no': 89, '_primary_term': 1}
# Job uploaded successfully: {'_index': 'software_jobs', '_id': 'KW-egI0BYlVpQ6ja2jm4', '_version': 1, 'result': 'created', '_shards': {'total': 1, 'successful': 1, 'failed': 0}, '_seq_no': 90, '_primary_term': 1}
# Job uploaded successfully: {'_index': 'software_jobs', '_id': 'Km-egI0BYlVpQ6ja2jm-', '_version': 1, 'result': 'created', '_shards': {'total': 1, 'successful': 1, 'failed': 0}, '_seq_no': 91, '_primary_term': 1}
# Job uploaded successfully: {'_index': 'software_jobs', '_id': 'K2-egI0BYlVpQ6ja2jnE', '_version': 1, 'result': 'created', '_shards': {'total': 1, 'successful': 1, 'failed': 0}, '_seq_no': 92, '_primary_term': 1}
# Job uploaded successfully: {'_index': 'software_jobs', '_id': 'LG-egI0BYlVpQ6ja2jnJ', '_version': 1, 'result': 'created', '_shards': {'total': 1, 'successful': 1, 'failed': 0}, '_seq_no': 93, '_primary_term': 1}
# Job uploaded successfully: {'_index': 'software_jobs', '_id': 'LW-egI0BYlVpQ6ja2jnP', '_version': 1, 'result': 'created', '_shards': {'total': 1, 'successful': 1, 'failed': 0}, '_seq_no': 94, '_primary_term': 1}
# Job uploaded successfully: {'_index': 'software_jobs', '_id': 'Lm-egI0BYlVpQ6ja2jnV', '_version': 1, 'result': 'created', '_shards': {'total': 1, 'successful': 1, 'failed': 0}, '_seq_no': 95, '_primary_term': 1}
# Job uploaded successfully: {'_index': 'software_jobs', '_id': 'L2-egI0BYlVpQ6ja2jna', '_version': 1, 'result': 'created', '_shards': {'total': 1, 'successful': 1, 'failed': 0}, '_seq_no': 96, '_primary_term': 1}
# Job uploaded successfully: {'_index': 'software_jobs', '_id': 'MG-egI0BYlVpQ6ja2jni', '_version': 1, 'result': 'created', '_shards': {'total': 1, 'successful': 1, 'failed': 0}, '_seq_no': 97, '_primary_term': 1}
# Job uploaded successfully: {'_index': 'software_jobs', '_id': 'MW-egI0BYlVpQ6ja2jnp', '_version': 1, 'result': 'created', '_shards': {'total': 1, 'successful': 1, 'failed': 0}, '_seq_no': 98, '_primary_term': 1}
# Job uploaded successfully: {'_index': 'software_jobs', '_id': 'Mm-egI0BYlVpQ6ja2jnv', '_version': 1, 'result': 'created', '_shards': {'total': 1, 'successful': 1, 'failed': 0}, '_seq_no': 99, '_primary_term': 1}
# Job uploaded successfully: {'_index': 'software_jobs', '_id': 'M2-egI0BYlVpQ6ja2jn1', '_version': 1, 'result': 'created', '_shards': {'total': 1, 'successful': 1, 'failed': 0}, '_seq_no': 100, '_primary_term': 1}
# Job uploaded successfully: {'_index': 'software_jobs', '_id': 'NG-egI0BYlVpQ6ja2jn7', '_version': 1, 'result': 'created', '_shards': {'total': 1, 'successful': 1, 'failed': 0}, '_seq_no': 101, '_primary_term': 1}
# Job uploaded successfully: {'_index': 'software_jobs', '_id': 'NW-egI0BYlVpQ6ja2zkB', '_version': 1, 'result': 'created', '_shards': {'total': 1, 'successful': 1, 'failed': 0}, '_seq_no': 102, '_primary_term': 1}
# Job uploaded successfully: {'_index': 'software_jobs', '_id': 'Nm-egI0BYlVpQ6ja2zkH', '_version': 1, 'result': 'created', '_shards': {'total': 1, 'successful': 1, 'failed': 0}, '_seq_no': 103, '_primary_term': 1}
# Job uploaded successfully: {'_index': 'software_jobs', '_id': 'N2-egI0BYlVpQ6ja2zkN', '_version': 1, 'result': 'created', '_shards': {'total': 1, 'successful': 1, 'failed': 0}, '_seq_no': 104, '_primary_term': 1}
# Job uploaded successfully: {'_index': 'software_jobs', '_id': 'OG-egI0BYlVpQ6ja2zkT', '_version': 1, 'result': 'created', '_shards': {'total': 1, 'successful': 1, 'failed': 0}, '_seq_no': 105, '_primary_term': 1}
# Job uploaded successfully: {'_index': 'software_jobs', '_id': 'OW-egI0BYlVpQ6ja2zka', '_version': 1, 'result': 'created', '_shards': {'total': 1, 'successful': 1, 'failed': 0}, '_seq_no': 106, '_primary_term': 1}
# Job uploaded successfully: {'_index': 'software_jobs', '_id': 'Om-egI0BYlVpQ6ja2zkg', '_version': 1, 'result': 'created', '_shards': {'total': 1, 'successful': 1, 'failed': 0}, '_seq_no': 107, '_primary_term': 1}
# Job uploaded successfully: {'_index': 'software_jobs', '_id': 'O2-egI0BYlVpQ6ja2zkl', '_version': 1, 'result': 'created', '_shards': {'total': 1, 'successful': 1, 'failed': 0}, '_seq_no': 108, '_primary_term': 1}
# Job uploaded successfully: {'_index': 'software_jobs', '_id': 'PG-egI0BYlVpQ6ja2zkr', '_version': 1, 'result': 'created', '_shards': {'total': 1, 'successful': 1, 'failed': 0}, '_seq_no': 109, '_primary_term': 1}
# Job uploaded successfully: {'_index': 'software_jobs', '_id': 'PW-egI0BYlVpQ6ja2zkx', '_version': 1, 'result': 'created', '_shards': {'total': 1, 'successful': 1, 'failed': 0}, '_seq_no': 110, '_primary_term': 1}
# Job uploaded successfully: {'_index': 'software_jobs', '_id': 'Pm-egI0BYlVpQ6ja2zk3', '_version': 1, 'result': 'created', '_shards': {'total': 1, 'successful': 1, 'failed': 0}, '_seq_no': 111, '_primary_term': 1}
# Job uploaded successfully: {'_index': 'software_jobs', '_id': 'P2-egI0BYlVpQ6ja2zk9', '_version': 1, 'result': 'created', '_shards': {'total': 1, 'successful': 1, 'failed': 0}, '_seq_no': 112, '_primary_term': 1}
# Job uploaded successfully: {'_index': 'software_jobs', '_id': 'QG-egI0BYlVpQ6ja2zlD', '_version': 1, 'result': 'created', '_shards': {'total': 1, 'successful': 1, 'failed': 0}, '_seq_no': 113, '_primary_term': 1}
# Job uploaded successfully: {'_index': 'software_jobs', '_id': 'QW-egI0BYlVpQ6ja2zlI', '_version': 1, 'result': 'created', '_shards': {'total': 1, 'successful': 1, 'failed': 0}, '_seq_no': 114, '_primary_term': 1}
# Job uploaded successfully: {'_index': 'software_jobs', '_id': 'Qm-egI0BYlVpQ6ja2zlO', '_version': 1, 'result': 'created', '_shards': {'total': 1, 'successful': 1, 'failed': 0}, '_seq_no': 115, '_primary_term': 1}
# Job uploaded successfully: {'_index': 'software_jobs', '_id': 'Q2-egI0BYlVpQ6ja2zlU', '_version': 1, 'result': 'created', '_shards': {'total': 1, 'successful': 1, 'failed': 0}, '_seq_no': 116, '_primary_term': 1}
# Job uploaded successfully: {'_index': 'software_jobs', '_id': 'RG-egI0BYlVpQ6ja2zla', '_version': 1, 'result': 'created', '_shards': {'total': 1, 'successful': 1, 'failed': 0}, '_seq_no': 117, '_primary_term': 1}
# Job uploaded successfully: {'_index': 'software_jobs', '_id': 'RW-egI0BYlVpQ6ja2zlg', '_version': 1, 'result': 'created', '_shards': {'total': 1, 'successful': 1, 'failed': 0}, '_seq_no': 118, '_primary_term': 1}
# Job uploaded successfully: {'_index': 'software_jobs', '_id': 'Rm-egI0BYlVpQ6ja2zll', '_version': 1, 'result': 'created', '_shards': {'total': 1, 'successful': 1, 'failed': 0}, '_seq_no': 119, '_primary_term': 1}
# Job uploaded successfully: {'_index': 'software_jobs', '_id': 'R2-egI0BYlVpQ6ja2zlr', '_version': 1, 'result': 'created', '_shards': {'total': 1, 'successful': 1, 'failed': 0}, '_seq_no': 120, '_primary_term': 1}
# Job uploaded successfully: {'_index': 'software_jobs', '_id': 'SG-egI0BYlVpQ6ja2zlw', '_version': 1, 'result': 'created', '_shards': {'total': 1, 'successful': 1, 'failed': 0}, '_seq_no': 121, '_primary_term': 1}
# Job uploaded successfully: {'_index': 'software_jobs', '_id': 'SW-egI0BYlVpQ6ja2zl2', '_version': 1, 'result': 'created', '_shards': {'total': 1, 'successful': 1, 'failed': 0}, '_seq_no': 122, '_primary_term': 1}
# Job uploaded successfully: {'_index': 'software_jobs', '_id': 'Sm-egI0BYlVpQ6ja2zl7', '_version': 1, 'result': 'created', '_shards': {'total': 1, 'successful': 1, 'failed': 0}, '_seq_no': 123, '_primary_term': 1}
# Job uploaded successfully: {'_index': 'software_jobs', '_id': 'S2-egI0BYlVpQ6ja2zmA', '_version': 1, 'result': 'created', '_shards': {'total': 1, 'successful': 1, 'failed': 0}, '_seq_no': 124, '_primary_term': 1}
# Job uploaded successfully: {'_index': 'software_jobs', '_id': 'TG-egI0BYlVpQ6ja2zmG', '_version': 1, 'result': 'created', '_shards': {'total': 1, 'successful': 1, 'failed': 0}, '_seq_no': 125, '_primary_term': 1}
# Job uploaded successfully: {'_index': 'software_jobs', '_id': 'TW-egI0BYlVpQ6ja2zmM', '_version': 1, 'result': 'created', '_shards': {'total': 1, 'successful': 1, 'failed': 0}, '_seq_no': 126, '_primary_term': 1}
# Job uploaded successfully: {'_index': 'software_jobs', '_id': 'Tm-egI0BYlVpQ6ja2zmS', '_version': 1, 'result': 'created', '_shards': {'total': 1, 'successful': 1, 'failed': 0}, '_seq_no': 127, '_primary_term': 1}
# Job uploaded successfully: {'_index': 'software_jobs', '_id': 'T2-egI0BYlVpQ6ja2zmY', '_version': 1, 'result': 'created', '_shards': {'total': 1, 'successful': 1, 'failed': 0}, '_seq_no': 128, '_primary_term': 1}
# Job uploaded successfully: {'_index': 'software_jobs', '_id': 'UG-egI0BYlVpQ6ja2zmf', '_version': 1, 'result': 'created', '_shards': {'total': 1, 'successful': 1, 'failed': 0}, '_seq_no': 129, '_primary_term': 1}
# Job uploaded successfully: {'_index': 'software_jobs', '_id': 'UW-egI0BYlVpQ6ja2zml', '_version': 1, 'result': 'created', '_shards': {'total': 1, 'successful': 1, 'failed': 0}, '_seq_no': 130, '_primary_term': 1}
# Job uploaded successfully: {'_index': 'software_jobs', '_id': 'Um-egI0BYlVpQ6ja2zmr', '_version': 1, 'result': 'created', '_shards': {'total': 1, 'successful': 1, 'failed': 0}, '_seq_no': 131, '_primary_term': 1}
# Job uploaded successfully: {'_index': 'software_jobs', '_id': 'U2-egI0BYlVpQ6ja2zmy', '_version': 1, 'result': 'created', '_shards': {'total': 1, 'successful': 1, 'failed': 0}, '_seq_no': 132, '_primary_term': 1}
# Job uploaded successfully: {'_index': 'software_jobs', '_id': 'VG-egI0BYlVpQ6ja2zm7', '_version': 1, 'result': 'created', '_shards': {'total': 1, 'successful': 1, 'failed': 0}, '_seq_no': 133, '_primary_term': 1}
# Job uploaded successfully: {'_index': 'software_jobs', '_id': 'VW-egI0BYlVpQ6ja2znB', '_version': 1, 'result': 'created', '_shards': {'total': 1, 'successful': 1, 'failed': 0}, '_seq_no': 134, '_primary_term': 1}
# Job uploaded successfully: {'_index': 'software_jobs', '_id': 'Vm-egI0BYlVpQ6ja2znH', '_version': 1, 'result': 'created', '_shards': {'total': 1, 'successful': 1, 'failed': 0}, '_seq_no': 135, '_primary_term': 1}
# Job uploaded successfully: {'_index': 'software_jobs', '_id': 'V2-egI0BYlVpQ6ja2znN', '_version': 1, 'result': 'created', '_shards': {'total': 1, 'successful': 1, 'failed': 0}, '_seq_no': 136, '_primary_term': 1}
# Job uploaded successfully: {'_index': 'software_jobs', '_id': 'WG-egI0BYlVpQ6ja2znT', '_version': 1, 'result': 'created', '_shards': {'total': 1, 'successful': 1, 'failed': 0}, '_seq_no': 137, '_primary_term': 1}
# Job uploaded successfully: {'_index': 'software_jobs', '_id': 'WW-egI0BYlVpQ6ja2znZ', '_version': 1, 'result': 'created', '_shards': {'total': 1, 'successful': 1, 'failed': 0}, '_seq_no': 138, '_primary_term': 1}
# Job uploaded successfully: {'_index': 'software_jobs', '_id': 'Wm-egI0BYlVpQ6ja2znf', '_version': 1, 'result': 'created', '_shards': {'total': 1, 'successful': 1, 'failed': 0}, '_seq_no': 139, '_primary_term': 1}
# Job uploaded successfully: {'_index': 'software_jobs', '_id': 'W2-egI0BYlVpQ6ja2znl', '_version': 1, 'result': 'created', '_shards': {'total': 1, 'successful': 1, 'failed': 0}, '_seq_no': 140, '_primary_term': 1}
# Job uploaded successfully: {'_index': 'software_jobs', '_id': 'XG-egI0BYlVpQ6ja2znr', '_version': 1, 'result': 'created', '_shards': {'total': 1, 'successful': 1, 'failed': 0}, '_seq_no': 141, '_primary_term': 1}
# Job uploaded successfully: {'_index': 'software_jobs', '_id': 'XW-egI0BYlVpQ6ja2znx', '_version': 1, 'result': 'created', '_shards': {'total': 1, 'successful': 1, 'failed': 0}, '_seq_no': 142, '_primary_term': 1}
# Job uploaded successfully: {'_index': 'software_jobs', '_id': 'Xm-egI0BYlVpQ6ja2zn3', '_version': 1, 'result': 'created', '_shards': {'total': 1, 'successful': 1, 'failed': 0}, '_seq_no': 143, '_primary_term': 1}
# Job uploaded successfully: {'_index': 'software_jobs', '_id': 'X2-egI0BYlVpQ6ja2zn9', '_version': 1, 'result': 'created', '_shards': {'total': 1, 'successful': 1, 'failed': 0}, '_seq_no': 144, '_primary_term': 1}
# Job uploaded successfully: {'_index': 'software_jobs', '_id': 'YG-egI0BYlVpQ6ja3DkC', '_version': 1, 'result': 'created', '_shards': {'total': 1, 'successful': 1, 'failed': 0}, '_seq_no': 145, '_primary_term': 1}
# Job uploaded successfully: {'_index': 'software_jobs', '_id': 'YW-egI0BYlVpQ6ja3DkI', '_version': 1, 'result': 'created', '_shards': {'total': 1, 'successful': 1, 'failed': 0}, '_seq_no': 146, '_primary_term': 1}
# Job uploaded successfully: {'_index': 'software_jobs', '_id': 'Ym-egI0BYlVpQ6ja3DkO', '_version': 1, 'result': 'created', '_shards': {'total': 1, 'successful': 1, 'failed': 0}, '_seq_no': 147, '_primary_term': 1}
# Job uploaded successfully: {'_index': 'software_jobs', '_id': 'Y2-egI0BYlVpQ6ja3DkT', '_version': 1, 'result': 'created', '_shards': {'total': 1, 'successful': 1, 'failed': 0}, '_seq_no': 148, '_primary_term': 1}
# Job uploaded successfully: {'_index': 'software_jobs', '_id': 'ZG-egI0BYlVpQ6ja3DkZ', '_version': 1, 'result': 'created', '_shards': {'total': 1, 'successful': 1, 'failed': 0}, '_seq_no': 149, '_primary_term': 1}
# Job uploaded successfully: {'_index': 'software_jobs', '_id': 'ZW-egI0BYlVpQ6ja3Dkf', '_version': 1, 'result': 'created', '_shards': {'total': 1, 'successful': 1, 'failed': 0}, '_seq_no': 150, '_primary_term': 1}
# Job uploaded successfully: {'_index': 'software_jobs', '_id': 'Zm-egI0BYlVpQ6ja3Dkl', '_version': 1, 'result': 'created', '_shards': {'total': 1, 'successful': 1, 'failed': 0}, '_seq_no': 151, '_primary_term': 1}
# Job uploaded successfully: {'_index': 'software_jobs', '_id': 'Z2-egI0BYlVpQ6ja3Dkr', '_version': 1, 'result': 'created', '_shards': {'total': 1, 'successful': 1, 'failed': 0}, '_seq_no': 152, '_primary_term': 1}
# Job uploaded successfully: {'_index': 'software_jobs', '_id': 'aG-egI0BYlVpQ6ja3Dkw', '_version': 1, 'result': 'created', '_shards': {'total': 1, 'successful': 1, 'failed': 0}, '_seq_no': 153, '_primary_term': 1}
# Job uploaded successfully: {'_index': 'software_jobs', '_id': 'aW-egI0BYlVpQ6ja3Dk1', '_version': 1, 'result': 'created', '_shards': {'total': 1, 'successful': 1, 'failed': 0}, '_seq_no': 154, '_primary_term': 1}
# Job uploaded successfully: {'_index': 'software_jobs', '_id': 'am-egI0BYlVpQ6ja3Dk7', '_version': 1, 'result': 'created', '_shards': {'total': 1, 'successful': 1, 'failed': 0}, '_seq_no': 155, '_primary_term': 1}
# Job uploaded successfully: {'_index': 'software_jobs', '_id': 'a2-egI0BYlVpQ6ja3DlB', '_version': 1, 'result': 'created', '_shards': {'total': 1, 'successful': 1, 'failed': 0}, '_seq_no': 156, '_primary_term': 1}
# Job uploaded successfully: {'_index': 'software_jobs', '_id': 'bG-egI0BYlVpQ6ja3DlG', '_version': 1, 'result': 'created', '_shards': {'total': 1, 'successful': 1, 'failed': 0}, '_seq_no': 157, '_primary_term': 1}
# Job uploaded successfully: {'_index': 'software_jobs', '_id': 'bW-egI0BYlVpQ6ja3DlM', '_version': 1, 'result': 'created', '_shards': {'total': 1, 'successful': 1, 'failed': 0}, '_seq_no': 158, '_primary_term': 1}
# Job uploaded successfully: {'_index': 'software_jobs', '_id': 'bm-egI0BYlVpQ6ja3DlS', '_version': 1, 'result': 'created', '_shards': {'total': 1, 'successful': 1, 'failed': 0}, '_seq_no': 159, '_primary_term': 1}
# Job uploaded successfully: {'_index': 'software_jobs', '_id': 'b2-egI0BYlVpQ6ja3DlZ', '_version': 1, 'result': 'created', '_shards': {'total': 1, 'successful': 1, 'failed': 0}, '_seq_no': 160, '_primary_term': 1}
# Job uploaded successfully: {'_index': 'software_jobs', '_id': 'cG-egI0BYlVpQ6ja3Dlf', '_version': 1, 'result': 'created', '_shards': {'total': 1, 'successful': 1, 'failed': 0}, '_seq_no': 161, '_primary_term': 1}
# Job uploaded successfully: {'_index': 'software_jobs', '_id': 'cW-egI0BYlVpQ6ja3Dll', '_version': 1, 'result': 'created', '_shards': {'total': 1, 'successful': 1, 'failed': 0}, '_seq_no': 162, '_primary_term': 1}
# Job uploaded successfully: {'_index': 'software_jobs', '_id': 'cm-egI0BYlVpQ6ja3Dlr', '_version': 1, 'result': 'created', '_shards': {'total': 1, 'successful': 1, 'failed': 0}, '_seq_no': 163, '_primary_term': 1}
# Job uploaded successfully: {'_index': 'software_jobs', '_id': 'c2-egI0BYlVpQ6ja3Dlx', '_version': 1, 'result': 'created', '_shards': {'total': 1, 'successful': 1, 'failed': 0}, '_seq_no': 164, '_primary_term': 1}
# Job uploaded successfully: {'_index': 'software_jobs', '_id': 'dG-egI0BYlVpQ6ja3Dl4', '_version': 1, 'result': 'created', '_shards': {'total': 1, 'successful': 1, 'failed': 0}, '_seq_no': 165, '_primary_term': 1}
# Job uploaded successfully: {'_index': 'software_jobs', '_id': 'dW-egI0BYlVpQ6ja3DmA', '_version': 1, 'result': 'created', '_shards': {'total': 1, 'successful': 1, 'failed': 0}, '_seq_no': 166, '_primary_term': 1}
# Job uploaded successfully: {'_index': 'software_jobs', '_id': 'dm-egI0BYlVpQ6ja3DmH', '_version': 1, 'result': 'created', '_shards': {'total': 1, 'successful': 1, 'failed': 0}, '_seq_no': 167, '_primary_term': 1}
# Job uploaded successfully: {'_index': 'software_jobs', '_id': 'd2-egI0BYlVpQ6ja3DmN', '_version': 1, 'result': 'created', '_shards': {'total': 1, 'successful': 1, 'failed': 0}, '_seq_no': 168, '_primary_term': 1}
# Job uploaded successfully: {'_index': 'software_jobs', '_id': 'eG-egI0BYlVpQ6ja3DmT', '_version': 1, 'result': 'created', '_shards': {'total': 1, 'successful': 1, 'failed': 0}, '_seq_no': 169, '_primary_term': 1}
# Job uploaded successfully: {'_index': 'software_jobs', '_id': 'eW-egI0BYlVpQ6ja3Dma', '_version': 1, 'result': 'created', '_shards': {'total': 1, 'successful': 1, 'failed': 0}, '_seq_no': 170, '_primary_term': 1}
# Job uploaded successfully: {'_index': 'software_jobs', '_id': 'em-egI0BYlVpQ6ja3Dmg', '_version': 1, 'result': 'created', '_shards': {'total': 1, 'successful': 1, 'failed': 0}, '_seq_no': 171, '_primary_term': 1}
# Job uploaded successfully: {'_index': 'software_jobs', '_id': 'e2-egI0BYlVpQ6ja3Dmm', '_version': 1, 'result': 'created', '_shards': {'total': 1, 'successful': 1, 'failed': 0}, '_seq_no': 172, '_primary_term': 1}
# Job uploaded successfully: {'_index': 'software_jobs', '_id': 'fG-egI0BYlVpQ6ja3Dmt', '_version': 1, 'result': 'created', '_shards': {'total': 1, 'successful': 1, 'failed': 0}, '_seq_no': 173, '_primary_term': 1}
# Job uploaded successfully: {'_index': 'software_jobs', '_id': 'fW-egI0BYlVpQ6ja3Dmz', '_version': 1, 'result': 'created', '_shards': {'total': 1, 'successful': 1, 'failed': 0}, '_seq_no': 174, '_primary_term': 1}
# Job uploaded successfully: {'_index': 'software_jobs', '_id': 'fm-egI0BYlVpQ6ja3Dm4', '_version': 1, 'result': 'created', '_shards': {'total': 1, 'successful': 1, 'failed': 0}, '_seq_no': 175, '_primary_term': 1}
# Job uploaded successfully: {'_index': 'software_jobs', '_id': 'f2-egI0BYlVpQ6ja3Dm-', '_version': 1, 'result': 'created', '_shards': {'total': 1, 'successful': 1, 'failed': 0}, '_seq_no': 176, '_primary_term': 1}
# Job uploaded successfully: {'_index': 'software_jobs', '_id': 'gG-egI0BYlVpQ6ja3DnF', '_version': 1, 'result': 'created', '_shards': {'total': 1, 'successful': 1, 'failed': 0}, '_seq_no': 177, '_primary_term': 1}
# Job uploaded successfully: {'_index': 'software_jobs', '_id': 'gW-egI0BYlVpQ6ja3DnL', '_version': 1, 'result': 'created', '_shards': {'total': 1, 'successful': 1, 'failed': 0}, '_seq_no': 178, '_primary_term': 1}
# Job uploaded successfully: {'_index': 'software_jobs', '_id': 'gm-egI0BYlVpQ6ja3DnS', '_version': 1, 'result': 'created', '_shards': {'total': 1, 'successful': 1, 'failed': 0}, '_seq_no': 179, '_primary_term': 1}
# Job uploaded successfully: {'_index': 'software_jobs', '_id': 'g2-egI0BYlVpQ6ja3DnY', '_version': 1, 'result': 'created', '_shards': {'total': 1, 'successful': 1, 'failed': 0}, '_seq_no': 180, '_primary_term': 1}
# Job uploaded successfully: {'_index': 'software_jobs', '_id': 'hG-egI0BYlVpQ6ja3Dne', '_version': 1, 'result': 'created', '_shards': {'total': 1, 'successful': 1, 'failed': 0}, '_seq_no': 181, '_primary_term': 1}
# Job uploaded successfully: {'_index': 'software_jobs', '_id': 'hW-egI0BYlVpQ6ja3Dnk', '_version': 1, 'result': 'created', '_shards': {'total': 1, 'successful': 1, 'failed': 0}, '_seq_no': 182, '_primary_term': 1}
# Job uploaded successfully: {'_index': 'software_jobs', '_id': 'hm-egI0BYlVpQ6ja3Dns', '_version': 1, 'result': 'created', '_shards': {'total': 1, 'successful': 1, 'failed': 0}, '_seq_no': 183, '_primary_term': 1}
# Job uploaded successfully: {'_index': 'software_jobs', '_id': 'h2-egI0BYlVpQ6ja3Dny', '_version': 1, 'result': 'created', '_shards': {'total': 1, 'successful': 1, 'failed': 0}, '_seq_no': 184, '_primary_term': 1}
# Job uploaded successfully: {'_index': 'software_jobs', '_id': 'iG-egI0BYlVpQ6ja3Dn4', '_version': 1, 'result': 'created', '_shards': {'total': 1, 'successful': 1, 'failed': 0}, '_seq_no': 185, '_primary_term': 1}
# Job uploaded successfully: {'_index': 'software_jobs', '_id': 'iW-egI0BYlVpQ6ja3Dn_', '_version': 1, 'result': 'created', '_shards': {'total': 1, 'successful': 1, 'failed': 0}, '_seq_no': 186, '_primary_term': 1}
# Job uploaded successfully: {'_index': 'software_jobs', '_id': 'im-egI0BYlVpQ6ja3TkF', '_version': 1, 'result': 'created', '_shards': {'total': 1, 'successful': 1, 'failed': 0}, '_seq_no': 187, '_primary_term': 1}
# Job uploaded successfully: {'_index': 'software_jobs', '_id': 'i2-egI0BYlVpQ6ja3TkM', '_version': 1, 'result': 'created', '_shards': {'total': 1, 'successful': 1, 'failed': 0}, '_seq_no': 188, '_primary_term': 1}
# Job uploaded successfully: {'_index': 'software_jobs', '_id': 'jG-egI0BYlVpQ6ja3TkS', '_version': 1, 'result': 'created', '_shards': {'total': 1, 'successful': 1, 'failed': 0}, '_seq_no': 189, '_primary_term': 1}
# Job uploaded successfully: {'_index': 'software_jobs', '_id': 'jW-egI0BYlVpQ6ja3TkY', '_version': 1, 'result': 'created', '_shards': {'total': 1, 'successful': 1, 'failed': 0}, '_seq_no': 190, '_primary_term': 1}
# Job uploaded successfully: {'_index': 'software_jobs', '_id': 'jm-egI0BYlVpQ6ja3Tkd', '_version': 1, 'result': 'created', '_shards': {'total': 1, 'successful': 1, 'failed': 0}, '_seq_no': 191, '_primary_term': 1}
# Job uploaded successfully: {'_index': 'software_jobs', '_id': 'j2-egI0BYlVpQ6ja3Tkj', '_version': 1, 'result': 'created', '_shards': {'total': 1, 'successful': 1, 'failed': 0}, '_seq_no': 192, '_primary_term': 1}
# Job uploaded successfully: {'_index': 'software_jobs', '_id': 'kG-egI0BYlVpQ6ja3Tkp', '_version': 1, 'result': 'created', '_shards': {'total': 1, 'successful': 1, 'failed': 0}, '_seq_no': 193, '_primary_term': 1}
# Job uploaded successfully: {'_index': 'software_jobs', '_id': 'kW-egI0BYlVpQ6ja3Tku', '_version': 1, 'result': 'created', '_shards': {'total': 1, 'successful': 1, 'failed': 0}, '_seq_no': 194, '_primary_term': 1}
# Job uploaded successfully: {'_index': 'software_jobs', '_id': 'km-egI0BYlVpQ6ja3Tk0', '_version': 1, 'result': 'created', '_shards': {'total': 1, 'successful': 1, 'failed': 0}, '_seq_no': 195, '_primary_term': 1}
# Job uploaded successfully: {'_index': 'software_jobs', '_id': 'k2-egI0BYlVpQ6ja3Tk6', '_version': 1, 'result': 'created', '_shards': {'total': 1, 'successful': 1, 'failed': 0}, '_seq_no': 196, '_primary_term': 1}
# Job uploaded successfully: {'_index': 'software_jobs', '_id': 'lG-egI0BYlVpQ6ja3Tk_', '_version': 1, 'result': 'created', '_shards': {'total': 1, 'successful': 1, 'failed': 0}, '_seq_no': 197, '_primary_term': 1}
# Job uploaded successfully: {'_index': 'software_jobs', '_id': 'lW-egI0BYlVpQ6ja3TlF', '_version': 1, 'result': 'created', '_shards': {'total': 1, 'successful': 1, 'failed': 0}, '_seq_no': 198, '_primary_term': 1}
# Job uploaded successfully: {'_index': 'software_jobs', '_id': 'lm-egI0BYlVpQ6ja3TlM', '_version': 1, 'result': 'created', '_shards': {'total': 1, 'successful': 1, 'failed': 0}, '_seq_no': 199, '_primary_term': 1}
# Job uploaded successfully: {'_index': 'software_jobs', '_id': 'l2-egI0BYlVpQ6ja3TlR', '_version': 1, 'result': 'created', '_shards': {'total': 1, 'successful': 1, 'failed': 0}, '_seq_no': 200, '_primary_term': 1}
# Job uploaded successfully: {'_index': 'software_jobs', '_id': 'mG-egI0BYlVpQ6ja3TlX', '_version': 1, 'result': 'created', '_shards': {'total': 1, 'successful': 1, 'failed': 0}, '_seq_no': 201, '_primary_term': 1}
# Job uploaded successfully: {'_index': 'software_jobs', '_id': 'mW-egI0BYlVpQ6ja3Tle', '_version': 1, 'result': 'created', '_shards': {'total': 1, 'successful': 1, 'failed': 0}, '_seq_no': 202, '_primary_term': 1}
# Job uploaded successfully: {'_index': 'software_jobs', '_id': 'mm-egI0BYlVpQ6ja3Tlj', '_version': 1, 'result': 'created', '_shards': {'total': 1, 'successful': 1, 'failed': 0}, '_seq_no': 203, '_primary_term': 1}
# Job uploaded successfully: {'_index': 'software_jobs', '_id': 'm2-egI0BYlVpQ6ja3Tln', '_version': 1, 'result': 'created', '_shards': {'total': 1, 'successful': 1, 'failed': 0}, '_seq_no': 204, '_primary_term': 1}
# Job uploaded successfully: {'_index': 'software_jobs', '_id': 'nG-egI0BYlVpQ6ja3Tlt', '_version': 1, 'result': 'created', '_shards': {'total': 1, 'successful': 1, 'failed': 0}, '_seq_no': 205, '_primary_term': 1}
# Job uploaded successfully: {'_index': 'software_jobs', '_id': 'nW-egI0BYlVpQ6ja3Tly', '_version': 1, 'result': 'created', '_shards': {'total': 1, 'successful': 1, 'failed': 0}, '_seq_no': 206, '_primary_term': 1}
# Job uploaded successfully: {'_index': 'software_jobs', '_id': 'nm-egI0BYlVpQ6ja3Tl3', '_version': 1, 'result': 'created', '_shards': {'total': 1, 'successful': 1, 'failed': 0}, '_seq_no': 207, '_primary_term': 1}
# Job uploaded successfully: {'_index': 'software_jobs', '_id': 'n2-egI0BYlVpQ6ja3Tl9', '_version': 1, 'result': 'created', '_shards': {'total': 1, 'successful': 1, 'failed': 0}, '_seq_no': 208, '_primary_term': 1}
# Job uploaded successfully: {'_index': 'software_jobs', '_id': 'oG-egI0BYlVpQ6ja3TmD', '_version': 1, 'result': 'created', '_shards': {'total': 1, 'successful': 1, 'failed': 0}, '_seq_no': 209, '_primary_term': 1}
# Job uploaded successfully: {'_index': 'software_jobs', '_id': 'oW-egI0BYlVpQ6ja3TmJ', '_version': 1, 'result': 'created', '_shards': {'total': 1, 'successful': 1, 'failed': 0}, '_seq_no': 210, '_primary_term': 1}
# Job uploaded successfully: {'_index': 'software_jobs', '_id': 'om-egI0BYlVpQ6ja3TmO', '_version': 1, 'result': 'created', '_shards': {'total': 1, 'successful': 1, 'failed': 0}, '_seq_no': 211, '_primary_term': 1}
# Job uploaded successfully: {'_index': 'software_jobs', '_id': 'o2-egI0BYlVpQ6ja3TmT', '_version': 1, 'result': 'created', '_shards': {'total': 1, 'successful': 1, 'failed': 0}, '_seq_no': 212, '_primary_term': 1}
# Job uploaded successfully: {'_index': 'software_jobs', '_id': 'pG-egI0BYlVpQ6ja3TmX', '_version': 1, 'result': 'created', '_shards': {'total': 1, 'successful': 1, 'failed': 0}, '_seq_no': 213, '_primary_term': 1}
# Job uploaded successfully: {'_index': 'software_jobs', '_id': 'pW-egI0BYlVpQ6ja3Tmd', '_version': 1, 'result': 'created', '_shards': {'total': 1, 'successful': 1, 'failed': 0}, '_seq_no': 214, '_primary_term': 1}
# Job uploaded successfully: {'_index': 'software_jobs', '_id': 'pm-egI0BYlVpQ6ja3Tmi', '_version': 1, 'result': 'created', '_shards': {'total': 1, 'successful': 1, 'failed': 0}, '_seq_no': 215, '_primary_term': 1}
# Job uploaded successfully: {'_index': 'software_jobs', '_id': 'p2-egI0BYlVpQ6ja3Tmo', '_version': 1, 'result': 'created', '_shards': {'total': 1, 'successful': 1, 'failed': 0}, '_seq_no': 216, '_primary_term': 1}
# Job uploaded successfully: {'_index': 'software_jobs', '_id': 'qG-egI0BYlVpQ6ja3Tmt', '_version': 1, 'result': 'created', '_shards': {'total': 1, 'successful': 1, 'failed': 0}, '_seq_no': 217, '_primary_term': 1}
# Job uploaded successfully: {'_index': 'software_jobs', '_id': 'qW-egI0BYlVpQ6ja3Tmz', '_version': 1, 'result': 'created', '_shards': {'total': 1, 'successful': 1, 'failed': 0}, '_seq_no': 218, '_primary_term': 1}
# Job uploaded successfully: {'_index': 'software_jobs', '_id': 'qm-egI0BYlVpQ6ja3Tm5', '_version': 1, 'result': 'created', '_shards': {'total': 1, 'successful': 1, 'failed': 0}, '_seq_no': 219, '_primary_term': 1}
# Job uploaded successfully: {'_index': 'software_jobs', '_id': 'q2-egI0BYlVpQ6ja3Tm_', '_version': 1, 'result': 'created', '_shards': {'total': 1, 'successful': 1, 'failed': 0}, '_seq_no': 220, '_primary_term': 1}
# Job uploaded successfully: {'_index': 'software_jobs', '_id': 'rG-egI0BYlVpQ6ja3TnG', '_version': 1, 'result': 'created', '_shards': {'total': 1, 'successful': 1, 'failed': 0}, '_seq_no': 221, '_primary_term': 1}
# Job uploaded successfully: {'_index': 'software_jobs', '_id': 'rW-egI0BYlVpQ6ja3TnN', '_version': 1, 'result': 'created', '_shards': {'total': 1, 'successful': 1, 'failed': 0}, '_seq_no': 222, '_primary_term': 1}

# %% [markdown]
# Retrieve all data from the index

# %%
elasticsearch_url = "http://localhost:9200"
index_name = "software_jobs"
# Define the search query to match all documents
query = {
    "query": {
        "match_all": {}
    }
}

# Send the search request
response = requests.get(
    f"{elasticsearch_url}/{index_name}/_search",
    json=query,
    auth=(username, password)  # Include authentication parameters
)

# Check the response
if response.status_code == 200:
    data = response.json()
    hits = data.get("hits", {}).get("hits", [])

    if hits:
        for hit in hits:
            print(f"Document ID: {hit['_id']}")
            print(f"Document Content: {hit['_source']}")
    else:
        print("No documents found in the index.")
else:
    print(f"Error fetching data: {response.content}")
# Out:
# Document ID: z2-egI0BYlVpQ6ja1zhs
# Document Content: {'job_id': '...', 'title': 'Remote ServiceNow Administration with Python, R, Advanced SQL...', 'company_name': 'Cube Hub Inc.', 'location': '  Irvine, Californie   ', 'via': 'via SaluteMyJob', 'description': "Position Description: ServiceNow Developer for Asset Management team\n\nhis team is working a hybrid schedule, but fully remote candidates will be considered as well...\n• Recent college graduates are not a good fit for this position.\n• Demonstrated knowledge in various programming languages (Python, R, Advanced SQL, etc.) MUST HAVE\n• 3+ Years experience of ServiceNow Administration MUST HAVE\n• Understanding of ServiceNow development environment, database, data management and infrastructure capabilities and constraints MUST HAVE\n• Business process knowledge of Hardware Asset Management (HAM), Software Asset Management (SAM), and procurement Preferred but not required\n• Ability to analyze, translate, and define business requirements into technical solutions, including advanced problem-solving ability - Preferred but not required\n• Excellence in verbal and written communication forms with emphasis on persuasive communication, tact and negotiation - Preferred but not required\nWhat Makes You Stand Out (Desired Skills/experiences)\n\nExperience with the following technologies:\n• Web technologies HTML, XML, or CSS\n• API integrations with other systems\n• Configuration of ServiceNow's ITSM service catalog\n• UI and SQL\n• Ability to manage many competing priorities/requests in a fast-paced environment.\n• ServiceNow Administration certification\n• Expert ITIL process knowledge\n• ITSM ServiceNow knowledge\n• Candidates who are selected for interviews will be required to complete a Glider assessment***\nResponsibilities\n• Builds the work needed to implement functionality from the product backlog (managed by the product owner).\n• Analyzes assignments and determines software specifications that must be fulfilled to achieve objectives and get appropriate value from packaged solutions.\n• Tests deliverables against a user story's acceptance tests.\n• Completes system configuration settings to enable software functionality that supports business processes.\n• Unit-tests software, creates automated test scripts and executes all other testing-related tasks.\n• Works closely with other team members to ensure that features meet business needs; Works collaboratively with infrastructure, security and other partners", 'skills': {'Coding': ['Python', 'CSS', 'SQL', 'R', 'HTML'], 'WebD': ['Python', 'CSS', 'HTML'], 'DevOps': ['UI'], 'Business': ['ITIL']}}
# Document ID: 0G-egI0BYlVpQ6ja1zil
# Document Content: {'job_id': '...', 'title': 'Lead Automated Python Tester', 'company_name': 'Lumen', 'location': '  États-Unis   ', 'via': 'via Lumen Jobs', 'description': "About Lumen\nLumen is guided by our belief that humanity is at its best when technology advances the way we live and work. With 450,000 route fiber miles serving customers in more than 60 countries, we deliver the fastest, most secure global platform for applications and data to help businesses, government and communities deliver amazing experiences. Learn more about Lumen’s network, edge cloud... security and communication and collaboration solutions and our purpose to further human progress through technology at news.lumen.com, LinkedIn: /lumentechnologies, Twitter: @lumentechco, Facebook: /lumentechnologies, Instagram: @lumentechnologies and YouTube: /lumentechnologies.\nThe Role\n\nProvides expert technical direction at a project level. This role will be responsible for planning, developing, and executing tests for complex systems and equipment. The individual will collaborate with various teams across IT to identify the impacts of test requirements and improve the overall quality of the final deliverables. As a technical expert, this person will possess strong communication skills and will be expected to partner with business and technical groups in order to anticipate the effects of testing and bring timely resolution to critical issues. Within their area of expertise, this person will provide specialized advice and direction. They will contribute towards the team’s continual process improvement, and will also provide industry knowledge regarding test strategy development, test R&D activities, and technical support when applicable.\n\nThe Main Responsibilities\n• Perform comprehensive QA planning and coordination\n• Perform manual testing of web, mobile & desktop applications\n• Write automated tests for web and mobile apps using various open-source test frameworks\n• Assist sales and account management on product questions and issues\n• Serve as the user advocate within the engineering team\n• Implement QA metrics, including benchmarking and identification of areas for improving overall performance\n• Identify and lead process improvements in QA and agile execution\n\nWhat We Look For in a Candidate\n• Consulting Level Bachelor's degree. Typically with 8+ years of experience.\n• 6+ years of experience QA Testing (Python). Masters Degree preferred.\n• Collect the release features & update test cases in automation to support Deployments.\n• Update Test automation to support CI/CD deployements.\n• Pre & Post Deployement validations on Apps.\n\nCompensation\n\nThe starting salary for this role differs based on the employee's primary work location. Employees typically do not start at the top of the range, though compensation depends on each individual's qualifications.\n\nLocation Based Pay Ranges\n\n$94420 - $118028 in these states: AR, ID, KY, LA, ME, MS, NE, SC, and SD.\n$99390 - $124230 in these states: AZ, FL, GA, IN, IA, KS, MO, MT, NM, ND, OH, OK, PA, TN, UT, VT, WV, WI, and WY.\n$104360 - $130448 in these states: CO, HI, MI, MN, NV, NH, NC, OR, and RI.\n$109330 - $136665 in these states: AK, CA, CT, DE, DC, IL, MD, MA, NJ, NY, TX, VA, and WA.\n\nAs with the pay range variety that's based on the region of a country, specific offers are determined by various factors such as experience, education, skills, certifications and other business needs.\n\nWhat to Expect Next\n\nRequisition #: 331220\n\nWhen applying for a position, you may be subject to a background screen (criminal records check, motor vehicle report, and/or drug screen), depending on the requirements for the position. More information on what’s included in these checks can be found in the Post Offer section of our FAQ page. Job-related concerns noted in the background screen may disqualify you from the new position or your current role. Background results will be evaluated on a case-by-c ...
# Document ID: 0W-egI0BYlVpQ6ja1zit
# Document Content: {'job_id': '', 'title': 'Python Developer', 'company_name': 'Neotech Solutions', 'location': '  San José, Californie   ', 'via': 'via Indeed', 'description': 'Job Role: Python Developer\n\nLocation: San Jose, CA (onsite only...\n\nClient: TechM/ ASML\n\nDuration: Contract\n\nJob Description:\n\nClient requirements are:\n• Skillful in Python/Perl scripting\n• Strong Experience with Unix/Linux and shell scripting\n• Experience on Python-based Robot framework is a plus\n• Very good communication and learning capability.\n• 3+ years of software test experiences\n• Proficient with the tooling: Git, Bamboo, JIRA, Test management tools like qTest,.\n• Proficient with Restful API testing\n• Proficient with robot test framework and python programming\n• Familiar with Linux terminal, docker and Kubernetes usage.\n• Experiences of developing/maintaining regression tests\n• Semiconductor Experience is +..\n\nThe following skills are mandatory:\n• SQL\n• LINUX\n• SDET\n• PYTHON\n• ROBOTICS\n• JIRA\n\nMamatha K | US IT Recruiter\nD: (908) 864-9004 |\nMamatha@neotechusa.com\nOne Cragwood Rd | South Plainfield, NJ 07080\neFax: 888-828-9871|\nwww.neotechusa.com\n\nJob Type: Contract\n\nSalary: $48.00 - $53.00 per hour\n\nSchedule:\n• 8 hour shift\n• Monday to Friday\n\nWork Location: In person', 'skills': {'Coding': ['Python', 'SQL', 'Perl'], 'WebD': ['Python']}}
# Document ID: 0m-egI0BYlVpQ6ja1zi2
# Document Content: {'job_id': '...', 'title': 'Python Engineer– (Manufacturing Software Tools) || San Jose, CA...', 'company_name': 'Zodiac Solutions, Inc', 'location': '  San José, Californie   ', 'via': 'via LinkedIn', 'description': 'Hello,\n\ni Hope you are doing great, my name is Prashant, I am a recruitment specialist at Zodiac solutions. Our client is looking for an Application Engineer(Python), might be this position can good next step towards your carrier, if you are looking for change or interested in this JOB role, please share me your updated resume so I can check your core strength, and we can discuss it further... Please find the Job description Below.\n\nImportant: Please make sure candidate has several iteration of Software development life cycle (SDLC) experience and he/she is well versed with Agile methodology, preferably have Manufacturing App experience..\n\nRole: Application Engineer(Python) – (Manufacturing Software Tools)\n\nLocation: San Jose, CA (Local, Onsite)\n\nDuration: Long-Term\n\nHire Mode: Contract\n\nA Google Cloud Project application that provides traditional application/ETL/relational database and data warehousing.\n\nShould have several iteration of Software development life cycle (SDLC) experience\n\nwell versed Experience working with Agile methodology, preferably have Manufacturing App experience..\n\nQualifications:\n• 8 years’ experience developing with any object-oriented language: e.g., Python, Java, or C++.\n• 3 years’ experience specifically developing in Python.\n• 3 years’ experience in relational or NoSQL database solutions and Web Frameworks such as Flask or Django.\n\nPreferred Qualifications:\n• Experience working in large, structured software development teams\n• Experience working across multiple distinct systems\n• Our Technologies:\n• Google Cloud Project: Spanner, Big Query, Relational Databases Python 3.9+\n• Git\n• Manufacturing Shop Floor Control Systems\n\nIf you are qualified, available, interested, planning to make a change, please feel free to reach me.\n\nThanks & Regards\n\nPrashant Bhardwaj\n\nSenior US IT Recruiter\n\nZodiac Solutions Inc.\n\n2625 N Josey Ln STE 320, Carrollton, TX 75007\n\nwww.zodiac-solutions.com\n\nEmail: prashant.bhardwaj@zodiac-solutions.com\n\nOffice: 484-953-8110', 'skills': {'WebD': ['Python', 'client', 'Django'], 'DevOps': ['Databases', 'NoSQL', 'Software development'], 'Business': ['SDLC'], 'Analytics': ['ETL'], 'Coding': ['Python', 'C++', 'Java'], 'ML/AI': ['Django', 'Flask']}}
# Document ID: 02-egI0BYlVpQ6ja1zjT
# Document Content: {'job_id': '...', 'title': 'GCP  Lead with Strong Python & SQL coding experience', 'company_name': 'ClifyX', 'location': '  Boston, Massachusetts   ', 'via': 'via SaluteMyJob', 'description': '1252334\nGCP(GCS, BigQuery, BQ SQL, Python, Data Fusion,Cloud Composer) Lead with Strong Python & SQL coding experience)\nBoston,Massachusetts...\nVeolia North America, LLC\nPay rate $90/hr\n\n" Possess In depth knowledge and hands on development experience building end to end data pipeline on GCP including ingestion, processing, and storage of datasets.\nStrong Python & SQL coding experience [Must].\nStrong programming foundation in Python, including debugging and performance analysis.\nGood exposure to GCP data services like GCS, BigQuery, BQ SQL, Python, Data Fusion,Cloud Composer\nDeveloping re-usable code and libraries for future use\nOutstanding analytical and critical thinking skills.\nWell-established experience in all phases of development requirement gathering, system design, implementation, testing, deployment and maintenance, of enterprise-wide application systems.\nKnowledge in AWS (S3, Redshift', 'skills': {'Coding': ['Python', 'SQL'], 'WebD': ['Python'], 'DevOps': ['AWS']}}
# Document ID: 1G-egI0BYlVpQ6ja1zjb
# Document Content: {'job_id': '...', 'title': 'Python Developer', 'company_name': 'Connective Talent', 'location': '  Houston, Texas   ', 'via': 'via LinkedIn', 'description': "• *Join Our Client as a Python Developer in Houston, TX!**\n\nLooking for an exciting Python Developer role in Houston, TX? You're in the right place! Enjoy an on-site position with amazing perks like an 11% annual 401K contribution, catered food, and top-notch healthcare benefits...\n\nRole Highlights:\n\n- Contribute to the development of a cutting-edge data management platform.\n\n- Collaborate with a talented Python developer team to build a robust data processing pipeline.\n\nKey Responsibilities:\n\n- Data Integration: Manage diverse data feeds, move them to the cloud, and distribute globally to support business operations.\n\n- Data Acquisition: Collect data from over 1,000 sources daily, including web scraping and handling various data formats.\n\n- Web Scraping: Efficiently download data into databases through web scraping and propose scraping solutions.\n\n- Python Development: Join a dynamic Python developer team, creating Python-based data processing solutions.\n\n- Solution Development: Collaborate on Python enterprise solutions, including libraries and modules for data processing.\n\nQualifications:\n\n- Python developer with 3-5 years of data-focused Python development experience.\n\n- Proficiency in data manipulation and scripting, with the ability to work independently or as part of a team.\n\n- Experience with ETL processes and data integration.\n\n- Familiarity with enterprise-level Python solutions and libraries.\n\nReady to make a mark in data management? Apply today and be part of our exciting team!\n\nhas context menuComposeParagraph", 'skills': {'Coding': ['Python'], 'WebD': ['Python'], 'Analytics': ['ETL']}}
# Document ID: 1W-egI0BYlVpQ6ja1zjk
# Document Content: {'job_id': '...', 'title': 'Software Engineer - C++ and Python', 'company_name': 'Global Technology Associates, Ltd.', 'location': '  Ann Arbor, Michigan   ', 'via': 'via ZipRecruiter', 'description': "Software engineer for Automated Driving Systems Engineer - C++ and Python\n\nHybrid Schedule. Must be local to work on site in Ann Arbor, MI, as needed. Average days on site estimated: 6-12 days/month...\n\nJob ID: 1266679 - Location: Ann Arbor, MI 48105\n\nPay Rate: Very Competitive w/OT paid over 40 hours in a week, with benefits options: Health, Dental, Vision, 401(k), company paid holidays\nType of hire: Contract, long-term with ongoing potential. No travel anticipated.\n\nPosition Summary:\n\nIntegrated Vehicle Systems Department is looking for a passionate and highly motivated Software Engineer. The primary responsibility of this role is to develop advanced driver system and software in C/C++ and support overall software quality auditing.\n\nIVS department's objective to design and evaluate the next generation of automated driving systems for the company’s vehicles.\n\nPosition Responsibilities:\n• Design ADS systems and software logic in C/C++\n• Complete logic development by making design requirements, confirming/testing logic, and ensuring quality and all safety concepts into software design.\n• Utilize and create support tools with Python code\n• Position Requirements:The schedule will be a hybrid schedule working at least 6 days a month from the office, however there may be times where this candidate will need to report to the office more frequently therefore this candidate must be flexible.\n• B.S. in Computer Science, related fields, or commensurate work experience.\n• Experience as a production software engineer (3 years).\n• Experience building, implementing, and supporting medium to large scale solutions in C/C++ and Python\n• Experience using GIT., Experience performing performance analysis, troubleshooting, and remediation in a software and integration environment (3 year).\n• Self-starter with the ability to work independently or as part of a project team with limited supervision.\n\nWhat you may bring:\n• C/C++ or Python Certification (foundational, associate, professional, or specialty).\n• A valid US drivers’ license.\n• Experience with dynamics-based vehicle simulation (1 year)\n• Experience developing software in a team setting, creating pull requests, conducting peer reviews.\n• Experience using ROS1 or ROS2\n• Familiarity with Docker\n• Experience developing code on Linux platforms, writing shell scripts.\n• Web development experience (html, JavaScript, CSS)\n• Experience using plotting tools like plot.ly, bokeh, matplotlib.\n• Experience using cloud services (AWS, Azure)\n• Time-series database experience\n\nCompany DescriptionGlobal Technology Associates, LTD can take your career search or hiring needs to the next level. As a premier technical and professional staffing company, with over 30 years of industry experience, we have longstanding connections in industries like automotive, aeronautics, information technology, defense, and healthcare. GTA can provide you with a full breadth of diverse candidates from our talent network. GTA is a national full-service provider of direct and contract professionals and top management talent", 'skills': {'Coding': ['Python', 'CSS', 'C++', 'JavaScript', 'C'], 'WebD': ['Python', 'CSS'], 'DevOps': ['Docker', 'AWS'], 'ML/AI': ['matplotlib']}}
# Document ID: 1m-egI0BYlVpQ6ja1zjs
# Document Content: {'job_id': '...', 'title': 'SAS Developer (With Python) @ Reston, VA (Remote, but once in a...', 'company_name': 'Smart IT Frame LLC', 'location': '  Boston, Massachusetts   ', 'via': 'via SaluteMyJob', 'description': 'Role : SAS Developer (With Python)\n\nMode of Hire : Fulltime / Contract...\n\nLocation : Reston, VA (Remote, but once in a month on-site required)\n\nJob Description:\n\nPrimary Skills - Python, Unix, AWS, SAS\n• 8 years of experience in SAS Development.\n• Experience in Base SAS, Advance SAS programming, SAS Macros and SQL and optimization techniques.\n• SAS knowledge to read and understand packages\n• Experience with Pandas, Numpy packages in Python programming\n• Experience with AWS cloud implementation\n• Experience with following AWS services preferred (Step Functions, Lambda, SNS, SQS, S3, EMR, Redshift)\n• Familiar with Release (promote) process, Batch Support (Daily, Weekly, Monthly) and strong SQL/SAS debugging skills\n• Knowledge in Shell scripting good to have.\n\nRegards,\n\nSanjeev\n\nsanjeev', 'skills': {'Coding': ['Python', 'SQL'], 'WebD': ['Python'], 'DevOps': ['AWS']}}
# Document ID: 12-egI0BYlVpQ6ja1zjz
# Document Content: {'job_id': '...', 'title': 'Java Tech Lead (Spark and Python expertise)', 'company_name': 'V-Solve', 'location': '  Dallas, Texas   ', 'via': 'via SaluteMyJob', 'description': 'Job Description:\n\nTech Lead (Spark and Python expertise...\n\nJob description:\n\nMandatory:\n\n10+ years of experience in solution, design and development of applications using Java 8+/J2EE, Spring, Spring-Boot, Micro Services, RESTful Services and with experience in Big Data and with experience working in heavy data background needed.\n\nDevelop, program, and maintain applications using the Apache Spark open-source framework.\n\nWork with different aspects of the Spark ecosystem, including Spark SQL, DataFrames, Datasets, and streaming.\n\nSpark Developer must have strong programming skills in Java, Scala, or Python.\n\nFamiliar with big data processing tools and techniques.\n\nProven experience as a Spark Developer or a related role.\n\nStrong programming skills in Java, Scala, or Python.\n\nFamiliarity with big data processing tools and techniques.\n\nExperience with the Hadoop ecosystem.\n\nGood understanding of distributed systems.\n\nExperience with streaming data platforms.\n\nMust have strong experience in Big Data and with experience working in heavy data background needed.\n\nMust be strong in Cloud AWS event-based architecture, Kubernetes, ELK (Elasticsearch, Logstash & Kibana).\n\nMust have excellent experience in designing and Implementing cloud-based solutions in various AWS Services (: s3, Lambda, Step Function, AMQ, SNS, SQS, CloudWatch Events, etc.)\n\nMust be well experienced in design and development of Microservice using Spring-Boot and REST API and with GraphQL.\n\nMust have solid knowledge and experience in NoSQL (MongoDB).\n\nGood knowledge and experience in any Queue based implementations.\n\nStrong knowledge/experience in ORM Framework - JPA / Hibernate.\n\nGood knowledge in technical concepts - Security, Transaction, Monitoring, Performance.\n\nShould we well versed with TDD/ATDD.\n\nShould have experience on Java, Python and Spark.\n\n2+ years of experience in designing and Implementing cloud-based solutions in various AWS Services.\n\nStrong experience in DevOps tool chain (Jenkins, Artifactory, Ansible/Chef/Puppet/Spinnaker, Maven/Gradle, Atlassian Tool suite).\n\nVery Good knowledge and experience in Non-Functional (Technical) Requirements like Security, Transaction, Performance, etc.\n\nExcellent analytical and problem-solving skills.\n\nNice to have:\n\nExperience in Experience with OAuth implementation using Ping Identity\n\nExperience in API Management (Apigee) or Service Mesh (Istio)\n\nGood knowledge and experience in Queue/Topic (Active-MQ) based implementations\n\nGood knowledge and experience in Scheduler and Batch Jobs\n\nExperience with scripting languages using Unix\n\nPreferably certified in AWS', 'skills': {'DevOps': ['NoSQL', 'MongoDB', 'Spark', 'Hadoop', 'AWS', 'DevOps'], 'Coding': ['Python', 'SQL', 'Scala', 'Java'], 'WebD': ['Python']}}
# Document ID: 2G-egI0BYlVpQ6ja1zj6
# Document Content: {'job_id': '...', 'title': 'Sr Python Developer / Senior Python Full Stack Developer', 'company_name': 'Makro Technologies Inc', 'location': '  Princeton, New Jersey   ', 'via': 'via ZipRecruiter', 'description': "Description:\n\nJob Description and nbsp...\n• Develop, test, and debug software applications using Python. and nbsp;\n• and nbsp;Write scalable and reusable code that adheres to best practices. and nbsp;\n• Strong knowledge with utilizing libraries such as Pandas, NumPy, and ORM's like SQL Alchemy.\n• Work with Object-Oriented Programming principles. and nbsp;\n• Proficiently use SQL and interact with RDBMS systems like SQL Server. and nbsp;\n• Collaborate with teams using Git and JIRA for version control and project management. and nbsp;\n• Take full ownership of tasks, work independently, and meet project deadlines. and nbsp;\n• Foster effective teamwork and communication within the development team. and nbsp;\n• API development using RESTful or GraphQL standards. and nbsp;\n• Develop Data Interfaces using Python, Data Frames, Pandas etc. and nbsp;\n• Integration with back-end technologies and frameworks, such as Node.js, .NET, or Java. and nbsp;\n• Build Data Access Layer and metadata-driven data query tool. and nbsp;\n• Write clean, reusable, and well-documented code that follows best practices and coding standards. and nbsp;\n• Collaborate with back-end developers to integrate UI components with server-side systems and APIs. Ensure efficient data retrieval and synchronization, handle data validation and error handling, and optimize API performance. and nbsp;\n• Work in an iterative/Agile environment as a good team player. and nbsp;\n• Ability to manage multiple tasks and projects simultaneously.\n• Work with the latest CI/CD DevOps deployment model\u200b\n\nRequirements and nbsp;\n• 7+ years of experience in Python programming and nbsp;\n• Strong knowledge of Python libraries like Pandas and NumPy and nbsp;\n• Experience in frameworks like Django, Flask, or any other web frameworks and nbsp;\n• Experience in UI library or Framework such as React, Angular or Vue (Preferred React) and nbsp;\n• Proficient with Data structures and Collections and nbsp;\n• Experience in Relational (MySQL, Postgres) and No SQL (Cassandra, Mongo) database technologies and nbsp;\n• Experience in designing and developing distributed and amp; scalable systems using OOPS and/or Functional programming and nbsp;\n• Experience in Distributed Computing and High Velocity data processing and nbsp;\n• Exposure to CI/CD tools like Jenkins, Maven, Git etc. and nbsp", 'skills': {'Coding': ['Python', 'SQL', 'Java', 'NumPy'], 'WebD': ['Python', 'Django', 'server'], 'DevOps': ['Node.js', 'DevOps', 'UI'], 'ML/AI': ['Django', 'Flask']}}

# %% [markdown]
# Eventually delete the index

# %%
response = requests.delete("http://localhost:9200/software_jobs", auth = (username, password))
response.text
# Out:
# '{"acknowledged":true}'
