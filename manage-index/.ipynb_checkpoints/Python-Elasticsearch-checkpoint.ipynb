# %% [markdown]
# Create the index

# %%
import requests

# Elasticsearch server details
base_url = "http://localhost:9200"
index_name = "software_jobs"
username = "elastic"
password = "<passwd>" 

# Index settings and mapping
index_settings = {
    "settings": {
        "number_of_shards": 1,
        "number_of_replicas": 0
    },
    "mappings": {
        "properties": {
            'job_id': {"type": "keyword"},
            'title': {"type": "keyword"},
            'company_name': {"type": "keyword"},
            'location': {"type": "keyword"},
            'via': {"type": "keyword"},
            'description': {"type": "keyword"},
        }
    }
}

# Create the index with authentication
response = requests.put(
    f"{base_url}/{index_name}",
    json=index_settings,
    auth=(username, password)  # Include authentication parameters
)

# Check the response
if response.status_code == 200:
    print(f"Index '{index_name}' created successfully.")
else:
    print(f"Error creating index: {response.content}")
# Out:
# Index 'software_jobs' created successfully.

# %% [markdown]
# Post the job offers to the index

# %%
import json
elasticsearch_url = "http://localhost:9200"
with open('jobs_jumble.json') as f:
    cleaned = json.load(f)
for c in cleaned:
        response = requests.post(
            f"{elasticsearch_url}/software_jobs/_doc",
            json=c,
            auth=(username, password)  # Include authentication parameters

        )

        if response.status_code == 201:
            print(f"Job uploaded successfully: {response.json()}")
        else:
            print(f"Error uploading job: {response.json()}")
# Out:
# Job uploaded successfully: {'_index': 'software_jobs', '_id': 'wNy6gYwBQYTzbOxES3w6', '_version': 1, 'result': 'created', '_shards': {'total': 1, 'successful': 1, 'failed': 0}, '_seq_no': 0, '_primary_term': 1}
# Job uploaded successfully: {'_index': 'software_jobs', '_id': 'wdy6gYwBQYTzbOxES3xW', '_version': 1, 'result': 'created', '_shards': {'total': 1, 'successful': 1, 'failed': 0}, '_seq_no': 1, '_primary_term': 1}
# Job uploaded successfully: {'_index': 'software_jobs', '_id': 'wty6gYwBQYTzbOxES3xf', '_version': 1, 'result': 'created', '_shards': {'total': 1, 'successful': 1, 'failed': 0}, '_seq_no': 2, '_primary_term': 1}
# Job uploaded successfully: {'_index': 'software_jobs', '_id': 'w9y6gYwBQYTzbOxES3xn', '_version': 1, 'result': 'created', '_shards': {'total': 1, 'successful': 1, 'failed': 0}, '_seq_no': 3, '_primary_term': 1}
# Job uploaded successfully: {'_index': 'software_jobs', '_id': 'xNy6gYwBQYTzbOxES3xu', '_version': 1, 'result': 'created', '_shards': {'total': 1, 'successful': 1, 'failed': 0}, '_seq_no': 4, '_primary_term': 1}
# Job uploaded successfully: {'_index': 'software_jobs', '_id': 'xdy6gYwBQYTzbOxES3x2', '_version': 1, 'result': 'created', '_shards': {'total': 1, 'successful': 1, 'failed': 0}, '_seq_no': 5, '_primary_term': 1}
# Job uploaded successfully: {'_index': 'software_jobs', '_id': 'xty6gYwBQYTzbOxES3x8', '_version': 1, 'result': 'created', '_shards': {'total': 1, 'successful': 1, 'failed': 0}, '_seq_no': 6, '_primary_term': 1}
# Job uploaded successfully: {'_index': 'software_jobs', '_id': 'x9y6gYwBQYTzbOxES3yD', '_version': 1, 'result': 'created', '_shards': {'total': 1, 'successful': 1, 'failed': 0}, '_seq_no': 7, '_primary_term': 1}
# Job uploaded successfully: {'_index': 'software_jobs', '_id': 'yNy6gYwBQYTzbOxES3yJ', '_version': 1, 'result': 'created', '_shards': {'total': 1, 'successful': 1, 'failed': 0}, '_seq_no': 8, '_primary_term': 1}
# Job uploaded successfully: {'_index': 'software_jobs', '_id': 'ydy6gYwBQYTzbOxES3yP', '_version': 1, 'result': 'created', '_shards': {'total': 1, 'successful': 1, 'failed': 0}, '_seq_no': 9, '_primary_term': 1}
# Job uploaded successfully: {'_index': 'software_jobs', '_id': 'yty6gYwBQYTzbOxES3yV', '_version': 1, 'result': 'created', '_shards': {'total': 1, 'successful': 1, 'failed': 0}, '_seq_no': 10, '_primary_term': 1}
# Job uploaded successfully: {'_index': 'software_jobs', '_id': 'y9y6gYwBQYTzbOxES3yd', '_version': 1, 'result': 'created', '_shards': {'total': 1, 'successful': 1, 'failed': 0}, '_seq_no': 11, '_primary_term': 1}
# Job uploaded successfully: {'_index': 'software_jobs', '_id': 'zNy6gYwBQYTzbOxES3yj', '_version': 1, 'result': 'created', '_shards': {'total': 1, 'successful': 1, 'failed': 0}, '_seq_no': 12, '_primary_term': 1}
# Job uploaded successfully: {'_index': 'software_jobs', '_id': 'zdy6gYwBQYTzbOxES3yp', '_version': 1, 'result': 'created', '_shards': {'total': 1, 'successful': 1, 'failed': 0}, '_seq_no': 13, '_primary_term': 1}
# Job uploaded successfully: {'_index': 'software_jobs', '_id': 'zty6gYwBQYTzbOxES3yx', '_version': 1, 'result': 'created', '_shards': {'total': 1, 'successful': 1, 'failed': 0}, '_seq_no': 14, '_primary_term': 1}
# Job uploaded successfully: {'_index': 'software_jobs', '_id': 'z9y6gYwBQYTzbOxES3y4', '_version': 1, 'result': 'created', '_shards': {'total': 1, 'successful': 1, 'failed': 0}, '_seq_no': 15, '_primary_term': 1}
# Job uploaded successfully: {'_index': 'software_jobs', '_id': '0Ny6gYwBQYTzbOxES3y-', '_version': 1, 'result': 'created', '_shards': {'total': 1, 'successful': 1, 'failed': 0}, '_seq_no': 16, '_primary_term': 1}
# Job uploaded successfully: {'_index': 'software_jobs', '_id': '0dy6gYwBQYTzbOxES3zG', '_version': 1, 'result': 'created', '_shards': {'total': 1, 'successful': 1, 'failed': 0}, '_seq_no': 17, '_primary_term': 1}
# Job uploaded successfully: {'_index': 'software_jobs', '_id': '0ty6gYwBQYTzbOxES3zL', '_version': 1, 'result': 'created', '_shards': {'total': 1, 'successful': 1, 'failed': 0}, '_seq_no': 18, '_primary_term': 1}
# Job uploaded successfully: {'_index': 'software_jobs', '_id': '09y6gYwBQYTzbOxES3zS', '_version': 1, 'result': 'created', '_shards': {'total': 1, 'successful': 1, 'failed': 0}, '_seq_no': 19, '_primary_term': 1}
# Job uploaded successfully: {'_index': 'software_jobs', '_id': '1Ny6gYwBQYTzbOxES3zY', '_version': 1, 'result': 'created', '_shards': {'total': 1, 'successful': 1, 'failed': 0}, '_seq_no': 20, '_primary_term': 1}
# Job uploaded successfully: {'_index': 'software_jobs', '_id': '1dy6gYwBQYTzbOxES3zi', '_version': 1, 'result': 'created', '_shards': {'total': 1, 'successful': 1, 'failed': 0}, '_seq_no': 21, '_primary_term': 1}
# Job uploaded successfully: {'_index': 'software_jobs', '_id': '1ty6gYwBQYTzbOxES3zp', '_version': 1, 'result': 'created', '_shards': {'total': 1, 'successful': 1, 'failed': 0}, '_seq_no': 22, '_primary_term': 1}
# Job uploaded successfully: {'_index': 'software_jobs', '_id': '19y6gYwBQYTzbOxES3zv', '_version': 1, 'result': 'created', '_shards': {'total': 1, 'successful': 1, 'failed': 0}, '_seq_no': 23, '_primary_term': 1}
# Job uploaded successfully: {'_index': 'software_jobs', '_id': '2Ny6gYwBQYTzbOxES3z1', '_version': 1, 'result': 'created', '_shards': {'total': 1, 'successful': 1, 'failed': 0}, '_seq_no': 24, '_primary_term': 1}
# Job uploaded successfully: {'_index': 'software_jobs', '_id': '2dy6gYwBQYTzbOxES3z9', '_version': 1, 'result': 'created', '_shards': {'total': 1, 'successful': 1, 'failed': 0}, '_seq_no': 25, '_primary_term': 1}
# Job uploaded successfully: {'_index': 'software_jobs', '_id': '2ty6gYwBQYTzbOxETHwD', '_version': 1, 'result': 'created', '_shards': {'total': 1, 'successful': 1, 'failed': 0}, '_seq_no': 26, '_primary_term': 1}
# Job uploaded successfully: {'_index': 'software_jobs', '_id': '29y6gYwBQYTzbOxETHwJ', '_version': 1, 'result': 'created', '_shards': {'total': 1, 'successful': 1, 'failed': 0}, '_seq_no': 27, '_primary_term': 1}
# Job uploaded successfully: {'_index': 'software_jobs', '_id': '3Ny6gYwBQYTzbOxETHwO', '_version': 1, 'result': 'created', '_shards': {'total': 1, 'successful': 1, 'failed': 0}, '_seq_no': 28, '_primary_term': 1}
# Job uploaded successfully: {'_index': 'software_jobs', '_id': '3dy6gYwBQYTzbOxETHwU', '_version': 1, 'result': 'created', '_shards': {'total': 1, 'successful': 1, 'failed': 0}, '_seq_no': 29, '_primary_term': 1}
# Job uploaded successfully: {'_index': 'software_jobs', '_id': '3ty6gYwBQYTzbOxETHwa', '_version': 1, 'result': 'created', '_shards': {'total': 1, 'successful': 1, 'failed': 0}, '_seq_no': 30, '_primary_term': 1}
# Job uploaded successfully: {'_index': 'software_jobs', '_id': '39y6gYwBQYTzbOxETHwg', '_version': 1, 'result': 'created', '_shards': {'total': 1, 'successful': 1, 'failed': 0}, '_seq_no': 31, '_primary_term': 1}
# Job uploaded successfully: {'_index': 'software_jobs', '_id': '4Ny6gYwBQYTzbOxETHwn', '_version': 1, 'result': 'created', '_shards': {'total': 1, 'successful': 1, 'failed': 0}, '_seq_no': 32, '_primary_term': 1}
# Job uploaded successfully: {'_index': 'software_jobs', '_id': '4dy6gYwBQYTzbOxETHwv', '_version': 1, 'result': 'created', '_shards': {'total': 1, 'successful': 1, 'failed': 0}, '_seq_no': 33, '_primary_term': 1}
# Job uploaded successfully: {'_index': 'software_jobs', '_id': '4ty6gYwBQYTzbOxETHw2', '_version': 1, 'result': 'created', '_shards': {'total': 1, 'successful': 1, 'failed': 0}, '_seq_no': 34, '_primary_term': 1}
# Job uploaded successfully: {'_index': 'software_jobs', '_id': '49y6gYwBQYTzbOxETHw7', '_version': 1, 'result': 'created', '_shards': {'total': 1, 'successful': 1, 'failed': 0}, '_seq_no': 35, '_primary_term': 1}
# Job uploaded successfully: {'_index': 'software_jobs', '_id': '5Ny6gYwBQYTzbOxETHxB', '_version': 1, 'result': 'created', '_shards': {'total': 1, 'successful': 1, 'failed': 0}, '_seq_no': 36, '_primary_term': 1}
# Job uploaded successfully: {'_index': 'software_jobs', '_id': '5dy6gYwBQYTzbOxETHxH', '_version': 1, 'result': 'created', '_shards': {'total': 1, 'successful': 1, 'failed': 0}, '_seq_no': 37, '_primary_term': 1}
# Job uploaded successfully: {'_index': 'software_jobs', '_id': '5ty6gYwBQYTzbOxETHxN', '_version': 1, 'result': 'created', '_shards': {'total': 1, 'successful': 1, 'failed': 0}, '_seq_no': 38, '_primary_term': 1}
# Job uploaded successfully: {'_index': 'software_jobs', '_id': '59y6gYwBQYTzbOxETHxU', '_version': 1, 'result': 'created', '_shards': {'total': 1, 'successful': 1, 'failed': 0}, '_seq_no': 39, '_primary_term': 1}
# Job uploaded successfully: {'_index': 'software_jobs', '_id': '6Ny6gYwBQYTzbOxETHxa', '_version': 1, 'result': 'created', '_shards': {'total': 1, 'successful': 1, 'failed': 0}, '_seq_no': 40, '_primary_term': 1}
# Job uploaded successfully: {'_index': 'software_jobs', '_id': '6dy6gYwBQYTzbOxETHxf', '_version': 1, 'result': 'created', '_shards': {'total': 1, 'successful': 1, 'failed': 0}, '_seq_no': 41, '_primary_term': 1}
# Job uploaded successfully: {'_index': 'software_jobs', '_id': '6ty6gYwBQYTzbOxETHxm', '_version': 1, 'result': 'created', '_shards': {'total': 1, 'successful': 1, 'failed': 0}, '_seq_no': 42, '_primary_term': 1}
# Job uploaded successfully: {'_index': 'software_jobs', '_id': '69y6gYwBQYTzbOxETHxt', '_version': 1, 'result': 'created', '_shards': {'total': 1, 'successful': 1, 'failed': 0}, '_seq_no': 43, '_primary_term': 1}
# Job uploaded successfully: {'_index': 'software_jobs', '_id': '7Ny6gYwBQYTzbOxETHx0', '_version': 1, 'result': 'created', '_shards': {'total': 1, 'successful': 1, 'failed': 0}, '_seq_no': 44, '_primary_term': 1}
# Job uploaded successfully: {'_index': 'software_jobs', '_id': '7dy6gYwBQYTzbOxETHx7', '_version': 1, 'result': 'created', '_shards': {'total': 1, 'successful': 1, 'failed': 0}, '_seq_no': 45, '_primary_term': 1}
# Job uploaded successfully: {'_index': 'software_jobs', '_id': '7ty6gYwBQYTzbOxETHyA', '_version': 1, 'result': 'created', '_shards': {'total': 1, 'successful': 1, 'failed': 0}, '_seq_no': 46, '_primary_term': 1}
# Job uploaded successfully: {'_index': 'software_jobs', '_id': '79y6gYwBQYTzbOxETHyG', '_version': 1, 'result': 'created', '_shards': {'total': 1, 'successful': 1, 'failed': 0}, '_seq_no': 47, '_primary_term': 1}
# Job uploaded successfully: {'_index': 'software_jobs', '_id': '8Ny6gYwBQYTzbOxETHyN', '_version': 1, 'result': 'created', '_shards': {'total': 1, 'successful': 1, 'failed': 0}, '_seq_no': 48, '_primary_term': 1}
# Job uploaded successfully: {'_index': 'software_jobs', '_id': '8dy6gYwBQYTzbOxETHyS', '_version': 1, 'result': 'created', '_shards': {'total': 1, 'successful': 1, 'failed': 0}, '_seq_no': 49, '_primary_term': 1}
# Job uploaded successfully: {'_index': 'software_jobs', '_id': '8ty6gYwBQYTzbOxETHyY', '_version': 1, 'result': 'created', '_shards': {'total': 1, 'successful': 1, 'failed': 0}, '_seq_no': 50, '_primary_term': 1}
# Job uploaded successfully: {'_index': 'software_jobs', '_id': '89y6gYwBQYTzbOxETHyf', '_version': 1, 'result': 'created', '_shards': {'total': 1, 'successful': 1, 'failed': 0}, '_seq_no': 51, '_primary_term': 1}
# Job uploaded successfully: {'_index': 'software_jobs', '_id': '9Ny6gYwBQYTzbOxETHyl', '_version': 1, 'result': 'created', '_shards': {'total': 1, 'successful': 1, 'failed': 0}, '_seq_no': 52, '_primary_term': 1}
# Job uploaded successfully: {'_index': 'software_jobs', '_id': '9dy6gYwBQYTzbOxETHyr', '_version': 1, 'result': 'created', '_shards': {'total': 1, 'successful': 1, 'failed': 0}, '_seq_no': 53, '_primary_term': 1}
# Job uploaded successfully: {'_index': 'software_jobs', '_id': '9ty6gYwBQYTzbOxETHyx', '_version': 1, 'result': 'created', '_shards': {'total': 1, 'successful': 1, 'failed': 0}, '_seq_no': 54, '_primary_term': 1}
# Job uploaded successfully: {'_index': 'software_jobs', '_id': '99y6gYwBQYTzbOxETHy4', '_version': 1, 'result': 'created', '_shards': {'total': 1, 'successful': 1, 'failed': 0}, '_seq_no': 55, '_primary_term': 1}
# Job uploaded successfully: {'_index': 'software_jobs', '_id': '-Ny6gYwBQYTzbOxETHy-', '_version': 1, 'result': 'created', '_shards': {'total': 1, 'successful': 1, 'failed': 0}, '_seq_no': 56, '_primary_term': 1}
# Job uploaded successfully: {'_index': 'software_jobs', '_id': '-dy6gYwBQYTzbOxETHzE', '_version': 1, 'result': 'created', '_shards': {'total': 1, 'successful': 1, 'failed': 0}, '_seq_no': 57, '_primary_term': 1}
# Job uploaded successfully: {'_index': 'software_jobs', '_id': '-ty6gYwBQYTzbOxETHzK', '_version': 1, 'result': 'created', '_shards': {'total': 1, 'successful': 1, 'failed': 0}, '_seq_no': 58, '_primary_term': 1}
# Job uploaded successfully: {'_index': 'software_jobs', '_id': '-9y6gYwBQYTzbOxETHzR', '_version': 1, 'result': 'created', '_shards': {'total': 1, 'successful': 1, 'failed': 0}, '_seq_no': 59, '_primary_term': 1}
# Job uploaded successfully: {'_index': 'software_jobs', '_id': '_Ny6gYwBQYTzbOxETHzY', '_version': 1, 'result': 'created', '_shards': {'total': 1, 'successful': 1, 'failed': 0}, '_seq_no': 60, '_primary_term': 1}
# Job uploaded successfully: {'_index': 'software_jobs', '_id': '_dy6gYwBQYTzbOxETHze', '_version': 1, 'result': 'created', '_shards': {'total': 1, 'successful': 1, 'failed': 0}, '_seq_no': 61, '_primary_term': 1}
# Job uploaded successfully: {'_index': 'software_jobs', '_id': '_ty6gYwBQYTzbOxETHzl', '_version': 1, 'result': 'created', '_shards': {'total': 1, 'successful': 1, 'failed': 0}, '_seq_no': 62, '_primary_term': 1}
# Job uploaded successfully: {'_index': 'software_jobs', '_id': '_9y6gYwBQYTzbOxETHzs', '_version': 1, 'result': 'created', '_shards': {'total': 1, 'successful': 1, 'failed': 0}, '_seq_no': 63, '_primary_term': 1}
# Job uploaded successfully: {'_index': 'software_jobs', '_id': 'ANy6gYwBQYTzbOxETH30', '_version': 1, 'result': 'created', '_shards': {'total': 1, 'successful': 1, 'failed': 0}, '_seq_no': 64, '_primary_term': 1}
# Job uploaded successfully: {'_index': 'software_jobs', '_id': 'Ady6gYwBQYTzbOxETH36', '_version': 1, 'result': 'created', '_shards': {'total': 1, 'successful': 1, 'failed': 0}, '_seq_no': 65, '_primary_term': 1}
# Job uploaded successfully: {'_index': 'software_jobs', '_id': 'Aty6gYwBQYTzbOxETX0B', '_version': 1, 'result': 'created', '_shards': {'total': 1, 'successful': 1, 'failed': 0}, '_seq_no': 66, '_primary_term': 1}
# Job uploaded successfully: {'_index': 'software_jobs', '_id': 'A9y6gYwBQYTzbOxETX0J', '_version': 1, 'result': 'created', '_shards': {'total': 1, 'successful': 1, 'failed': 0}, '_seq_no': 67, '_primary_term': 1}
# Job uploaded successfully: {'_index': 'software_jobs', '_id': 'BNy6gYwBQYTzbOxETX0T', '_version': 1, 'result': 'created', '_shards': {'total': 1, 'successful': 1, 'failed': 0}, '_seq_no': 68, '_primary_term': 1}
# Job uploaded successfully: {'_index': 'software_jobs', '_id': 'Bdy6gYwBQYTzbOxETX0d', '_version': 1, 'result': 'created', '_shards': {'total': 1, 'successful': 1, 'failed': 0}, '_seq_no': 69, '_primary_term': 1}
# Job uploaded successfully: {'_index': 'software_jobs', '_id': 'Bty6gYwBQYTzbOxETX0k', '_version': 1, 'result': 'created', '_shards': {'total': 1, 'successful': 1, 'failed': 0}, '_seq_no': 70, '_primary_term': 1}
# Job uploaded successfully: {'_index': 'software_jobs', '_id': 'B9y6gYwBQYTzbOxETX0r', '_version': 1, 'result': 'created', '_shards': {'total': 1, 'successful': 1, 'failed': 0}, '_seq_no': 71, '_primary_term': 1}
# Job uploaded successfully: {'_index': 'software_jobs', '_id': 'CNy6gYwBQYTzbOxETX0y', '_version': 1, 'result': 'created', '_shards': {'total': 1, 'successful': 1, 'failed': 0}, '_seq_no': 72, '_primary_term': 1}
# Job uploaded successfully: {'_index': 'software_jobs', '_id': 'Cdy6gYwBQYTzbOxETX04', '_version': 1, 'result': 'created', '_shards': {'total': 1, 'successful': 1, 'failed': 0}, '_seq_no': 73, '_primary_term': 1}
# Job uploaded successfully: {'_index': 'software_jobs', '_id': 'Cty6gYwBQYTzbOxETX0_', '_version': 1, 'result': 'created', '_shards': {'total': 1, 'successful': 1, 'failed': 0}, '_seq_no': 74, '_primary_term': 1}
# Job uploaded successfully: {'_index': 'software_jobs', '_id': 'C9y6gYwBQYTzbOxETX1G', '_version': 1, 'result': 'created', '_shards': {'total': 1, 'successful': 1, 'failed': 0}, '_seq_no': 75, '_primary_term': 1}
# Job uploaded successfully: {'_index': 'software_jobs', '_id': 'DNy6gYwBQYTzbOxETX1N', '_version': 1, 'result': 'created', '_shards': {'total': 1, 'successful': 1, 'failed': 0}, '_seq_no': 76, '_primary_term': 1}
# Job uploaded successfully: {'_index': 'software_jobs', '_id': 'Ddy6gYwBQYTzbOxETX1U', '_version': 1, 'result': 'created', '_shards': {'total': 1, 'successful': 1, 'failed': 0}, '_seq_no': 77, '_primary_term': 1}
# Job uploaded successfully: {'_index': 'software_jobs', '_id': 'Dty6gYwBQYTzbOxETX1a', '_version': 1, 'result': 'created', '_shards': {'total': 1, 'successful': 1, 'failed': 0}, '_seq_no': 78, '_primary_term': 1}
# Job uploaded successfully: {'_index': 'software_jobs', '_id': 'D9y6gYwBQYTzbOxETX1g', '_version': 1, 'result': 'created', '_shards': {'total': 1, 'successful': 1, 'failed': 0}, '_seq_no': 79, '_primary_term': 1}
# Job uploaded successfully: {'_index': 'software_jobs', '_id': 'ENy6gYwBQYTzbOxETX1n', '_version': 1, 'result': 'created', '_shards': {'total': 1, 'successful': 1, 'failed': 0}, '_seq_no': 80, '_primary_term': 1}
# Job uploaded successfully: {'_index': 'software_jobs', '_id': 'Edy6gYwBQYTzbOxETX1u', '_version': 1, 'result': 'created', '_shards': {'total': 1, 'successful': 1, 'failed': 0}, '_seq_no': 81, '_primary_term': 1}
# Job uploaded successfully: {'_index': 'software_jobs', '_id': 'Ety6gYwBQYTzbOxETX10', '_version': 1, 'result': 'created', '_shards': {'total': 1, 'successful': 1, 'failed': 0}, '_seq_no': 82, '_primary_term': 1}
# Job uploaded successfully: {'_index': 'software_jobs', '_id': 'E9y6gYwBQYTzbOxETX17', '_version': 1, 'result': 'created', '_shards': {'total': 1, 'successful': 1, 'failed': 0}, '_seq_no': 83, '_primary_term': 1}
# Job uploaded successfully: {'_index': 'software_jobs', '_id': 'FNy6gYwBQYTzbOxETX2C', '_version': 1, 'result': 'created', '_shards': {'total': 1, 'successful': 1, 'failed': 0}, '_seq_no': 84, '_primary_term': 1}
# Job uploaded successfully: {'_index': 'software_jobs', '_id': 'Fdy6gYwBQYTzbOxETX2I', '_version': 1, 'result': 'created', '_shards': {'total': 1, 'successful': 1, 'failed': 0}, '_seq_no': 85, '_primary_term': 1}
# Job uploaded successfully: {'_index': 'software_jobs', '_id': 'Fty6gYwBQYTzbOxETX2P', '_version': 1, 'result': 'created', '_shards': {'total': 1, 'successful': 1, 'failed': 0}, '_seq_no': 86, '_primary_term': 1}
# Job uploaded successfully: {'_index': 'software_jobs', '_id': 'F9y6gYwBQYTzbOxETX2V', '_version': 1, 'result': 'created', '_shards': {'total': 1, 'successful': 1, 'failed': 0}, '_seq_no': 87, '_primary_term': 1}
# Job uploaded successfully: {'_index': 'software_jobs', '_id': 'GNy6gYwBQYTzbOxETX2j', '_version': 1, 'result': 'created', '_shards': {'total': 1, 'successful': 1, 'failed': 0}, '_seq_no': 88, '_primary_term': 1}
# Job uploaded successfully: {'_index': 'software_jobs', '_id': 'Gdy6gYwBQYTzbOxETX2p', '_version': 1, 'result': 'created', '_shards': {'total': 1, 'successful': 1, 'failed': 0}, '_seq_no': 89, '_primary_term': 1}
# Job uploaded successfully: {'_index': 'software_jobs', '_id': 'Gty6gYwBQYTzbOxETX2v', '_version': 1, 'result': 'created', '_shards': {'total': 1, 'successful': 1, 'failed': 0}, '_seq_no': 90, '_primary_term': 1}
# Job uploaded successfully: {'_index': 'software_jobs', '_id': 'G9y6gYwBQYTzbOxETX22', '_version': 1, 'result': 'created', '_shards': {'total': 1, 'successful': 1, 'failed': 0}, '_seq_no': 91, '_primary_term': 1}
# Job uploaded successfully: {'_index': 'software_jobs', '_id': 'HNy6gYwBQYTzbOxETX29', '_version': 1, 'result': 'created', '_shards': {'total': 1, 'successful': 1, 'failed': 0}, '_seq_no': 92, '_primary_term': 1}
# Job uploaded successfully: {'_index': 'software_jobs', '_id': 'Hdy6gYwBQYTzbOxETX3G', '_version': 1, 'result': 'created', '_shards': {'total': 1, 'successful': 1, 'failed': 0}, '_seq_no': 93, '_primary_term': 1}
# Job uploaded successfully: {'_index': 'software_jobs', '_id': 'Hty6gYwBQYTzbOxETX3N', '_version': 1, 'result': 'created', '_shards': {'total': 1, 'successful': 1, 'failed': 0}, '_seq_no': 94, '_primary_term': 1}
# Job uploaded successfully: {'_index': 'software_jobs', '_id': 'H9y6gYwBQYTzbOxETX3U', '_version': 1, 'result': 'created', '_shards': {'total': 1, 'successful': 1, 'failed': 0}, '_seq_no': 95, '_primary_term': 1}
# Job uploaded successfully: {'_index': 'software_jobs', '_id': 'INy6gYwBQYTzbOxETX3a', '_version': 1, 'result': 'created', '_shards': {'total': 1, 'successful': 1, 'failed': 0}, '_seq_no': 96, '_primary_term': 1}
# Job uploaded successfully: {'_index': 'software_jobs', '_id': 'Idy6gYwBQYTzbOxETX3g', '_version': 1, 'result': 'created', '_shards': {'total': 1, 'successful': 1, 'failed': 0}, '_seq_no': 97, '_primary_term': 1}
# Job uploaded successfully: {'_index': 'software_jobs', '_id': 'Ity6gYwBQYTzbOxETX3m', '_version': 1, 'result': 'created', '_shards': {'total': 1, 'successful': 1, 'failed': 0}, '_seq_no': 98, '_primary_term': 1}
# Job uploaded successfully: {'_index': 'software_jobs', '_id': 'I9y6gYwBQYTzbOxETX3t', '_version': 1, 'result': 'created', '_shards': {'total': 1, 'successful': 1, 'failed': 0}, '_seq_no': 99, '_primary_term': 1}
# Job uploaded successfully: {'_index': 'software_jobs', '_id': 'JNy6gYwBQYTzbOxETX3z', '_version': 1, 'result': 'created', '_shards': {'total': 1, 'successful': 1, 'failed': 0}, '_seq_no': 100, '_primary_term': 1}
# Job uploaded successfully: {'_index': 'software_jobs', '_id': 'Jdy6gYwBQYTzbOxETX35', '_version': 1, 'result': 'created', '_shards': {'total': 1, 'successful': 1, 'failed': 0}, '_seq_no': 101, '_primary_term': 1}
# Job uploaded successfully: {'_index': 'software_jobs', '_id': 'Jty6gYwBQYTzbOxETX3_', '_version': 1, 'result': 'created', '_shards': {'total': 1, 'successful': 1, 'failed': 0}, '_seq_no': 102, '_primary_term': 1}
# Job uploaded successfully: {'_index': 'software_jobs', '_id': 'J9y6gYwBQYTzbOxETn0F', '_version': 1, 'result': 'created', '_shards': {'total': 1, 'successful': 1, 'failed': 0}, '_seq_no': 103, '_primary_term': 1}
# Job uploaded successfully: {'_index': 'software_jobs', '_id': 'KNy6gYwBQYTzbOxETn0R', '_version': 1, 'result': 'created', '_shards': {'total': 1, 'successful': 1, 'failed': 0}, '_seq_no': 104, '_primary_term': 1}
# Job uploaded successfully: {'_index': 'software_jobs', '_id': 'Kdy6gYwBQYTzbOxETn0W', '_version': 1, 'result': 'created', '_shards': {'total': 1, 'successful': 1, 'failed': 0}, '_seq_no': 105, '_primary_term': 1}
# Job uploaded successfully: {'_index': 'software_jobs', '_id': 'Kty6gYwBQYTzbOxETn0c', '_version': 1, 'result': 'created', '_shards': {'total': 1, 'successful': 1, 'failed': 0}, '_seq_no': 106, '_primary_term': 1}
# Job uploaded successfully: {'_index': 'software_jobs', '_id': 'K9y6gYwBQYTzbOxETn0i', '_version': 1, 'result': 'created', '_shards': {'total': 1, 'successful': 1, 'failed': 0}, '_seq_no': 107, '_primary_term': 1}
# Job uploaded successfully: {'_index': 'software_jobs', '_id': 'LNy6gYwBQYTzbOxETn0n', '_version': 1, 'result': 'created', '_shards': {'total': 1, 'successful': 1, 'failed': 0}, '_seq_no': 108, '_primary_term': 1}
# Job uploaded successfully: {'_index': 'software_jobs', '_id': 'Ldy6gYwBQYTzbOxETn0t', '_version': 1, 'result': 'created', '_shards': {'total': 1, 'successful': 1, 'failed': 0}, '_seq_no': 109, '_primary_term': 1}
# Job uploaded successfully: {'_index': 'software_jobs', '_id': 'Lty6gYwBQYTzbOxETn0z', '_version': 1, 'result': 'created', '_shards': {'total': 1, 'successful': 1, 'failed': 0}, '_seq_no': 110, '_primary_term': 1}
# Job uploaded successfully: {'_index': 'software_jobs', '_id': 'L9y6gYwBQYTzbOxETn05', '_version': 1, 'result': 'created', '_shards': {'total': 1, 'successful': 1, 'failed': 0}, '_seq_no': 111, '_primary_term': 1}
# Job uploaded successfully: {'_index': 'software_jobs', '_id': 'MNy6gYwBQYTzbOxETn0_', '_version': 1, 'result': 'created', '_shards': {'total': 1, 'successful': 1, 'failed': 0}, '_seq_no': 112, '_primary_term': 1}
# Job uploaded successfully: {'_index': 'software_jobs', '_id': 'Mdy6gYwBQYTzbOxETn1F', '_version': 1, 'result': 'created', '_shards': {'total': 1, 'successful': 1, 'failed': 0}, '_seq_no': 113, '_primary_term': 1}
# Job uploaded successfully: {'_index': 'software_jobs', '_id': 'Mty6gYwBQYTzbOxETn1L', '_version': 1, 'result': 'created', '_shards': {'total': 1, 'successful': 1, 'failed': 0}, '_seq_no': 114, '_primary_term': 1}
# Job uploaded successfully: {'_index': 'software_jobs', '_id': 'M9y6gYwBQYTzbOxETn1R', '_version': 1, 'result': 'created', '_shards': {'total': 1, 'successful': 1, 'failed': 0}, '_seq_no': 115, '_primary_term': 1}
# Job uploaded successfully: {'_index': 'software_jobs', '_id': 'NNy6gYwBQYTzbOxETn1X', '_version': 1, 'result': 'created', '_shards': {'total': 1, 'successful': 1, 'failed': 0}, '_seq_no': 116, '_primary_term': 1}
# Job uploaded successfully: {'_index': 'software_jobs', '_id': 'Ndy6gYwBQYTzbOxETn1d', '_version': 1, 'result': 'created', '_shards': {'total': 1, 'successful': 1, 'failed': 0}, '_seq_no': 117, '_primary_term': 1}
# Job uploaded successfully: {'_index': 'software_jobs', '_id': 'Nty6gYwBQYTzbOxETn1i', '_version': 1, 'result': 'created', '_shards': {'total': 1, 'successful': 1, 'failed': 0}, '_seq_no': 118, '_primary_term': 1}
# Job uploaded successfully: {'_index': 'software_jobs', '_id': 'N9y6gYwBQYTzbOxETn1o', '_version': 1, 'result': 'created', '_shards': {'total': 1, 'successful': 1, 'failed': 0}, '_seq_no': 119, '_primary_term': 1}
# Job uploaded successfully: {'_index': 'software_jobs', '_id': 'ONy6gYwBQYTzbOxETn1u', '_version': 1, 'result': 'created', '_shards': {'total': 1, 'successful': 1, 'failed': 0}, '_seq_no': 120, '_primary_term': 1}
# Job uploaded successfully: {'_index': 'software_jobs', '_id': 'Ody6gYwBQYTzbOxETn10', '_version': 1, 'result': 'created', '_shards': {'total': 1, 'successful': 1, 'failed': 0}, '_seq_no': 121, '_primary_term': 1}
# Job uploaded successfully: {'_index': 'software_jobs', '_id': 'Oty6gYwBQYTzbOxETn16', '_version': 1, 'result': 'created', '_shards': {'total': 1, 'successful': 1, 'failed': 0}, '_seq_no': 122, '_primary_term': 1}
# Job uploaded successfully: {'_index': 'software_jobs', '_id': 'O9y6gYwBQYTzbOxETn2A', '_version': 1, 'result': 'created', '_shards': {'total': 1, 'successful': 1, 'failed': 0}, '_seq_no': 123, '_primary_term': 1}
# Job uploaded successfully: {'_index': 'software_jobs', '_id': 'PNy6gYwBQYTzbOxETn2H', '_version': 1, 'result': 'created', '_shards': {'total': 1, 'successful': 1, 'failed': 0}, '_seq_no': 124, '_primary_term': 1}
# Job uploaded successfully: {'_index': 'software_jobs', '_id': 'Pdy6gYwBQYTzbOxETn2O', '_version': 1, 'result': 'created', '_shards': {'total': 1, 'successful': 1, 'failed': 0}, '_seq_no': 125, '_primary_term': 1}
# Job uploaded successfully: {'_index': 'software_jobs', '_id': 'Pty6gYwBQYTzbOxETn2W', '_version': 1, 'result': 'created', '_shards': {'total': 1, 'successful': 1, 'failed': 0}, '_seq_no': 126, '_primary_term': 1}
# Job uploaded successfully: {'_index': 'software_jobs', '_id': 'P9y6gYwBQYTzbOxETn2c', '_version': 1, 'result': 'created', '_shards': {'total': 1, 'successful': 1, 'failed': 0}, '_seq_no': 127, '_primary_term': 1}
# Job uploaded successfully: {'_index': 'software_jobs', '_id': 'QNy6gYwBQYTzbOxETn2j', '_version': 1, 'result': 'created', '_shards': {'total': 1, 'successful': 1, 'failed': 0}, '_seq_no': 128, '_primary_term': 1}
# Job uploaded successfully: {'_index': 'software_jobs', '_id': 'Qdy6gYwBQYTzbOxETn2p', '_version': 1, 'result': 'created', '_shards': {'total': 1, 'successful': 1, 'failed': 0}, '_seq_no': 129, '_primary_term': 1}
# Job uploaded successfully: {'_index': 'software_jobs', '_id': 'Qty6gYwBQYTzbOxETn2w', '_version': 1, 'result': 'created', '_shards': {'total': 1, 'successful': 1, 'failed': 0}, '_seq_no': 130, '_primary_term': 1}
# Job uploaded successfully: {'_index': 'software_jobs', '_id': 'Q9y6gYwBQYTzbOxETn21', '_version': 1, 'result': 'created', '_shards': {'total': 1, 'successful': 1, 'failed': 0}, '_seq_no': 131, '_primary_term': 1}
# Job uploaded successfully: {'_index': 'software_jobs', '_id': 'RNy6gYwBQYTzbOxETn27', '_version': 1, 'result': 'created', '_shards': {'total': 1, 'successful': 1, 'failed': 0}, '_seq_no': 132, '_primary_term': 1}
# Job uploaded successfully: {'_index': 'software_jobs', '_id': 'Rdy6gYwBQYTzbOxETn3B', '_version': 1, 'result': 'created', '_shards': {'total': 1, 'successful': 1, 'failed': 0}, '_seq_no': 133, '_primary_term': 1}
# Job uploaded successfully: {'_index': 'software_jobs', '_id': 'Rty6gYwBQYTzbOxETn3H', '_version': 1, 'result': 'created', '_shards': {'total': 1, 'successful': 1, 'failed': 0}, '_seq_no': 134, '_primary_term': 1}
# Job uploaded successfully: {'_index': 'software_jobs', '_id': 'R9y6gYwBQYTzbOxETn3N', '_version': 1, 'result': 'created', '_shards': {'total': 1, 'successful': 1, 'failed': 0}, '_seq_no': 135, '_primary_term': 1}
# Job uploaded successfully: {'_index': 'software_jobs', '_id': 'SNy6gYwBQYTzbOxETn3T', '_version': 1, 'result': 'created', '_shards': {'total': 1, 'successful': 1, 'failed': 0}, '_seq_no': 136, '_primary_term': 1}
# Job uploaded successfully: {'_index': 'software_jobs', '_id': 'Sdy6gYwBQYTzbOxETn3Z', '_version': 1, 'result': 'created', '_shards': {'total': 1, 'successful': 1, 'failed': 0}, '_seq_no': 137, '_primary_term': 1}
# Job uploaded successfully: {'_index': 'software_jobs', '_id': 'Sty6gYwBQYTzbOxETn3f', '_version': 1, 'result': 'created', '_shards': {'total': 1, 'successful': 1, 'failed': 0}, '_seq_no': 138, '_primary_term': 1}
# Job uploaded successfully: {'_index': 'software_jobs', '_id': 'S9y6gYwBQYTzbOxETn3l', '_version': 1, 'result': 'created', '_shards': {'total': 1, 'successful': 1, 'failed': 0}, '_seq_no': 139, '_primary_term': 1}
# Job uploaded successfully: {'_index': 'software_jobs', '_id': 'TNy6gYwBQYTzbOxETn3s', '_version': 1, 'result': 'created', '_shards': {'total': 1, 'successful': 1, 'failed': 0}, '_seq_no': 140, '_primary_term': 1}
# Job uploaded successfully: {'_index': 'software_jobs', '_id': 'Tdy6gYwBQYTzbOxETn31', '_version': 1, 'result': 'created', '_shards': {'total': 1, 'successful': 1, 'failed': 0}, '_seq_no': 141, '_primary_term': 1}
# Job uploaded successfully: {'_index': 'software_jobs', '_id': 'Tty6gYwBQYTzbOxETn36', '_version': 1, 'result': 'created', '_shards': {'total': 1, 'successful': 1, 'failed': 0}, '_seq_no': 142, '_primary_term': 1}
# Job uploaded successfully: {'_index': 'software_jobs', '_id': 'T9y6gYwBQYTzbOxET30B', '_version': 1, 'result': 'created', '_shards': {'total': 1, 'successful': 1, 'failed': 0}, '_seq_no': 143, '_primary_term': 1}
# Job uploaded successfully: {'_index': 'software_jobs', '_id': 'UNy6gYwBQYTzbOxET30I', '_version': 1, 'result': 'created', '_shards': {'total': 1, 'successful': 1, 'failed': 0}, '_seq_no': 144, '_primary_term': 1}
# Job uploaded successfully: {'_index': 'software_jobs', '_id': 'Udy6gYwBQYTzbOxET30O', '_version': 1, 'result': 'created', '_shards': {'total': 1, 'successful': 1, 'failed': 0}, '_seq_no': 145, '_primary_term': 1}
# Job uploaded successfully: {'_index': 'software_jobs', '_id': 'Uty6gYwBQYTzbOxET30U', '_version': 1, 'result': 'created', '_shards': {'total': 1, 'successful': 1, 'failed': 0}, '_seq_no': 146, '_primary_term': 1}
# Job uploaded successfully: {'_index': 'software_jobs', '_id': 'U9y6gYwBQYTzbOxET30a', '_version': 1, 'result': 'created', '_shards': {'total': 1, 'successful': 1, 'failed': 0}, '_seq_no': 147, '_primary_term': 1}
# Job uploaded successfully: {'_index': 'software_jobs', '_id': 'VNy6gYwBQYTzbOxET30h', '_version': 1, 'result': 'created', '_shards': {'total': 1, 'successful': 1, 'failed': 0}, '_seq_no': 148, '_primary_term': 1}
# Job uploaded successfully: {'_index': 'software_jobs', '_id': 'Vdy6gYwBQYTzbOxET30o', '_version': 1, 'result': 'created', '_shards': {'total': 1, 'successful': 1, 'failed': 0}, '_seq_no': 149, '_primary_term': 1}
# Job uploaded successfully: {'_index': 'software_jobs', '_id': 'Vty6gYwBQYTzbOxET30v', '_version': 1, 'result': 'created', '_shards': {'total': 1, 'successful': 1, 'failed': 0}, '_seq_no': 150, '_primary_term': 1}
# Job uploaded successfully: {'_index': 'software_jobs', '_id': 'V9y6gYwBQYTzbOxET302', '_version': 1, 'result': 'created', '_shards': {'total': 1, 'successful': 1, 'failed': 0}, '_seq_no': 151, '_primary_term': 1}
# Job uploaded successfully: {'_index': 'software_jobs', '_id': 'WNy6gYwBQYTzbOxET308', '_version': 1, 'result': 'created', '_shards': {'total': 1, 'successful': 1, 'failed': 0}, '_seq_no': 152, '_primary_term': 1}
# Job uploaded successfully: {'_index': 'software_jobs', '_id': 'Wdy6gYwBQYTzbOxET31D', '_version': 1, 'result': 'created', '_shards': {'total': 1, 'successful': 1, 'failed': 0}, '_seq_no': 153, '_primary_term': 1}
# Job uploaded successfully: {'_index': 'software_jobs', '_id': 'Wty6gYwBQYTzbOxET31J', '_version': 1, 'result': 'created', '_shards': {'total': 1, 'successful': 1, 'failed': 0}, '_seq_no': 154, '_primary_term': 1}
# Job uploaded successfully: {'_index': 'software_jobs', '_id': 'W9y6gYwBQYTzbOxET31P', '_version': 1, 'result': 'created', '_shards': {'total': 1, 'successful': 1, 'failed': 0}, '_seq_no': 155, '_primary_term': 1}
# Job uploaded successfully: {'_index': 'software_jobs', '_id': 'XNy6gYwBQYTzbOxET31W', '_version': 1, 'result': 'created', '_shards': {'total': 1, 'successful': 1, 'failed': 0}, '_seq_no': 156, '_primary_term': 1}
# Job uploaded successfully: {'_index': 'software_jobs', '_id': 'Xdy6gYwBQYTzbOxET31f', '_version': 1, 'result': 'created', '_shards': {'total': 1, 'successful': 1, 'failed': 0}, '_seq_no': 157, '_primary_term': 1}
# Job uploaded successfully: {'_index': 'software_jobs', '_id': 'Xty6gYwBQYTzbOxET31m', '_version': 1, 'result': 'created', '_shards': {'total': 1, 'successful': 1, 'failed': 0}, '_seq_no': 158, '_primary_term': 1}
# Job uploaded successfully: {'_index': 'software_jobs', '_id': 'X9y6gYwBQYTzbOxET311', '_version': 1, 'result': 'created', '_shards': {'total': 1, 'successful': 1, 'failed': 0}, '_seq_no': 159, '_primary_term': 1}
# Job uploaded successfully: {'_index': 'software_jobs', '_id': 'YNy6gYwBQYTzbOxET32E', '_version': 1, 'result': 'created', '_shards': {'total': 1, 'successful': 1, 'failed': 0}, '_seq_no': 160, '_primary_term': 1}
# Job uploaded successfully: {'_index': 'software_jobs', '_id': 'Ydy6gYwBQYTzbOxET32O', '_version': 1, 'result': 'created', '_shards': {'total': 1, 'successful': 1, 'failed': 0}, '_seq_no': 161, '_primary_term': 1}
# Job uploaded successfully: {'_index': 'software_jobs', '_id': 'Yty6gYwBQYTzbOxET32U', '_version': 1, 'result': 'created', '_shards': {'total': 1, 'successful': 1, 'failed': 0}, '_seq_no': 162, '_primary_term': 1}
# Job uploaded successfully: {'_index': 'software_jobs', '_id': 'Y9y6gYwBQYTzbOxET32a', '_version': 1, 'result': 'created', '_shards': {'total': 1, 'successful': 1, 'failed': 0}, '_seq_no': 163, '_primary_term': 1}
# Job uploaded successfully: {'_index': 'software_jobs', '_id': 'ZNy6gYwBQYTzbOxET32h', '_version': 1, 'result': 'created', '_shards': {'total': 1, 'successful': 1, 'failed': 0}, '_seq_no': 164, '_primary_term': 1}
# Job uploaded successfully: {'_index': 'software_jobs', '_id': 'Zdy6gYwBQYTzbOxET32m', '_version': 1, 'result': 'created', '_shards': {'total': 1, 'successful': 1, 'failed': 0}, '_seq_no': 165, '_primary_term': 1}
# Job uploaded successfully: {'_index': 'software_jobs', '_id': 'Zty6gYwBQYTzbOxET32s', '_version': 1, 'result': 'created', '_shards': {'total': 1, 'successful': 1, 'failed': 0}, '_seq_no': 166, '_primary_term': 1}
# Job uploaded successfully: {'_index': 'software_jobs', '_id': 'Z9y6gYwBQYTzbOxET32y', '_version': 1, 'result': 'created', '_shards': {'total': 1, 'successful': 1, 'failed': 0}, '_seq_no': 167, '_primary_term': 1}
# Job uploaded successfully: {'_index': 'software_jobs', '_id': 'aNy6gYwBQYTzbOxET327', '_version': 1, 'result': 'created', '_shards': {'total': 1, 'successful': 1, 'failed': 0}, '_seq_no': 168, '_primary_term': 1}
# Job uploaded successfully: {'_index': 'software_jobs', '_id': 'ady6gYwBQYTzbOxET33B', '_version': 1, 'result': 'created', '_shards': {'total': 1, 'successful': 1, 'failed': 0}, '_seq_no': 169, '_primary_term': 1}
# Job uploaded successfully: {'_index': 'software_jobs', '_id': 'aty6gYwBQYTzbOxET33H', '_version': 1, 'result': 'created', '_shards': {'total': 1, 'successful': 1, 'failed': 0}, '_seq_no': 170, '_primary_term': 1}
# Job uploaded successfully: {'_index': 'software_jobs', '_id': 'a9y6gYwBQYTzbOxET33N', '_version': 1, 'result': 'created', '_shards': {'total': 1, 'successful': 1, 'failed': 0}, '_seq_no': 171, '_primary_term': 1}
# Job uploaded successfully: {'_index': 'software_jobs', '_id': 'bNy6gYwBQYTzbOxET33T', '_version': 1, 'result': 'created', '_shards': {'total': 1, 'successful': 1, 'failed': 0}, '_seq_no': 172, '_primary_term': 1}
# Job uploaded successfully: {'_index': 'software_jobs', '_id': 'bdy6gYwBQYTzbOxET33Z', '_version': 1, 'result': 'created', '_shards': {'total': 1, 'successful': 1, 'failed': 0}, '_seq_no': 173, '_primary_term': 1}
# Job uploaded successfully: {'_index': 'software_jobs', '_id': 'bty6gYwBQYTzbOxET33f', '_version': 1, 'result': 'created', '_shards': {'total': 1, 'successful': 1, 'failed': 0}, '_seq_no': 174, '_primary_term': 1}
# Job uploaded successfully: {'_index': 'software_jobs', '_id': 'b9y6gYwBQYTzbOxET33k', '_version': 1, 'result': 'created', '_shards': {'total': 1, 'successful': 1, 'failed': 0}, '_seq_no': 175, '_primary_term': 1}
# Job uploaded successfully: {'_index': 'software_jobs', '_id': 'cNy6gYwBQYTzbOxET33q', '_version': 1, 'result': 'created', '_shards': {'total': 1, 'successful': 1, 'failed': 0}, '_seq_no': 176, '_primary_term': 1}
# Job uploaded successfully: {'_index': 'software_jobs', '_id': 'cdy6gYwBQYTzbOxET33w', '_version': 1, 'result': 'created', '_shards': {'total': 1, 'successful': 1, 'failed': 0}, '_seq_no': 177, '_primary_term': 1}
# Job uploaded successfully: {'_index': 'software_jobs', '_id': 'cty6gYwBQYTzbOxET332', '_version': 1, 'result': 'created', '_shards': {'total': 1, 'successful': 1, 'failed': 0}, '_seq_no': 178, '_primary_term': 1}
# Job uploaded successfully: {'_index': 'software_jobs', '_id': 'c9y6gYwBQYTzbOxET338', '_version': 1, 'result': 'created', '_shards': {'total': 1, 'successful': 1, 'failed': 0}, '_seq_no': 179, '_primary_term': 1}
# Job uploaded successfully: {'_index': 'software_jobs', '_id': 'dNy6gYwBQYTzbOxEUH0C', '_version': 1, 'result': 'created', '_shards': {'total': 1, 'successful': 1, 'failed': 0}, '_seq_no': 180, '_primary_term': 1}
# Job uploaded successfully: {'_index': 'software_jobs', '_id': 'ddy6gYwBQYTzbOxEUH0I', '_version': 1, 'result': 'created', '_shards': {'total': 1, 'successful': 1, 'failed': 0}, '_seq_no': 181, '_primary_term': 1}
# Job uploaded successfully: {'_index': 'software_jobs', '_id': 'dty6gYwBQYTzbOxEUH0N', '_version': 1, 'result': 'created', '_shards': {'total': 1, 'successful': 1, 'failed': 0}, '_seq_no': 182, '_primary_term': 1}
# Job uploaded successfully: {'_index': 'software_jobs', '_id': 'd9y6gYwBQYTzbOxEUH0T', '_version': 1, 'result': 'created', '_shards': {'total': 1, 'successful': 1, 'failed': 0}, '_seq_no': 183, '_primary_term': 1}
# Job uploaded successfully: {'_index': 'software_jobs', '_id': 'eNy6gYwBQYTzbOxEUH0Y', '_version': 1, 'result': 'created', '_shards': {'total': 1, 'successful': 1, 'failed': 0}, '_seq_no': 184, '_primary_term': 1}
# Job uploaded successfully: {'_index': 'software_jobs', '_id': 'edy6gYwBQYTzbOxEUH0e', '_version': 1, 'result': 'created', '_shards': {'total': 1, 'successful': 1, 'failed': 0}, '_seq_no': 185, '_primary_term': 1}
# Job uploaded successfully: {'_index': 'software_jobs', '_id': 'ety6gYwBQYTzbOxEUH0k', '_version': 1, 'result': 'created', '_shards': {'total': 1, 'successful': 1, 'failed': 0}, '_seq_no': 186, '_primary_term': 1}
# Job uploaded successfully: {'_index': 'software_jobs', '_id': 'e9y6gYwBQYTzbOxEUH0q', '_version': 1, 'result': 'created', '_shards': {'total': 1, 'successful': 1, 'failed': 0}, '_seq_no': 187, '_primary_term': 1}
# Job uploaded successfully: {'_index': 'software_jobs', '_id': 'fNy6gYwBQYTzbOxEUH0x', '_version': 1, 'result': 'created', '_shards': {'total': 1, 'successful': 1, 'failed': 0}, '_seq_no': 188, '_primary_term': 1}
# Job uploaded successfully: {'_index': 'software_jobs', '_id': 'fdy6gYwBQYTzbOxEUH04', '_version': 1, 'result': 'created', '_shards': {'total': 1, 'successful': 1, 'failed': 0}, '_seq_no': 189, '_primary_term': 1}
# Job uploaded successfully: {'_index': 'software_jobs', '_id': 'fty6gYwBQYTzbOxEUH1A', '_version': 1, 'result': 'created', '_shards': {'total': 1, 'successful': 1, 'failed': 0}, '_seq_no': 190, '_primary_term': 1}
# Job uploaded successfully: {'_index': 'software_jobs', '_id': 'f9y6gYwBQYTzbOxEUH1H', '_version': 1, 'result': 'created', '_shards': {'total': 1, 'successful': 1, 'failed': 0}, '_seq_no': 191, '_primary_term': 1}
# Job uploaded successfully: {'_index': 'software_jobs', '_id': 'gNy6gYwBQYTzbOxEUH1O', '_version': 1, 'result': 'created', '_shards': {'total': 1, 'successful': 1, 'failed': 0}, '_seq_no': 192, '_primary_term': 1}
# Job uploaded successfully: {'_index': 'software_jobs', '_id': 'gdy6gYwBQYTzbOxEUH1T', '_version': 1, 'result': 'created', '_shards': {'total': 1, 'successful': 1, 'failed': 0}, '_seq_no': 193, '_primary_term': 1}
# Job uploaded successfully: {'_index': 'software_jobs', '_id': 'gty6gYwBQYTzbOxEUH1Z', '_version': 1, 'result': 'created', '_shards': {'total': 1, 'successful': 1, 'failed': 0}, '_seq_no': 194, '_primary_term': 1}
# Job uploaded successfully: {'_index': 'software_jobs', '_id': 'g9y6gYwBQYTzbOxEUH1e', '_version': 1, 'result': 'created', '_shards': {'total': 1, 'successful': 1, 'failed': 0}, '_seq_no': 195, '_primary_term': 1}
# Job uploaded successfully: {'_index': 'software_jobs', '_id': 'hNy6gYwBQYTzbOxEUH1j', '_version': 1, 'result': 'created', '_shards': {'total': 1, 'successful': 1, 'failed': 0}, '_seq_no': 196, '_primary_term': 1}
# Job uploaded successfully: {'_index': 'software_jobs', '_id': 'hdy6gYwBQYTzbOxEUH1o', '_version': 1, 'result': 'created', '_shards': {'total': 1, 'successful': 1, 'failed': 0}, '_seq_no': 197, '_primary_term': 1}
# Job uploaded successfully: {'_index': 'software_jobs', '_id': 'hty6gYwBQYTzbOxEUH1u', '_version': 1, 'result': 'created', '_shards': {'total': 1, 'successful': 1, 'failed': 0}, '_seq_no': 198, '_primary_term': 1}
# Job uploaded successfully: {'_index': 'software_jobs', '_id': 'h9y6gYwBQYTzbOxEUH1z', '_version': 1, 'result': 'created', '_shards': {'total': 1, 'successful': 1, 'failed': 0}, '_seq_no': 199, '_primary_term': 1}
# Job uploaded successfully: {'_index': 'software_jobs', '_id': 'iNy6gYwBQYTzbOxEUH14', '_version': 1, 'result': 'created', '_shards': {'total': 1, 'successful': 1, 'failed': 0}, '_seq_no': 200, '_primary_term': 1}
# Job uploaded successfully: {'_index': 'software_jobs', '_id': 'idy6gYwBQYTzbOxEUH19', '_version': 1, 'result': 'created', '_shards': {'total': 1, 'successful': 1, 'failed': 0}, '_seq_no': 201, '_primary_term': 1}
# Job uploaded successfully: {'_index': 'software_jobs', '_id': 'ity6gYwBQYTzbOxEUH2C', '_version': 1, 'result': 'created', '_shards': {'total': 1, 'successful': 1, 'failed': 0}, '_seq_no': 202, '_primary_term': 1}
# Job uploaded successfully: {'_index': 'software_jobs', '_id': 'i9y6gYwBQYTzbOxEUH2I', '_version': 1, 'result': 'created', '_shards': {'total': 1, 'successful': 1, 'failed': 0}, '_seq_no': 203, '_primary_term': 1}
# Job uploaded successfully: {'_index': 'software_jobs', '_id': 'jNy6gYwBQYTzbOxEUH2N', '_version': 1, 'result': 'created', '_shards': {'total': 1, 'successful': 1, 'failed': 0}, '_seq_no': 204, '_primary_term': 1}
# Job uploaded successfully: {'_index': 'software_jobs', '_id': 'jdy6gYwBQYTzbOxEUH2R', '_version': 1, 'result': 'created', '_shards': {'total': 1, 'successful': 1, 'failed': 0}, '_seq_no': 205, '_primary_term': 1}
# Job uploaded successfully: {'_index': 'software_jobs', '_id': 'jty6gYwBQYTzbOxEUH2W', '_version': 1, 'result': 'created', '_shards': {'total': 1, 'successful': 1, 'failed': 0}, '_seq_no': 206, '_primary_term': 1}
# Job uploaded successfully: {'_index': 'software_jobs', '_id': 'j9y6gYwBQYTzbOxEUH2c', '_version': 1, 'result': 'created', '_shards': {'total': 1, 'successful': 1, 'failed': 0}, '_seq_no': 207, '_primary_term': 1}
# Job uploaded successfully: {'_index': 'software_jobs', '_id': 'kNy6gYwBQYTzbOxEUH2i', '_version': 1, 'result': 'created', '_shards': {'total': 1, 'successful': 1, 'failed': 0}, '_seq_no': 208, '_primary_term': 1}
# Job uploaded successfully: {'_index': 'software_jobs', '_id': 'kdy6gYwBQYTzbOxEUH2o', '_version': 1, 'result': 'created', '_shards': {'total': 1, 'successful': 1, 'failed': 0}, '_seq_no': 209, '_primary_term': 1}
# Job uploaded successfully: {'_index': 'software_jobs', '_id': 'kty6gYwBQYTzbOxEUH2u', '_version': 1, 'result': 'created', '_shards': {'total': 1, 'successful': 1, 'failed': 0}, '_seq_no': 210, '_primary_term': 1}
# Job uploaded successfully: {'_index': 'software_jobs', '_id': 'k9y6gYwBQYTzbOxEUH21', '_version': 1, 'result': 'created', '_shards': {'total': 1, 'successful': 1, 'failed': 0}, '_seq_no': 211, '_primary_term': 1}
# Job uploaded successfully: {'_index': 'software_jobs', '_id': 'lNy6gYwBQYTzbOxEUH27', '_version': 1, 'result': 'created', '_shards': {'total': 1, 'successful': 1, 'failed': 0}, '_seq_no': 212, '_primary_term': 1}
# Job uploaded successfully: {'_index': 'software_jobs', '_id': 'ldy6gYwBQYTzbOxEUH3A', '_version': 1, 'result': 'created', '_shards': {'total': 1, 'successful': 1, 'failed': 0}, '_seq_no': 213, '_primary_term': 1}
# Job uploaded successfully: {'_index': 'software_jobs', '_id': 'lty6gYwBQYTzbOxEUH3F', '_version': 1, 'result': 'created', '_shards': {'total': 1, 'successful': 1, 'failed': 0}, '_seq_no': 214, '_primary_term': 1}
# Job uploaded successfully: {'_index': 'software_jobs', '_id': 'l9y6gYwBQYTzbOxEUH3J', '_version': 1, 'result': 'created', '_shards': {'total': 1, 'successful': 1, 'failed': 0}, '_seq_no': 215, '_primary_term': 1}
# Job uploaded successfully: {'_index': 'software_jobs', '_id': 'mNy6gYwBQYTzbOxEUH3O', '_version': 1, 'result': 'created', '_shards': {'total': 1, 'successful': 1, 'failed': 0}, '_seq_no': 216, '_primary_term': 1}
# Job uploaded successfully: {'_index': 'software_jobs', '_id': 'mdy6gYwBQYTzbOxEUH3T', '_version': 1, 'result': 'created', '_shards': {'total': 1, 'successful': 1, 'failed': 0}, '_seq_no': 217, '_primary_term': 1}
# Job uploaded successfully: {'_index': 'software_jobs', '_id': 'mty6gYwBQYTzbOxEUH3Y', '_version': 1, 'result': 'created', '_shards': {'total': 1, 'successful': 1, 'failed': 0}, '_seq_no': 218, '_primary_term': 1}
# Job uploaded successfully: {'_index': 'software_jobs', '_id': 'm9y6gYwBQYTzbOxEUH3d', '_version': 1, 'result': 'created', '_shards': {'total': 1, 'successful': 1, 'failed': 0}, '_seq_no': 219, '_primary_term': 1}
# Job uploaded successfully: {'_index': 'software_jobs', '_id': 'nNy6gYwBQYTzbOxEUH3h', '_version': 1, 'result': 'created', '_shards': {'total': 1, 'successful': 1, 'failed': 0}, '_seq_no': 220, '_primary_term': 1}
# Job uploaded successfully: {'_index': 'software_jobs', '_id': 'ndy6gYwBQYTzbOxEUH3n', '_version': 1, 'result': 'created', '_shards': {'total': 1, 'successful': 1, 'failed': 0}, '_seq_no': 221, '_primary_term': 1}
# Job uploaded successfully: {'_index': 'software_jobs', '_id': 'nty6gYwBQYTzbOxEUH3s', '_version': 1, 'result': 'created', '_shards': {'total': 1, 'successful': 1, 'failed': 0}, '_seq_no': 222, '_primary_term': 1}

# %% [markdown]
# Retrieve all data from the index

# %%
elasticsearch_url = "http://localhost:9200"
index_name = "software_jobs"
# Define the search query to match all documents
query = {
    "query": {
        "match_all": {}
    }
}

# Send the search request
response = requests.get(
    f"{elasticsearch_url}/{index_name}/_search",
    json=query,
    auth=(username, password)  # Include authentication parameters
)

# Check the response
if response.status_code == 200:
    data = response.json()
    hits = data.get("hits", {}).get("hits", [])

    if hits:
        for hit in hits:
            print(f"Document ID: {hit['_id']}")
            print(f"Document Content: {hit['_source']}")
    else:
        print("No documents found in the index.")
else:
    print(f"Error fetching data: {response.content}")
# Out:
# Document ID: wNy6gYwBQYTzbOxES3w6
# Document Content: {'job_id': '...', 'title': 'Remote ServiceNow Administration with Python, R, Advanced SQL...', 'company_name': 'Cube Hub Inc.', 'location': '  Irvine, Californie   ', 'via': 'via SaluteMyJob', 'description': "Position Description: ServiceNow Developer for Asset Management team\n\nhis team is working a hybrid schedule, but fully remote candidates will be considered as well...\n• Recent college graduates are not a good fit for this position.\n• Demonstrated knowledge in various programming languages (Python, R, Advanced SQL, etc.) MUST HAVE\n• 3+ Years experience of ServiceNow Administration MUST HAVE\n• Understanding of ServiceNow development environment, database, data management and infrastructure capabilities and constraints MUST HAVE\n• Business process knowledge of Hardware Asset Management (HAM), Software Asset Management (SAM), and procurement Preferred but not required\n• Ability to analyze, translate, and define business requirements into technical solutions, including advanced problem-solving ability - Preferred but not required\n• Excellence in verbal and written communication forms with emphasis on persuasive communication, tact and negotiation - Preferred but not required\nWhat Makes You Stand Out (Desired Skills/experiences)\n\nExperience with the following technologies:\n• Web technologies HTML, XML, or CSS\n• API integrations with other systems\n• Configuration of ServiceNow's ITSM service catalog\n• UI and SQL\n• Ability to manage many competing priorities/requests in a fast-paced environment.\n• ServiceNow Administration certification\n• Expert ITIL process knowledge\n• ITSM ServiceNow knowledge\n• Candidates who are selected for interviews will be required to complete a Glider assessment***\nResponsibilities\n• Builds the work needed to implement functionality from the product backlog (managed by the product owner).\n• Analyzes assignments and determines software specifications that must be fulfilled to achieve objectives and get appropriate value from packaged solutions.\n• Tests deliverables against a user story's acceptance tests.\n• Completes system configuration settings to enable software functionality that supports business processes.\n• Unit-tests software, creates automated test scripts and executes all other testing-related tasks.\n• Works closely with other team members to ensure that features meet business needs; Works collaboratively with infrastructure, security and other partners"}
# Document ID: wdy6gYwBQYTzbOxES3xW
# Document Content: {'job_id': '...', 'title': 'Lead Automated Python Tester', 'company_name': 'Lumen', 'location': '  États-Unis   ', 'via': 'via Lumen Jobs', 'description': "About Lumen\nLumen is guided by our belief that humanity is at its best when technology advances the way we live and work. With 450,000 route fiber miles serving customers in more than 60 countries, we deliver the fastest, most secure global platform for applications and data to help businesses, government and communities deliver amazing experiences. Learn more about Lumen’s network, edge cloud... security and communication and collaboration solutions and our purpose to further human progress through technology at news.lumen.com, LinkedIn: /lumentechnologies, Twitter: @lumentechco, Facebook: /lumentechnologies, Instagram: @lumentechnologies and YouTube: /lumentechnologies.\nThe Role\n\nProvides expert technical direction at a project level. This role will be responsible for planning, developing, and executing tests for complex systems and equipment. The individual will collaborate with various teams across IT to identify the impacts of test requirements and improve the overall quality of the final deliverables. As a technical expert, this person will possess strong communication skills and will be expected to partner with business and technical groups in order to anticipate the effects of testing and bring timely resolution to critical issues. Within their area of expertise, this person will provide specialized advice and direction. They will contribute towards the team’s continual process improvement, and will also provide industry knowledge regarding test strategy development, test R&D activities, and technical support when applicable.\n\nThe Main Responsibilities\n• Perform comprehensive QA planning and coordination\n• Perform manual testing of web, mobile & desktop applications\n• Write automated tests for web and mobile apps using various open-source test frameworks\n• Assist sales and account management on product questions and issues\n• Serve as the user advocate within the engineering team\n• Implement QA metrics, including benchmarking and identification of areas for improving overall performance\n• Identify and lead process improvements in QA and agile execution\n\nWhat We Look For in a Candidate\n• Consulting Level Bachelor's degree. Typically with 8+ years of experience.\n• 6+ years of experience QA Testing (Python). Masters Degree preferred.\n• Collect the release features & update test cases in automation to support Deployments.\n• Update Test automation to support CI/CD deployements.\n• Pre & Post Deployement validations on Apps.\n\nCompensation\n\nThe starting salary for this role differs based on the employee's primary work location. Employees typically do not start at the top of the range, though compensation depends on each individual's qualifications.\n\nLocation Based Pay Ranges\n\n$94420 - $118028 in these states: AR, ID, KY, LA, ME, MS, NE, SC, and SD.\n$99390 - $124230 in these states: AZ, FL, GA, IN, IA, KS, MO, MT, NM, ND, OH, OK, PA, TN, UT, VT, WV, WI, and WY.\n$104360 - $130448 in these states: CO, HI, MI, MN, NV, NH, NC, OR, and RI.\n$109330 - $136665 in these states: AK, CA, CT, DE, DC, IL, MD, MA, NJ, NY, TX, VA, and WA.\n\nAs with the pay range variety that's based on the region of a country, specific offers are determined by various factors such as experience, education, skills, certifications and other business needs.\n\nWhat to Expect Next\n\nRequisition #: 331220\n\nWhen applying for a position, you may be subject to a background screen (criminal records check, motor vehicle report, and/or drug screen), depending on the requirements for the position. More information on what’s included in these checks can be found in the Post Offer section of our FAQ page. Job-related concerns noted in the background screen may disqualify you from the new position or your current role. Background results will be evaluated on a case-by-c ...
# Document ID: wty6gYwBQYTzbOxES3xf
# Document Content: {'job_id': '', 'title': 'Python Developer', 'company_name': 'Neotech Solutions', 'location': '  San José, Californie   ', 'via': 'via Indeed', 'description': 'Job Role: Python Developer\n\nLocation: San Jose, CA (onsite only...\n\nClient: TechM/ ASML\n\nDuration: Contract\n\nJob Description:\n\nClient requirements are:\n• Skillful in Python/Perl scripting\n• Strong Experience with Unix/Linux and shell scripting\n• Experience on Python-based Robot framework is a plus\n• Very good communication and learning capability.\n• 3+ years of software test experiences\n• Proficient with the tooling: Git, Bamboo, JIRA, Test management tools like qTest,.\n• Proficient with Restful API testing\n• Proficient with robot test framework and python programming\n• Familiar with Linux terminal, docker and Kubernetes usage.\n• Experiences of developing/maintaining regression tests\n• Semiconductor Experience is +..\n\nThe following skills are mandatory:\n• SQL\n• LINUX\n• SDET\n• PYTHON\n• ROBOTICS\n• JIRA\n\nMamatha K | US IT Recruiter\nD: (908) 864-9004 |\nMamatha@neotechusa.com\nOne Cragwood Rd | South Plainfield, NJ 07080\neFax: 888-828-9871|\nwww.neotechusa.com\n\nJob Type: Contract\n\nSalary: $48.00 - $53.00 per hour\n\nSchedule:\n• 8 hour shift\n• Monday to Friday\n\nWork Location: In person'}
# Document ID: w9y6gYwBQYTzbOxES3xn
# Document Content: {'job_id': '...', 'title': 'Python Engineer– (Manufacturing Software Tools) || San Jose, CA...', 'company_name': 'Zodiac Solutions, Inc', 'location': '  San José, Californie   ', 'via': 'via LinkedIn', 'description': 'Hello,\n\ni Hope you are doing great, my name is Prashant, I am a recruitment specialist at Zodiac solutions. Our client is looking for an Application Engineer(Python), might be this position can good next step towards your carrier, if you are looking for change or interested in this JOB role, please share me your updated resume so I can check your core strength, and we can discuss it further... Please find the Job description Below.\n\nImportant: Please make sure candidate has several iteration of Software development life cycle (SDLC) experience and he/she is well versed with Agile methodology, preferably have Manufacturing App experience..\n\nRole: Application Engineer(Python) – (Manufacturing Software Tools)\n\nLocation: San Jose, CA (Local, Onsite)\n\nDuration: Long-Term\n\nHire Mode: Contract\n\nA Google Cloud Project application that provides traditional application/ETL/relational database and data warehousing.\n\nShould have several iteration of Software development life cycle (SDLC) experience\n\nwell versed Experience working with Agile methodology, preferably have Manufacturing App experience..\n\nQualifications:\n• 8 years’ experience developing with any object-oriented language: e.g., Python, Java, or C++.\n• 3 years’ experience specifically developing in Python.\n• 3 years’ experience in relational or NoSQL database solutions and Web Frameworks such as Flask or Django.\n\nPreferred Qualifications:\n• Experience working in large, structured software development teams\n• Experience working across multiple distinct systems\n• Our Technologies:\n• Google Cloud Project: Spanner, Big Query, Relational Databases Python 3.9+\n• Git\n• Manufacturing Shop Floor Control Systems\n\nIf you are qualified, available, interested, planning to make a change, please feel free to reach me.\n\nThanks & Regards\n\nPrashant Bhardwaj\n\nSenior US IT Recruiter\n\nZodiac Solutions Inc.\n\n2625 N Josey Ln STE 320, Carrollton, TX 75007\n\nwww.zodiac-solutions.com\n\nEmail: prashant.bhardwaj@zodiac-solutions.com\n\nOffice: 484-953-8110'}
# Document ID: xNy6gYwBQYTzbOxES3xu
# Document Content: {'job_id': '...', 'title': 'GCP  Lead with Strong Python & SQL coding experience', 'company_name': 'ClifyX', 'location': '  Boston, Massachusetts   ', 'via': 'via SaluteMyJob', 'description': '1252334\nGCP(GCS, BigQuery, BQ SQL, Python, Data Fusion,Cloud Composer) Lead with Strong Python & SQL coding experience)\nBoston,Massachusetts...\nVeolia North America, LLC\nPay rate $90/hr\n\n" Possess In depth knowledge and hands on development experience building end to end data pipeline on GCP including ingestion, processing, and storage of datasets.\nStrong Python & SQL coding experience [Must].\nStrong programming foundation in Python, including debugging and performance analysis.\nGood exposure to GCP data services like GCS, BigQuery, BQ SQL, Python, Data Fusion,Cloud Composer\nDeveloping re-usable code and libraries for future use\nOutstanding analytical and critical thinking skills.\nWell-established experience in all phases of development requirement gathering, system design, implementation, testing, deployment and maintenance, of enterprise-wide application systems.\nKnowledge in AWS (S3, Redshift'}
# Document ID: xdy6gYwBQYTzbOxES3x2
# Document Content: {'job_id': '...', 'title': 'Python Developer', 'company_name': 'Connective Talent', 'location': '  Houston, Texas   ', 'via': 'via LinkedIn', 'description': "• *Join Our Client as a Python Developer in Houston, TX!**\n\nLooking for an exciting Python Developer role in Houston, TX? You're in the right place! Enjoy an on-site position with amazing perks like an 11% annual 401K contribution, catered food, and top-notch healthcare benefits...\n\nRole Highlights:\n\n- Contribute to the development of a cutting-edge data management platform.\n\n- Collaborate with a talented Python developer team to build a robust data processing pipeline.\n\nKey Responsibilities:\n\n- Data Integration: Manage diverse data feeds, move them to the cloud, and distribute globally to support business operations.\n\n- Data Acquisition: Collect data from over 1,000 sources daily, including web scraping and handling various data formats.\n\n- Web Scraping: Efficiently download data into databases through web scraping and propose scraping solutions.\n\n- Python Development: Join a dynamic Python developer team, creating Python-based data processing solutions.\n\n- Solution Development: Collaborate on Python enterprise solutions, including libraries and modules for data processing.\n\nQualifications:\n\n- Python developer with 3-5 years of data-focused Python development experience.\n\n- Proficiency in data manipulation and scripting, with the ability to work independently or as part of a team.\n\n- Experience with ETL processes and data integration.\n\n- Familiarity with enterprise-level Python solutions and libraries.\n\nReady to make a mark in data management? Apply today and be part of our exciting team!\n\nhas context menuComposeParagraph"}
# Document ID: xty6gYwBQYTzbOxES3x8
# Document Content: {'job_id': '...', 'title': 'Software Engineer - C++ and Python', 'company_name': 'Global Technology Associates, Ltd.', 'location': '  Ann Arbor, Michigan   ', 'via': 'via ZipRecruiter', 'description': "Software engineer for Automated Driving Systems Engineer - C++ and Python\n\nHybrid Schedule. Must be local to work on site in Ann Arbor, MI, as needed. Average days on site estimated: 6-12 days/month...\n\nJob ID: 1266679 - Location: Ann Arbor, MI 48105\n\nPay Rate: Very Competitive w/OT paid over 40 hours in a week, with benefits options: Health, Dental, Vision, 401(k), company paid holidays\nType of hire: Contract, long-term with ongoing potential. No travel anticipated.\n\nPosition Summary:\n\nIntegrated Vehicle Systems Department is looking for a passionate and highly motivated Software Engineer. The primary responsibility of this role is to develop advanced driver system and software in C/C++ and support overall software quality auditing.\n\nIVS department's objective to design and evaluate the next generation of automated driving systems for the company’s vehicles.\n\nPosition Responsibilities:\n• Design ADS systems and software logic in C/C++\n• Complete logic development by making design requirements, confirming/testing logic, and ensuring quality and all safety concepts into software design.\n• Utilize and create support tools with Python code\n• Position Requirements:The schedule will be a hybrid schedule working at least 6 days a month from the office, however there may be times where this candidate will need to report to the office more frequently therefore this candidate must be flexible.\n• B.S. in Computer Science, related fields, or commensurate work experience.\n• Experience as a production software engineer (3 years).\n• Experience building, implementing, and supporting medium to large scale solutions in C/C++ and Python\n• Experience using GIT., Experience performing performance analysis, troubleshooting, and remediation in a software and integration environment (3 year).\n• Self-starter with the ability to work independently or as part of a project team with limited supervision.\n\nWhat you may bring:\n• C/C++ or Python Certification (foundational, associate, professional, or specialty).\n• A valid US drivers’ license.\n• Experience with dynamics-based vehicle simulation (1 year)\n• Experience developing software in a team setting, creating pull requests, conducting peer reviews.\n• Experience using ROS1 or ROS2\n• Familiarity with Docker\n• Experience developing code on Linux platforms, writing shell scripts.\n• Web development experience (html, JavaScript, CSS)\n• Experience using plotting tools like plot.ly, bokeh, matplotlib.\n• Experience using cloud services (AWS, Azure)\n• Time-series database experience\n\nCompany DescriptionGlobal Technology Associates, LTD can take your career search or hiring needs to the next level. As a premier technical and professional staffing company, with over 30 years of industry experience, we have longstanding connections in industries like automotive, aeronautics, information technology, defense, and healthcare. GTA can provide you with a full breadth of diverse candidates from our talent network. GTA is a national full-service provider of direct and contract professionals and top management talent"}
# Document ID: x9y6gYwBQYTzbOxES3yD
# Document Content: {'job_id': '...', 'title': 'SAS Developer (With Python) @ Reston, VA (Remote, but once in a...', 'company_name': 'Smart IT Frame LLC', 'location': '  Boston, Massachusetts   ', 'via': 'via SaluteMyJob', 'description': 'Role : SAS Developer (With Python)\n\nMode of Hire : Fulltime / Contract...\n\nLocation : Reston, VA (Remote, but once in a month on-site required)\n\nJob Description:\n\nPrimary Skills - Python, Unix, AWS, SAS\n• 8 years of experience in SAS Development.\n• Experience in Base SAS, Advance SAS programming, SAS Macros and SQL and optimization techniques.\n• SAS knowledge to read and understand packages\n• Experience with Pandas, Numpy packages in Python programming\n• Experience with AWS cloud implementation\n• Experience with following AWS services preferred (Step Functions, Lambda, SNS, SQS, S3, EMR, Redshift)\n• Familiar with Release (promote) process, Batch Support (Daily, Weekly, Monthly) and strong SQL/SAS debugging skills\n• Knowledge in Shell scripting good to have.\n\nRegards,\n\nSanjeev\n\nsanjeev'}
# Document ID: yNy6gYwBQYTzbOxES3yJ
# Document Content: {'job_id': '...', 'title': 'Java Tech Lead (Spark and Python expertise)', 'company_name': 'V-Solve', 'location': '  Dallas, Texas   ', 'via': 'via SaluteMyJob', 'description': 'Job Description:\n\nTech Lead (Spark and Python expertise...\n\nJob description:\n\nMandatory:\n\n10+ years of experience in solution, design and development of applications using Java 8+/J2EE, Spring, Spring-Boot, Micro Services, RESTful Services and with experience in Big Data and with experience working in heavy data background needed.\n\nDevelop, program, and maintain applications using the Apache Spark open-source framework.\n\nWork with different aspects of the Spark ecosystem, including Spark SQL, DataFrames, Datasets, and streaming.\n\nSpark Developer must have strong programming skills in Java, Scala, or Python.\n\nFamiliar with big data processing tools and techniques.\n\nProven experience as a Spark Developer or a related role.\n\nStrong programming skills in Java, Scala, or Python.\n\nFamiliarity with big data processing tools and techniques.\n\nExperience with the Hadoop ecosystem.\n\nGood understanding of distributed systems.\n\nExperience with streaming data platforms.\n\nMust have strong experience in Big Data and with experience working in heavy data background needed.\n\nMust be strong in Cloud AWS event-based architecture, Kubernetes, ELK (Elasticsearch, Logstash & Kibana).\n\nMust have excellent experience in designing and Implementing cloud-based solutions in various AWS Services (: s3, Lambda, Step Function, AMQ, SNS, SQS, CloudWatch Events, etc.)\n\nMust be well experienced in design and development of Microservice using Spring-Boot and REST API and with GraphQL.\n\nMust have solid knowledge and experience in NoSQL (MongoDB).\n\nGood knowledge and experience in any Queue based implementations.\n\nStrong knowledge/experience in ORM Framework - JPA / Hibernate.\n\nGood knowledge in technical concepts - Security, Transaction, Monitoring, Performance.\n\nShould we well versed with TDD/ATDD.\n\nShould have experience on Java, Python and Spark.\n\n2+ years of experience in designing and Implementing cloud-based solutions in various AWS Services.\n\nStrong experience in DevOps tool chain (Jenkins, Artifactory, Ansible/Chef/Puppet/Spinnaker, Maven/Gradle, Atlassian Tool suite).\n\nVery Good knowledge and experience in Non-Functional (Technical) Requirements like Security, Transaction, Performance, etc.\n\nExcellent analytical and problem-solving skills.\n\nNice to have:\n\nExperience in Experience with OAuth implementation using Ping Identity\n\nExperience in API Management (Apigee) or Service Mesh (Istio)\n\nGood knowledge and experience in Queue/Topic (Active-MQ) based implementations\n\nGood knowledge and experience in Scheduler and Batch Jobs\n\nExperience with scripting languages using Unix\n\nPreferably certified in AWS'}
# Document ID: ydy6gYwBQYTzbOxES3yP
# Document Content: {'job_id': '...', 'title': 'Sr Python Developer / Senior Python Full Stack Developer', 'company_name': 'Makro Technologies Inc', 'location': '  Princeton, New Jersey   ', 'via': 'via ZipRecruiter', 'description': "Description:\n\nJob Description and nbsp...\n• Develop, test, and debug software applications using Python. and nbsp;\n• and nbsp;Write scalable and reusable code that adheres to best practices. and nbsp;\n• Strong knowledge with utilizing libraries such as Pandas, NumPy, and ORM's like SQL Alchemy.\n• Work with Object-Oriented Programming principles. and nbsp;\n• Proficiently use SQL and interact with RDBMS systems like SQL Server. and nbsp;\n• Collaborate with teams using Git and JIRA for version control and project management. and nbsp;\n• Take full ownership of tasks, work independently, and meet project deadlines. and nbsp;\n• Foster effective teamwork and communication within the development team. and nbsp;\n• API development using RESTful or GraphQL standards. and nbsp;\n• Develop Data Interfaces using Python, Data Frames, Pandas etc. and nbsp;\n• Integration with back-end technologies and frameworks, such as Node.js, .NET, or Java. and nbsp;\n• Build Data Access Layer and metadata-driven data query tool. and nbsp;\n• Write clean, reusable, and well-documented code that follows best practices and coding standards. and nbsp;\n• Collaborate with back-end developers to integrate UI components with server-side systems and APIs. Ensure efficient data retrieval and synchronization, handle data validation and error handling, and optimize API performance. and nbsp;\n• Work in an iterative/Agile environment as a good team player. and nbsp;\n• Ability to manage multiple tasks and projects simultaneously.\n• Work with the latest CI/CD DevOps deployment model\u200b\n\nRequirements and nbsp;\n• 7+ years of experience in Python programming and nbsp;\n• Strong knowledge of Python libraries like Pandas and NumPy and nbsp;\n• Experience in frameworks like Django, Flask, or any other web frameworks and nbsp;\n• Experience in UI library or Framework such as React, Angular or Vue (Preferred React) and nbsp;\n• Proficient with Data structures and Collections and nbsp;\n• Experience in Relational (MySQL, Postgres) and No SQL (Cassandra, Mongo) database technologies and nbsp;\n• Experience in designing and developing distributed and amp; scalable systems using OOPS and/or Functional programming and nbsp;\n• Experience in Distributed Computing and High Velocity data processing and nbsp;\n• Exposure to CI/CD tools like Jenkins, Maven, Git etc. and nbsp"}

# %% [markdown]
# Eventually delete the index

# %%
#response = requests.delete("http://localhost:9200/software_jobs", auth = (username, password))
#response.text
# Out:
# '{"acknowledged":true}'
