# %% [markdown]
# Create the entreprises index

# %%
# Elasticsearch server details

import requests
from my_credentials import *
base_url = "http://localhost:9200"
index_name = "senegal_entreprises_data"

# %%
# Index settings and mapping

index_settings = {
    "settings": {
        "number_of_shards": 1,
        "number_of_replicas": 0
    },
    
    "mappings": {
        
        "properties": {

            'Nom': {"type": "keyword"},
            'Type': {"type": "keyword"},
            'Region': {"type": "keyword"},
            'Arrondissement': {"type": "keyword"},
            'Commune': {"type": "keyword"},
            'Quartier': {"type": "keyword"},
            'Tél': {"type": "keyword"},
            'Statut ligne': {"type": "keyword"}
            
        }
    }
}

# Create the index with authentication
response = requests.put(
    f"{base_url}/{index_name}",
    json=index_settings,
    auth=(username, password)  # Include authentication parameters
)

# Check the response
if response.status_code == 200:
    print(f"Index '{index_name}' created successfully.")
else:
    print(f"Error creating index: {response.content}")
# Out:
# Index 'senegal_entreprises_data' created successfully.

# %% [markdown]
# Post the entreprise data to the index

# %%
import json
elasticsearch_url = "http://localhost:9200"
with open('entreprise_data_2.json') as f:
    cleaned = json.load(f)
for c in cleaned:
        response = requests.post(
            f"{elasticsearch_url}/senegal_entreprises_data/_doc",
            json=c,
            auth=(username, password)  # Include authentication parameters

        )

        if response.status_code == 201:
            print(f"Entreprise data uploaded successfully: {response.json()}")
        else:
            print(f"Error uploading entreprise data: {response.json()}")
# Out:
# Entreprise data successfully: {'_index': 'senegal_entreprises_data', '_id': 'rjIcvY0BWWw3zxq3miUQ', '_version': 1, 'result': 'created', '_shards': {'total': 1, 'successful': 1, 'failed': 0}, '_seq_no': 0, '_primary_term': 1}
# Entreprise data successfully: {'_index': 'senegal_entreprises_data', '_id': 'rzIcvY0BWWw3zxq3miUp', '_version': 1, 'result': 'created', '_shards': {'total': 1, 'successful': 1, 'failed': 0}, '_seq_no': 1, '_primary_term': 1}
# Entreprise data successfully: {'_index': 'senegal_entreprises_data', '_id': 'sDIcvY0BWWw3zxq3miUy', '_version': 1, 'result': 'created', '_shards': {'total': 1, 'successful': 1, 'failed': 0}, '_seq_no': 2, '_primary_term': 1}
# Entreprise data successfully: {'_index': 'senegal_entreprises_data', '_id': 'sTIcvY0BWWw3zxq3miU4', '_version': 1, 'result': 'created', '_shards': {'total': 1, 'successful': 1, 'failed': 0}, '_seq_no': 3, '_primary_term': 1}
# Entreprise data successfully: {'_index': 'senegal_entreprises_data', '_id': 'sjIcvY0BWWw3zxq3miU-', '_version': 1, 'result': 'created', '_shards': {'total': 1, 'successful': 1, 'failed': 0}, '_seq_no': 4, '_primary_term': 1}
# Entreprise data successfully: {'_index': 'senegal_entreprises_data', '_id': 'szIcvY0BWWw3zxq3miVF', '_version': 1, 'result': 'created', '_shards': {'total': 1, 'successful': 1, 'failed': 0}, '_seq_no': 5, '_primary_term': 1}
# Entreprise data successfully: {'_index': 'senegal_entreprises_data', '_id': 'tDIcvY0BWWw3zxq3miVK', '_version': 1, 'result': 'created', '_shards': {'total': 1, 'successful': 1, 'failed': 0}, '_seq_no': 6, '_primary_term': 1}
# Entreprise data successfully: {'_index': 'senegal_entreprises_data', '_id': 'tTIcvY0BWWw3zxq3miVQ', '_version': 1, 'result': 'created', '_shards': {'total': 1, 'successful': 1, 'failed': 0}, '_seq_no': 7, '_primary_term': 1}
# Entreprise data successfully: {'_index': 'senegal_entreprises_data', '_id': 'tjIcvY0BWWw3zxq3miVW', '_version': 1, 'result': 'created', '_shards': {'total': 1, 'successful': 1, 'failed': 0}, '_seq_no': 8, '_primary_term': 1}
# Entreprise data successfully: {'_index': 'senegal_entreprises_data', '_id': 'tzIcvY0BWWw3zxq3miVb', '_version': 1, 'result': 'created', '_shards': {'total': 1, 'successful': 1, 'failed': 0}, '_seq_no': 9, '_primary_term': 1}
# Entreprise data successfully: {'_index': 'senegal_entreprises_data', '_id': 'uDIcvY0BWWw3zxq3miVh', '_version': 1, 'result': 'created', '_shards': {'total': 1, 'successful': 1, 'failed': 0}, '_seq_no': 10, '_primary_term': 1}
# Entreprise data successfully: {'_index': 'senegal_entreprises_data', '_id': 'uTIcvY0BWWw3zxq3miVn', '_version': 1, 'result': 'created', '_shards': {'total': 1, 'successful': 1, 'failed': 0}, '_seq_no': 11, '_primary_term': 1}
# Entreprise data successfully: {'_index': 'senegal_entreprises_data', '_id': 'ujIcvY0BWWw3zxq3miVs', '_version': 1, 'result': 'created', '_shards': {'total': 1, 'successful': 1, 'failed': 0}, '_seq_no': 12, '_primary_term': 1}
# Entreprise data successfully: {'_index': 'senegal_entreprises_data', '_id': 'uzIcvY0BWWw3zxq3miVz', '_version': 1, 'result': 'created', '_shards': {'total': 1, 'successful': 1, 'failed': 0}, '_seq_no': 13, '_primary_term': 1}
# Entreprise data successfully: {'_index': 'senegal_entreprises_data', '_id': 'vDIcvY0BWWw3zxq3miV4', '_version': 1, 'result': 'created', '_shards': {'total': 1, 'successful': 1, 'failed': 0}, '_seq_no': 14, '_primary_term': 1}
# Entreprise data successfully: {'_index': 'senegal_entreprises_data', '_id': 'vTIcvY0BWWw3zxq3miV8', '_version': 1, 'result': 'created', '_shards': {'total': 1, 'successful': 1, 'failed': 0}, '_seq_no': 15, '_primary_term': 1}
# Entreprise data successfully: {'_index': 'senegal_entreprises_data', '_id': 'vjIcvY0BWWw3zxq3miWE', '_version': 1, 'result': 'created', '_shards': {'total': 1, 'successful': 1, 'failed': 0}, '_seq_no': 16, '_primary_term': 1}
# Entreprise data successfully: {'_index': 'senegal_entreprises_data', '_id': 'vzIcvY0BWWw3zxq3miWK', '_version': 1, 'result': 'created', '_shards': {'total': 1, 'successful': 1, 'failed': 0}, '_seq_no': 17, '_primary_term': 1}
# Entreprise data successfully: {'_index': 'senegal_entreprises_data', '_id': 'wDIcvY0BWWw3zxq3miWO', '_version': 1, 'result': 'created', '_shards': {'total': 1, 'successful': 1, 'failed': 0}, '_seq_no': 18, '_primary_term': 1}
# Entreprise data successfully: {'_index': 'senegal_entreprises_data', '_id': 'wTIcvY0BWWw3zxq3miWV', '_version': 1, 'result': 'created', '_shards': {'total': 1, 'successful': 1, 'failed': 0}, '_seq_no': 19, '_primary_term': 1}
# Entreprise data successfully: {'_index': 'senegal_entreprises_data', '_id': 'wjIcvY0BWWw3zxq3miWa', '_version': 1, 'result': 'created', '_shards': {'total': 1, 'successful': 1, 'failed': 0}, '_seq_no': 20, '_primary_term': 1}
# Entreprise data successfully: {'_index': 'senegal_entreprises_data', '_id': 'wzIcvY0BWWw3zxq3miWf', '_version': 1, 'result': 'created', '_shards': {'total': 1, 'successful': 1, 'failed': 0}, '_seq_no': 21, '_primary_term': 1}
# Entreprise data successfully: {'_index': 'senegal_entreprises_data', '_id': 'xDIcvY0BWWw3zxq3miWm', '_version': 1, 'result': 'created', '_shards': {'total': 1, 'successful': 1, 'failed': 0}, '_seq_no': 22, '_primary_term': 1}
# Entreprise data successfully: {'_index': 'senegal_entreprises_data', '_id': 'xTIcvY0BWWw3zxq3miWq', '_version': 1, 'result': 'created', '_shards': {'total': 1, 'successful': 1, 'failed': 0}, '_seq_no': 23, '_primary_term': 1}
# Entreprise data successfully: {'_index': 'senegal_entreprises_data', '_id': 'xjIcvY0BWWw3zxq3miWv', '_version': 1, 'result': 'created', '_shards': {'total': 1, 'successful': 1, 'failed': 0}, '_seq_no': 24, '_primary_term': 1}
# Entreprise data successfully: {'_index': 'senegal_entreprises_data', '_id': 'xzIcvY0BWWw3zxq3miW3', '_version': 1, 'result': 'created', '_shards': {'total': 1, 'successful': 1, 'failed': 0}, '_seq_no': 25, '_primary_term': 1}
# Entreprise data successfully: {'_index': 'senegal_entreprises_data', '_id': 'yDIcvY0BWWw3zxq3miW8', '_version': 1, 'result': 'created', '_shards': {'total': 1, 'successful': 1, 'failed': 0}, '_seq_no': 26, '_primary_term': 1}
# Entreprise data successfully: {'_index': 'senegal_entreprises_data', '_id': 'yTIcvY0BWWw3zxq3miXA', '_version': 1, 'result': 'created', '_shards': {'total': 1, 'successful': 1, 'failed': 0}, '_seq_no': 27, '_primary_term': 1}
# Entreprise data successfully: {'_index': 'senegal_entreprises_data', '_id': 'yjIcvY0BWWw3zxq3miXG', '_version': 1, 'result': 'created', '_shards': {'total': 1, 'successful': 1, 'failed': 0}, '_seq_no': 28, '_primary_term': 1}
# Entreprise data successfully: {'_index': 'senegal_entreprises_data', '_id': 'yzIcvY0BWWw3zxq3miXL', '_version': 1, 'result': 'created', '_shards': {'total': 1, 'successful': 1, 'failed': 0}, '_seq_no': 29, '_primary_term': 1}
# Entreprise data successfully: {'_index': 'senegal_entreprises_data', '_id': 'zDIcvY0BWWw3zxq3miXQ', '_version': 1, 'result': 'created', '_shards': {'total': 1, 'successful': 1, 'failed': 0}, '_seq_no': 30, '_primary_term': 1}
# Entreprise data successfully: {'_index': 'senegal_entreprises_data', '_id': 'zTIcvY0BWWw3zxq3miXX', '_version': 1, 'result': 'created', '_shards': {'total': 1, 'successful': 1, 'failed': 0}, '_seq_no': 31, '_primary_term': 1}
# Entreprise data successfully: {'_index': 'senegal_entreprises_data', '_id': 'zjIcvY0BWWw3zxq3miXd', '_version': 1, 'result': 'created', '_shards': {'total': 1, 'successful': 1, 'failed': 0}, '_seq_no': 32, '_primary_term': 1}
# Entreprise data successfully: {'_index': 'senegal_entreprises_data', '_id': 'zzIcvY0BWWw3zxq3miXi', '_version': 1, 'result': 'created', '_shards': {'total': 1, 'successful': 1, 'failed': 0}, '_seq_no': 33, '_primary_term': 1}
# Entreprise data successfully: {'_index': 'senegal_entreprises_data', '_id': '0DIcvY0BWWw3zxq3miXo', '_version': 1, 'result': 'created', '_shards': {'total': 1, 'successful': 1, 'failed': 0}, '_seq_no': 34, '_primary_term': 1}
# Entreprise data successfully: {'_index': 'senegal_entreprises_data', '_id': '0TIcvY0BWWw3zxq3miXu', '_version': 1, 'result': 'created', '_shards': {'total': 1, 'successful': 1, 'failed': 0}, '_seq_no': 35, '_primary_term': 1}
# Entreprise data successfully: {'_index': 'senegal_entreprises_data', '_id': '0jIcvY0BWWw3zxq3miXz', '_version': 1, 'result': 'created', '_shards': {'total': 1, 'successful': 1, 'failed': 0}, '_seq_no': 36, '_primary_term': 1}
# Entreprise data successfully: {'_index': 'senegal_entreprises_data', '_id': '0zIcvY0BWWw3zxq3miX5', '_version': 1, 'result': 'created', '_shards': {'total': 1, 'successful': 1, 'failed': 0}, '_seq_no': 37, '_primary_term': 1}
# Entreprise data successfully: {'_index': 'senegal_entreprises_data', '_id': '1DIcvY0BWWw3zxq3miX_', '_version': 1, 'result': 'created', '_shards': {'total': 1, 'successful': 1, 'failed': 0}, '_seq_no': 38, '_primary_term': 1}
# Entreprise data successfully: {'_index': 'senegal_entreprises_data', '_id': '1TIcvY0BWWw3zxq3myUG', '_version': 1, 'result': 'created', '_shards': {'total': 1, 'successful': 1, 'failed': 0}, '_seq_no': 39, '_primary_term': 1}
# Entreprise data successfully: {'_index': 'senegal_entreprises_data', '_id': '1jIcvY0BWWw3zxq3myUP', '_version': 1, 'result': 'created', '_shards': {'total': 1, 'successful': 1, 'failed': 0}, '_seq_no': 40, '_primary_term': 1}
# Entreprise data successfully: {'_index': 'senegal_entreprises_data', '_id': '1zIcvY0BWWw3zxq3myUV', '_version': 1, 'result': 'created', '_shards': {'total': 1, 'successful': 1, 'failed': 0}, '_seq_no': 41, '_primary_term': 1}
# Entreprise data successfully: {'_index': 'senegal_entreprises_data', '_id': '2DIcvY0BWWw3zxq3myUa', '_version': 1, 'result': 'created', '_shards': {'total': 1, 'successful': 1, 'failed': 0}, '_seq_no': 42, '_primary_term': 1}
# Entreprise data successfully: {'_index': 'senegal_entreprises_data', '_id': '2TIcvY0BWWw3zxq3myUf', '_version': 1, 'result': 'created', '_shards': {'total': 1, 'successful': 1, 'failed': 0}, '_seq_no': 43, '_primary_term': 1}
# Entreprise data successfully: {'_index': 'senegal_entreprises_data', '_id': '2jIcvY0BWWw3zxq3myUk', '_version': 1, 'result': 'created', '_shards': {'total': 1, 'successful': 1, 'failed': 0}, '_seq_no': 44, '_primary_term': 1}
# Entreprise data successfully: {'_index': 'senegal_entreprises_data', '_id': '2zIcvY0BWWw3zxq3myUq', '_version': 1, 'result': 'created', '_shards': {'total': 1, 'successful': 1, 'failed': 0}, '_seq_no': 45, '_primary_term': 1}
# Entreprise data successfully: {'_index': 'senegal_entreprises_data', '_id': '3DIcvY0BWWw3zxq3myUu', '_version': 1, 'result': 'created', '_shards': {'total': 1, 'successful': 1, 'failed': 0}, '_seq_no': 46, '_primary_term': 1}
# Entreprise data successfully: {'_index': 'senegal_entreprises_data', '_id': '3TIcvY0BWWw3zxq3myUz', '_version': 1, 'result': 'created', '_shards': {'total': 1, 'successful': 1, 'failed': 0}, '_seq_no': 47, '_primary_term': 1}
# Entreprise data successfully: {'_index': 'senegal_entreprises_data', '_id': '3jIcvY0BWWw3zxq3myU5', '_version': 1, 'result': 'created', '_shards': {'total': 1, 'successful': 1, 'failed': 0}, '_seq_no': 48, '_primary_term': 1}
# Entreprise data successfully: {'_index': 'senegal_entreprises_data', '_id': '3zIcvY0BWWw3zxq3myU_', '_version': 1, 'result': 'created', '_shards': {'total': 1, 'successful': 1, 'failed': 0}, '_seq_no': 49, '_primary_term': 1}
# Entreprise data successfully: {'_index': 'senegal_entreprises_data', '_id': '4DIcvY0BWWw3zxq3myVD', '_version': 1, 'result': 'created', '_shards': {'total': 1, 'successful': 1, 'failed': 0}, '_seq_no': 50, '_primary_term': 1}
# Entreprise data successfully: {'_index': 'senegal_entreprises_data', '_id': '4TIcvY0BWWw3zxq3myVI', '_version': 1, 'result': 'created', '_shards': {'total': 1, 'successful': 1, 'failed': 0}, '_seq_no': 51, '_primary_term': 1}
# Entreprise data successfully: {'_index': 'senegal_entreprises_data', '_id': '4jIcvY0BWWw3zxq3myVN', '_version': 1, 'result': 'created', '_shards': {'total': 1, 'successful': 1, 'failed': 0}, '_seq_no': 52, '_primary_term': 1}
# Entreprise data successfully: {'_index': 'senegal_entreprises_data', '_id': '4zIcvY0BWWw3zxq3myVT', '_version': 1, 'result': 'created', '_shards': {'total': 1, 'successful': 1, 'failed': 0}, '_seq_no': 53, '_primary_term': 1}
# Entreprise data successfully: {'_index': 'senegal_entreprises_data', '_id': '5DIcvY0BWWw3zxq3myVY', '_version': 1, 'result': 'created', '_shards': {'total': 1, 'successful': 1, 'failed': 0}, '_seq_no': 54, '_primary_term': 1}
# Entreprise data successfully: {'_index': 'senegal_entreprises_data', '_id': '5TIcvY0BWWw3zxq3myVd', '_version': 1, 'result': 'created', '_shards': {'total': 1, 'successful': 1, 'failed': 0}, '_seq_no': 55, '_primary_term': 1}
# Entreprise data successfully: {'_index': 'senegal_entreprises_data', '_id': '5jIcvY0BWWw3zxq3myVj', '_version': 1, 'result': 'created', '_shards': {'total': 1, 'successful': 1, 'failed': 0}, '_seq_no': 56, '_primary_term': 1}
# Entreprise data successfully: {'_index': 'senegal_entreprises_data', '_id': '5zIcvY0BWWw3zxq3myVn', '_version': 1, 'result': 'created', '_shards': {'total': 1, 'successful': 1, 'failed': 0}, '_seq_no': 57, '_primary_term': 1}
# Entreprise data successfully: {'_index': 'senegal_entreprises_data', '_id': '6DIcvY0BWWw3zxq3myVt', '_version': 1, 'result': 'created', '_shards': {'total': 1, 'successful': 1, 'failed': 0}, '_seq_no': 58, '_primary_term': 1}
# Entreprise data successfully: {'_index': 'senegal_entreprises_data', '_id': '6TIcvY0BWWw3zxq3myVy', '_version': 1, 'result': 'created', '_shards': {'total': 1, 'successful': 1, 'failed': 0}, '_seq_no': 59, '_primary_term': 1}
# Entreprise data successfully: {'_index': 'senegal_entreprises_data', '_id': '6jIcvY0BWWw3zxq3myV3', '_version': 1, 'result': 'created', '_shards': {'total': 1, 'successful': 1, 'failed': 0}, '_seq_no': 60, '_primary_term': 1}
# Entreprise data successfully: {'_index': 'senegal_entreprises_data', '_id': '6zIcvY0BWWw3zxq3myV8', '_version': 1, 'result': 'created', '_shards': {'total': 1, 'successful': 1, 'failed': 0}, '_seq_no': 61, '_primary_term': 1}
# Entreprise data successfully: {'_index': 'senegal_entreprises_data', '_id': '7DIcvY0BWWw3zxq3myWB', '_version': 1, 'result': 'created', '_shards': {'total': 1, 'successful': 1, 'failed': 0}, '_seq_no': 62, '_primary_term': 1}
# Entreprise data successfully: {'_index': 'senegal_entreprises_data', '_id': '7TIcvY0BWWw3zxq3myWF', '_version': 1, 'result': 'created', '_shards': {'total': 1, 'successful': 1, 'failed': 0}, '_seq_no': 63, '_primary_term': 1}
# Entreprise data successfully: {'_index': 'senegal_entreprises_data', '_id': '7jIcvY0BWWw3zxq3myWL', '_version': 1, 'result': 'created', '_shards': {'total': 1, 'successful': 1, 'failed': 0}, '_seq_no': 64, '_primary_term': 1}
# Entreprise data successfully: {'_index': 'senegal_entreprises_data', '_id': '7zIcvY0BWWw3zxq3myWP', '_version': 1, 'result': 'created', '_shards': {'total': 1, 'successful': 1, 'failed': 0}, '_seq_no': 65, '_primary_term': 1}
# Entreprise data successfully: {'_index': 'senegal_entreprises_data', '_id': '8DIcvY0BWWw3zxq3myWU', '_version': 1, 'result': 'created', '_shards': {'total': 1, 'successful': 1, 'failed': 0}, '_seq_no': 66, '_primary_term': 1}
# Entreprise data successfully: {'_index': 'senegal_entreprises_data', '_id': '8TIcvY0BWWw3zxq3myWZ', '_version': 1, 'result': 'created', '_shards': {'total': 1, 'successful': 1, 'failed': 0}, '_seq_no': 67, '_primary_term': 1}
# Entreprise data successfully: {'_index': 'senegal_entreprises_data', '_id': '8jIcvY0BWWw3zxq3myWe', '_version': 1, 'result': 'created', '_shards': {'total': 1, 'successful': 1, 'failed': 0}, '_seq_no': 68, '_primary_term': 1}
# Entreprise data successfully: {'_index': 'senegal_entreprises_data', '_id': '8zIcvY0BWWw3zxq3myWj', '_version': 1, 'result': 'created', '_shards': {'total': 1, 'successful': 1, 'failed': 0}, '_seq_no': 69, '_primary_term': 1}
# Entreprise data successfully: {'_index': 'senegal_entreprises_data', '_id': '9DIcvY0BWWw3zxq3myWo', '_version': 1, 'result': 'created', '_shards': {'total': 1, 'successful': 1, 'failed': 0}, '_seq_no': 70, '_primary_term': 1}
# Entreprise data successfully: {'_index': 'senegal_entreprises_data', '_id': '9TIcvY0BWWw3zxq3myWt', '_version': 1, 'result': 'created', '_shards': {'total': 1, 'successful': 1, 'failed': 0}, '_seq_no': 71, '_primary_term': 1}
# Entreprise data successfully: {'_index': 'senegal_entreprises_data', '_id': '9jIcvY0BWWw3zxq3myWx', '_version': 1, 'result': 'created', '_shards': {'total': 1, 'successful': 1, 'failed': 0}, '_seq_no': 72, '_primary_term': 1}
# Entreprise data successfully: {'_index': 'senegal_entreprises_data', '_id': '9zIcvY0BWWw3zxq3myW2', '_version': 1, 'result': 'created', '_shards': {'total': 1, 'successful': 1, 'failed': 0}, '_seq_no': 73, '_primary_term': 1}
# Entreprise data successfully: {'_index': 'senegal_entreprises_data', '_id': '-DIcvY0BWWw3zxq3myW7', '_version': 1, 'result': 'created', '_shards': {'total': 1, 'successful': 1, 'failed': 0}, '_seq_no': 74, '_primary_term': 1}
# Entreprise data successfully: {'_index': 'senegal_entreprises_data', '_id': '-TIcvY0BWWw3zxq3myXB', '_version': 1, 'result': 'created', '_shards': {'total': 1, 'successful': 1, 'failed': 0}, '_seq_no': 75, '_primary_term': 1}
# Entreprise data successfully: {'_index': 'senegal_entreprises_data', '_id': '-jIcvY0BWWw3zxq3myXJ', '_version': 1, 'result': 'created', '_shards': {'total': 1, 'successful': 1, 'failed': 0}, '_seq_no': 76, '_primary_term': 1}
# Entreprise data successfully: {'_index': 'senegal_entreprises_data', '_id': '-zIcvY0BWWw3zxq3myXP', '_version': 1, 'result': 'created', '_shards': {'total': 1, 'successful': 1, 'failed': 0}, '_seq_no': 77, '_primary_term': 1}
# Entreprise data successfully: {'_index': 'senegal_entreprises_data', '_id': '_DIcvY0BWWw3zxq3myXV', '_version': 1, 'result': 'created', '_shards': {'total': 1, 'successful': 1, 'failed': 0}, '_seq_no': 78, '_primary_term': 1}
# Entreprise data successfully: {'_index': 'senegal_entreprises_data', '_id': '_TIcvY0BWWw3zxq3myXb', '_version': 1, 'result': 'created', '_shards': {'total': 1, 'successful': 1, 'failed': 0}, '_seq_no': 79, '_primary_term': 1}
# Entreprise data successfully: {'_index': 'senegal_entreprises_data', '_id': '_jIcvY0BWWw3zxq3myXj', '_version': 1, 'result': 'created', '_shards': {'total': 1, 'successful': 1, 'failed': 0}, '_seq_no': 80, '_primary_term': 1}
# Entreprise data successfully: {'_index': 'senegal_entreprises_data', '_id': '_zIcvY0BWWw3zxq3myXr', '_version': 1, 'result': 'created', '_shards': {'total': 1, 'successful': 1, 'failed': 0}, '_seq_no': 81, '_primary_term': 1}
# Entreprise data successfully: {'_index': 'senegal_entreprises_data', '_id': 'ADIcvY0BWWw3zxq3nCY0', '_version': 1, 'result': 'created', '_shards': {'total': 1, 'successful': 1, 'failed': 0}, '_seq_no': 82, '_primary_term': 1}
# Entreprise data successfully: {'_index': 'senegal_entreprises_data', '_id': 'ATIcvY0BWWw3zxq3nCY5', '_version': 1, 'result': 'created', '_shards': {'total': 1, 'successful': 1, 'failed': 0}, '_seq_no': 83, '_primary_term': 1}
# Entreprise data successfully: {'_index': 'senegal_entreprises_data', '_id': 'AjIcvY0BWWw3zxq3nCY9', '_version': 1, 'result': 'created', '_shards': {'total': 1, 'successful': 1, 'failed': 0}, '_seq_no': 84, '_primary_term': 1}
# Entreprise data successfully: {'_index': 'senegal_entreprises_data', '_id': 'AzIcvY0BWWw3zxq3nCZC', '_version': 1, 'result': 'created', '_shards': {'total': 1, 'successful': 1, 'failed': 0}, '_seq_no': 85, '_primary_term': 1}
# Entreprise data successfully: {'_index': 'senegal_entreprises_data', '_id': 'BDIcvY0BWWw3zxq3nCZH', '_version': 1, 'result': 'created', '_shards': {'total': 1, 'successful': 1, 'failed': 0}, '_seq_no': 86, '_primary_term': 1}
# Entreprise data successfully: {'_index': 'senegal_entreprises_data', '_id': 'BTIcvY0BWWw3zxq3nCZM', '_version': 1, 'result': 'created', '_shards': {'total': 1, 'successful': 1, 'failed': 0}, '_seq_no': 87, '_primary_term': 1}
# Entreprise data successfully: {'_index': 'senegal_entreprises_data', '_id': 'BjIcvY0BWWw3zxq3nCZR', '_version': 1, 'result': 'created', '_shards': {'total': 1, 'successful': 1, 'failed': 0}, '_seq_no': 88, '_primary_term': 1}
# Entreprise data successfully: {'_index': 'senegal_entreprises_data', '_id': 'BzIcvY0BWWw3zxq3nCZW', '_version': 1, 'result': 'created', '_shards': {'total': 1, 'successful': 1, 'failed': 0}, '_seq_no': 89, '_primary_term': 1}
# Entreprise data successfully: {'_index': 'senegal_entreprises_data', '_id': 'CDIcvY0BWWw3zxq3nCZb', '_version': 1, 'result': 'created', '_shards': {'total': 1, 'successful': 1, 'failed': 0}, '_seq_no': 90, '_primary_term': 1}
# Entreprise data successfully: {'_index': 'senegal_entreprises_data', '_id': 'CTIcvY0BWWw3zxq3nCZf', '_version': 1, 'result': 'created', '_shards': {'total': 1, 'successful': 1, 'failed': 0}, '_seq_no': 91, '_primary_term': 1}
# Entreprise data successfully: {'_index': 'senegal_entreprises_data', '_id': 'CjIcvY0BWWw3zxq3nCZk', '_version': 1, 'result': 'created', '_shards': {'total': 1, 'successful': 1, 'failed': 0}, '_seq_no': 92, '_primary_term': 1}
# Entreprise data successfully: {'_index': 'senegal_entreprises_data', '_id': 'CzIcvY0BWWw3zxq3nCZo', '_version': 1, 'result': 'created', '_shards': {'total': 1, 'successful': 1, 'failed': 0}, '_seq_no': 93, '_primary_term': 1}
# Entreprise data successfully: {'_index': 'senegal_entreprises_data', '_id': 'DDIcvY0BWWw3zxq3nCZs', '_version': 1, 'result': 'created', '_shards': {'total': 1, 'successful': 1, 'failed': 0}, '_seq_no': 94, '_primary_term': 1}
# Entreprise data successfully: {'_index': 'senegal_entreprises_data', '_id': 'DTIcvY0BWWw3zxq3nCZx', '_version': 1, 'result': 'created', '_shards': {'total': 1, 'successful': 1, 'failed': 0}, '_seq_no': 95, '_primary_term': 1}
# Entreprise data successfully: {'_index': 'senegal_entreprises_data', '_id': 'DjIcvY0BWWw3zxq3nCZ3', '_version': 1, 'result': 'created', '_shards': {'total': 1, 'successful': 1, 'failed': 0}, '_seq_no': 96, '_primary_term': 1}
# Entreprise data successfully: {'_index': 'senegal_entreprises_data', '_id': 'DzIcvY0BWWw3zxq3nCZ7', '_version': 1, 'result': 'created', '_shards': {'total': 1, 'successful': 1, 'failed': 0}, '_seq_no': 97, '_primary_term': 1}
# Entreprise data successfully: {'_index': 'senegal_entreprises_data', '_id': 'EDIcvY0BWWw3zxq3nCZ_', '_version': 1, 'result': 'created', '_shards': {'total': 1, 'successful': 1, 'failed': 0}, '_seq_no': 98, '_primary_term': 1}
# Entreprise data successfully: {'_index': 'senegal_entreprises_data', '_id': 'ETIcvY0BWWw3zxq3nCaF', '_version': 1, 'result': 'created', '_shards': {'total': 1, 'successful': 1, 'failed': 0}, '_seq_no': 99, '_primary_term': 1}
# Entreprise data successfully: {'_index': 'senegal_entreprises_data', '_id': 'EjIcvY0BWWw3zxq3nCaK', '_version': 1, 'result': 'created', '_shards': {'total': 1, 'successful': 1, 'failed': 0}, '_seq_no': 100, '_primary_term': 1}
# Entreprise data successfully: {'_index': 'senegal_entreprises_data', '_id': 'EzIcvY0BWWw3zxq3nCaP', '_version': 1, 'result': 'created', '_shards': {'total': 1, 'successful': 1, 'failed': 0}, '_seq_no': 101, '_primary_term': 1}
# Entreprise data successfully: {'_index': 'senegal_entreprises_data', '_id': 'FDIcvY0BWWw3zxq3nCaV', '_version': 1, 'result': 'created', '_shards': {'total': 1, 'successful': 1, 'failed': 0}, '_seq_no': 102, '_primary_term': 1}
# Entreprise data successfully: {'_index': 'senegal_entreprises_data', '_id': 'FTIcvY0BWWw3zxq3nCaa', '_version': 1, 'result': 'created', '_shards': {'total': 1, 'successful': 1, 'failed': 0}, '_seq_no': 103, '_primary_term': 1}
# Entreprise data successfully: {'_index': 'senegal_entreprises_data', '_id': 'FjIcvY0BWWw3zxq3nCag', '_version': 1, 'result': 'created', '_shards': {'total': 1, 'successful': 1, 'failed': 0}, '_seq_no': 104, '_primary_term': 1}
# Entreprise data successfully: {'_index': 'senegal_entreprises_data', '_id': 'FzIcvY0BWWw3zxq3nCan', '_version': 1, 'result': 'created', '_shards': {'total': 1, 'successful': 1, 'failed': 0}, '_seq_no': 105, '_primary_term': 1}
# Entreprise data successfully: {'_index': 'senegal_entreprises_data', '_id': 'GDIcvY0BWWw3zxq3nCat', '_version': 1, 'result': 'created', '_shards': {'total': 1, 'successful': 1, 'failed': 0}, '_seq_no': 106, '_primary_term': 1}
# Entreprise data successfully: {'_index': 'senegal_entreprises_data', '_id': 'GTIcvY0BWWw3zxq3nCay', '_version': 1, 'result': 'created', '_shards': {'total': 1, 'successful': 1, 'failed': 0}, '_seq_no': 107, '_primary_term': 1}
# Entreprise data successfully: {'_index': 'senegal_entreprises_data', '_id': 'GjIcvY0BWWw3zxq3nCa5', '_version': 1, 'result': 'created', '_shards': {'total': 1, 'successful': 1, 'failed': 0}, '_seq_no': 108, '_primary_term': 1}
# Entreprise data successfully: {'_index': 'senegal_entreprises_data', '_id': 'GzIcvY0BWWw3zxq3nCa-', '_version': 1, 'result': 'created', '_shards': {'total': 1, 'successful': 1, 'failed': 0}, '_seq_no': 109, '_primary_term': 1}
# Entreprise data successfully: {'_index': 'senegal_entreprises_data', '_id': 'HDIcvY0BWWw3zxq3nCbD', '_version': 1, 'result': 'created', '_shards': {'total': 1, 'successful': 1, 'failed': 0}, '_seq_no': 110, '_primary_term': 1}
# Entreprise data successfully: {'_index': 'senegal_entreprises_data', '_id': 'HTIcvY0BWWw3zxq3nCbK', '_version': 1, 'result': 'created', '_shards': {'total': 1, 'successful': 1, 'failed': 0}, '_seq_no': 111, '_primary_term': 1}
# Entreprise data successfully: {'_index': 'senegal_entreprises_data', '_id': 'HjIcvY0BWWw3zxq3nCbP', '_version': 1, 'result': 'created', '_shards': {'total': 1, 'successful': 1, 'failed': 0}, '_seq_no': 112, '_primary_term': 1}
# Entreprise data successfully: {'_index': 'senegal_entreprises_data', '_id': 'HzIcvY0BWWw3zxq3nCbV', '_version': 1, 'result': 'created', '_shards': {'total': 1, 'successful': 1, 'failed': 0}, '_seq_no': 113, '_primary_term': 1}
# Entreprise data successfully: {'_index': 'senegal_entreprises_data', '_id': 'IDIcvY0BWWw3zxq3nCbc', '_version': 1, 'result': 'created', '_shards': {'total': 1, 'successful': 1, 'failed': 0}, '_seq_no': 114, '_primary_term': 1}
# Entreprise data successfully: {'_index': 'senegal_entreprises_data', '_id': 'ITIcvY0BWWw3zxq3nCbi', '_version': 1, 'result': 'created', '_shards': {'total': 1, 'successful': 1, 'failed': 0}, '_seq_no': 115, '_primary_term': 1}
# Entreprise data successfully: {'_index': 'senegal_entreprises_data', '_id': 'IjIcvY0BWWw3zxq3nCbn', '_version': 1, 'result': 'created', '_shards': {'total': 1, 'successful': 1, 'failed': 0}, '_seq_no': 116, '_primary_term': 1}
# Entreprise data successfully: {'_index': 'senegal_entreprises_data', '_id': 'IzIcvY0BWWw3zxq3nCbu', '_version': 1, 'result': 'created', '_shards': {'total': 1, 'successful': 1, 'failed': 0}, '_seq_no': 117, '_primary_term': 1}
# Entreprise data successfully: {'_index': 'senegal_entreprises_data', '_id': 'JDIcvY0BWWw3zxq3nCby', '_version': 1, 'result': 'created', '_shards': {'total': 1, 'successful': 1, 'failed': 0}, '_seq_no': 118, '_primary_term': 1}
# Entreprise data successfully: {'_index': 'senegal_entreprises_data', '_id': 'JTIcvY0BWWw3zxq3nCb4', '_version': 1, 'result': 'created', '_shards': {'total': 1, 'successful': 1, 'failed': 0}, '_seq_no': 119, '_primary_term': 1}
# Entreprise data successfully: {'_index': 'senegal_entreprises_data', '_id': 'JjIcvY0BWWw3zxq3nCb_', '_version': 1, 'result': 'created', '_shards': {'total': 1, 'successful': 1, 'failed': 0}, '_seq_no': 120, '_primary_term': 1}
# Entreprise data successfully: {'_index': 'senegal_entreprises_data', '_id': 'JzIcvY0BWWw3zxq3nSYE', '_version': 1, 'result': 'created', '_shards': {'total': 1, 'successful': 1, 'failed': 0}, '_seq_no': 121, '_primary_term': 1}
# Entreprise data successfully: {'_index': 'senegal_entreprises_data', '_id': 'KDIcvY0BWWw3zxq3nSYK', '_version': 1, 'result': 'created', '_shards': {'total': 1, 'successful': 1, 'failed': 0}, '_seq_no': 122, '_primary_term': 1}
# Entreprise data successfully: {'_index': 'senegal_entreprises_data', '_id': 'KTIcvY0BWWw3zxq3nSYR', '_version': 1, 'result': 'created', '_shards': {'total': 1, 'successful': 1, 'failed': 0}, '_seq_no': 123, '_primary_term': 1}
# Entreprise data successfully: {'_index': 'senegal_entreprises_data', '_id': 'KjIcvY0BWWw3zxq3nSYV', '_version': 1, 'result': 'created', '_shards': {'total': 1, 'successful': 1, 'failed': 0}, '_seq_no': 124, '_primary_term': 1}
# Entreprise data successfully: {'_index': 'senegal_entreprises_data', '_id': 'KzIcvY0BWWw3zxq3nSYb', '_version': 1, 'result': 'created', '_shards': {'total': 1, 'successful': 1, 'failed': 0}, '_seq_no': 125, '_primary_term': 1}
# Entreprise data successfully: {'_index': 'senegal_entreprises_data', '_id': 'LDIcvY0BWWw3zxq3nSYh', '_version': 1, 'result': 'created', '_shards': {'total': 1, 'successful': 1, 'failed': 0}, '_seq_no': 126, '_primary_term': 1}
# Entreprise data successfully: {'_index': 'senegal_entreprises_data', '_id': 'LTIcvY0BWWw3zxq3nSYm', '_version': 1, 'result': 'created', '_shards': {'total': 1, 'successful': 1, 'failed': 0}, '_seq_no': 127, '_primary_term': 1}
# Entreprise data successfully: {'_index': 'senegal_entreprises_data', '_id': 'LjIcvY0BWWw3zxq3nSYr', '_version': 1, 'result': 'created', '_shards': {'total': 1, 'successful': 1, 'failed': 0}, '_seq_no': 128, '_primary_term': 1}
# Entreprise data successfully: {'_index': 'senegal_entreprises_data', '_id': 'LzIcvY0BWWw3zxq3nSYw', '_version': 1, 'result': 'created', '_shards': {'total': 1, 'successful': 1, 'failed': 0}, '_seq_no': 129, '_primary_term': 1}
# Entreprise data successfully: {'_index': 'senegal_entreprises_data', '_id': 'MDIcvY0BWWw3zxq3nSY0', '_version': 1, 'result': 'created', '_shards': {'total': 1, 'successful': 1, 'failed': 0}, '_seq_no': 130, '_primary_term': 1}
# Entreprise data successfully: {'_index': 'senegal_entreprises_data', '_id': 'MTIcvY0BWWw3zxq3nSY5', '_version': 1, 'result': 'created', '_shards': {'total': 1, 'successful': 1, 'failed': 0}, '_seq_no': 131, '_primary_term': 1}
# Entreprise data successfully: {'_index': 'senegal_entreprises_data', '_id': 'MjIcvY0BWWw3zxq3nSY-', '_version': 1, 'result': 'created', '_shards': {'total': 1, 'successful': 1, 'failed': 0}, '_seq_no': 132, '_primary_term': 1}
# Entreprise data successfully: {'_index': 'senegal_entreprises_data', '_id': 'MzIcvY0BWWw3zxq3nSZC', '_version': 1, 'result': 'created', '_shards': {'total': 1, 'successful': 1, 'failed': 0}, '_seq_no': 133, '_primary_term': 1}
# Entreprise data successfully: {'_index': 'senegal_entreprises_data', '_id': 'NDIcvY0BWWw3zxq3nSZH', '_version': 1, 'result': 'created', '_shards': {'total': 1, 'successful': 1, 'failed': 0}, '_seq_no': 134, '_primary_term': 1}
# Entreprise data successfully: {'_index': 'senegal_entreprises_data', '_id': 'NTIcvY0BWWw3zxq3nSZM', '_version': 1, 'result': 'created', '_shards': {'total': 1, 'successful': 1, 'failed': 0}, '_seq_no': 135, '_primary_term': 1}
# Entreprise data successfully: {'_index': 'senegal_entreprises_data', '_id': 'NjIcvY0BWWw3zxq3nSZR', '_version': 1, 'result': 'created', '_shards': {'total': 1, 'successful': 1, 'failed': 0}, '_seq_no': 136, '_primary_term': 1}
# Entreprise data successfully: {'_index': 'senegal_entreprises_data', '_id': 'NzIcvY0BWWw3zxq3nSZV', '_version': 1, 'result': 'created', '_shards': {'total': 1, 'successful': 1, 'failed': 0}, '_seq_no': 137, '_primary_term': 1}
# Entreprise data successfully: {'_index': 'senegal_entreprises_data', '_id': 'ODIcvY0BWWw3zxq3nSZa', '_version': 1, 'result': 'created', '_shards': {'total': 1, 'successful': 1, 'failed': 0}, '_seq_no': 138, '_primary_term': 1}
# Entreprise data successfully: {'_index': 'senegal_entreprises_data', '_id': 'OTIcvY0BWWw3zxq3nSZf', '_version': 1, 'result': 'created', '_shards': {'total': 1, 'successful': 1, 'failed': 0}, '_seq_no': 139, '_primary_term': 1}
# Entreprise data successfully: {'_index': 'senegal_entreprises_data', '_id': 'OjIcvY0BWWw3zxq3nSZj', '_version': 1, 'result': 'created', '_shards': {'total': 1, 'successful': 1, 'failed': 0}, '_seq_no': 140, '_primary_term': 1}
# Entreprise data successfully: {'_index': 'senegal_entreprises_data', '_id': 'OzIcvY0BWWw3zxq3nSZp', '_version': 1, 'result': 'created', '_shards': {'total': 1, 'successful': 1, 'failed': 0}, '_seq_no': 141, '_primary_term': 1}
# Entreprise data successfully: {'_index': 'senegal_entreprises_data', '_id': 'PDIcvY0BWWw3zxq3nSZu', '_version': 1, 'result': 'created', '_shards': {'total': 1, 'successful': 1, 'failed': 0}, '_seq_no': 142, '_primary_term': 1}
# Entreprise data successfully: {'_index': 'senegal_entreprises_data', '_id': 'PTIcvY0BWWw3zxq3nSZ0', '_version': 1, 'result': 'created', '_shards': {'total': 1, 'successful': 1, 'failed': 0}, '_seq_no': 143, '_primary_term': 1}
# Entreprise data successfully: {'_index': 'senegal_entreprises_data', '_id': 'PjIcvY0BWWw3zxq3nSZ6', '_version': 1, 'result': 'created', '_shards': {'total': 1, 'successful': 1, 'failed': 0}, '_seq_no': 144, '_primary_term': 1}
# Entreprise data successfully: {'_index': 'senegal_entreprises_data', '_id': 'PzIcvY0BWWw3zxq3nSaA', '_version': 1, 'result': 'created', '_shards': {'total': 1, 'successful': 1, 'failed': 0}, '_seq_no': 145, '_primary_term': 1}
# Entreprise data successfully: {'_index': 'senegal_entreprises_data', '_id': 'QDIcvY0BWWw3zxq3nSaF', '_version': 1, 'result': 'created', '_shards': {'total': 1, 'successful': 1, 'failed': 0}, '_seq_no': 146, '_primary_term': 1}
# Entreprise data successfully: {'_index': 'senegal_entreprises_data', '_id': 'QTIcvY0BWWw3zxq3nSaK', '_version': 1, 'result': 'created', '_shards': {'total': 1, 'successful': 1, 'failed': 0}, '_seq_no': 147, '_primary_term': 1}
# Entreprise data successfully: {'_index': 'senegal_entreprises_data', '_id': 'QjIcvY0BWWw3zxq3nSaP', '_version': 1, 'result': 'created', '_shards': {'total': 1, 'successful': 1, 'failed': 0}, '_seq_no': 148, '_primary_term': 1}
# Entreprise data successfully: {'_index': 'senegal_entreprises_data', '_id': 'QzIcvY0BWWw3zxq3nSaU', '_version': 1, 'result': 'created', '_shards': {'total': 1, 'successful': 1, 'failed': 0}, '_seq_no': 149, '_primary_term': 1}
# Entreprise data successfully: {'_index': 'senegal_entreprises_data', '_id': 'RDIcvY0BWWw3zxq3nSaZ', '_version': 1, 'result': 'created', '_shards': {'total': 1, 'successful': 1, 'failed': 0}, '_seq_no': 150, '_primary_term': 1}
# Entreprise data successfully: {'_index': 'senegal_entreprises_data', '_id': 'RTIcvY0BWWw3zxq3nSae', '_version': 1, 'result': 'created', '_shards': {'total': 1, 'successful': 1, 'failed': 0}, '_seq_no': 151, '_primary_term': 1}
# Entreprise data successfully: {'_index': 'senegal_entreprises_data', '_id': 'RjIcvY0BWWw3zxq3nSal', '_version': 1, 'result': 'created', '_shards': {'total': 1, 'successful': 1, 'failed': 0}, '_seq_no': 152, '_primary_term': 1}
# Entreprise data successfully: {'_index': 'senegal_entreprises_data', '_id': 'RzIcvY0BWWw3zxq3nSap', '_version': 1, 'result': 'created', '_shards': {'total': 1, 'successful': 1, 'failed': 0}, '_seq_no': 153, '_primary_term': 1}
# Entreprise data successfully: {'_index': 'senegal_entreprises_data', '_id': 'SDIcvY0BWWw3zxq3nSau', '_version': 1, 'result': 'created', '_shards': {'total': 1, 'successful': 1, 'failed': 0}, '_seq_no': 154, '_primary_term': 1}
# Entreprise data successfully: {'_index': 'senegal_entreprises_data', '_id': 'STIcvY0BWWw3zxq3nSaz', '_version': 1, 'result': 'created', '_shards': {'total': 1, 'successful': 1, 'failed': 0}, '_seq_no': 155, '_primary_term': 1}
# Entreprise data successfully: {'_index': 'senegal_entreprises_data', '_id': 'SjIcvY0BWWw3zxq3nSa3', '_version': 1, 'result': 'created', '_shards': {'total': 1, 'successful': 1, 'failed': 0}, '_seq_no': 156, '_primary_term': 1}
# Entreprise data successfully: {'_index': 'senegal_entreprises_data', '_id': 'SzIcvY0BWWw3zxq3nSa8', '_version': 1, 'result': 'created', '_shards': {'total': 1, 'successful': 1, 'failed': 0}, '_seq_no': 157, '_primary_term': 1}
# Entreprise data successfully: {'_index': 'senegal_entreprises_data', '_id': 'TDIcvY0BWWw3zxq3nSbA', '_version': 1, 'result': 'created', '_shards': {'total': 1, 'successful': 1, 'failed': 0}, '_seq_no': 158, '_primary_term': 1}
# Entreprise data successfully: {'_index': 'senegal_entreprises_data', '_id': 'TTIcvY0BWWw3zxq3nSbF', '_version': 1, 'result': 'created', '_shards': {'total': 1, 'successful': 1, 'failed': 0}, '_seq_no': 159, '_primary_term': 1}
# Entreprise data successfully: {'_index': 'senegal_entreprises_data', '_id': 'TjIcvY0BWWw3zxq3nSbJ', '_version': 1, 'result': 'created', '_shards': {'total': 1, 'successful': 1, 'failed': 0}, '_seq_no': 160, '_primary_term': 1}
# Entreprise data successfully: {'_index': 'senegal_entreprises_data', '_id': 'TzIcvY0BWWw3zxq3nSbO', '_version': 1, 'result': 'created', '_shards': {'total': 1, 'successful': 1, 'failed': 0}, '_seq_no': 161, '_primary_term': 1}
# Entreprise data successfully: {'_index': 'senegal_entreprises_data', '_id': 'UDIcvY0BWWw3zxq3nSbU', '_version': 1, 'result': 'created', '_shards': {'total': 1, 'successful': 1, 'failed': 0}, '_seq_no': 162, '_primary_term': 1}
# Entreprise data successfully: {'_index': 'senegal_entreprises_data', '_id': 'UTIcvY0BWWw3zxq3nSbY', '_version': 1, 'result': 'created', '_shards': {'total': 1, 'successful': 1, 'failed': 0}, '_seq_no': 163, '_primary_term': 1}
# Entreprise data successfully: {'_index': 'senegal_entreprises_data', '_id': 'UjIcvY0BWWw3zxq3nSbc', '_version': 1, 'result': 'created', '_shards': {'total': 1, 'successful': 1, 'failed': 0}, '_seq_no': 164, '_primary_term': 1}
# Entreprise data successfully: {'_index': 'senegal_entreprises_data', '_id': 'UzIcvY0BWWw3zxq3nSbh', '_version': 1, 'result': 'created', '_shards': {'total': 1, 'successful': 1, 'failed': 0}, '_seq_no': 165, '_primary_term': 1}
# Entreprise data successfully: {'_index': 'senegal_entreprises_data', '_id': 'VDIcvY0BWWw3zxq3nSbl', '_version': 1, 'result': 'created', '_shards': {'total': 1, 'successful': 1, 'failed': 0}, '_seq_no': 166, '_primary_term': 1}
# Entreprise data successfully: {'_index': 'senegal_entreprises_data', '_id': 'VTIcvY0BWWw3zxq3nSbp', '_version': 1, 'result': 'created', '_shards': {'total': 1, 'successful': 1, 'failed': 0}, '_seq_no': 167, '_primary_term': 1}
# Entreprise data successfully: {'_index': 'senegal_entreprises_data', '_id': 'VjIcvY0BWWw3zxq3nSbu', '_version': 1, 'result': 'created', '_shards': {'total': 1, 'successful': 1, 'failed': 0}, '_seq_no': 168, '_primary_term': 1}
# Entreprise data successfully: {'_index': 'senegal_entreprises_data', '_id': 'VzIcvY0BWWw3zxq3nSbz', '_version': 1, 'result': 'created', '_shards': {'total': 1, 'successful': 1, 'failed': 0}, '_seq_no': 169, '_primary_term': 1}
# Entreprise data successfully: {'_index': 'senegal_entreprises_data', '_id': 'WDIcvY0BWWw3zxq3nSb5', '_version': 1, 'result': 'created', '_shards': {'total': 1, 'successful': 1, 'failed': 0}, '_seq_no': 170, '_primary_term': 1}
# Entreprise data successfully: {'_index': 'senegal_entreprises_data', '_id': 'WTIcvY0BWWw3zxq3nSb-', '_version': 1, 'result': 'created', '_shards': {'total': 1, 'successful': 1, 'failed': 0}, '_seq_no': 171, '_primary_term': 1}
# Entreprise data successfully: {'_index': 'senegal_entreprises_data', '_id': 'WjIcvY0BWWw3zxq3niYC', '_version': 1, 'result': 'created', '_shards': {'total': 1, 'successful': 1, 'failed': 0}, '_seq_no': 172, '_primary_term': 1}
# Entreprise data successfully: {'_index': 'senegal_entreprises_data', '_id': 'WzIcvY0BWWw3zxq3niYH', '_version': 1, 'result': 'created', '_shards': {'total': 1, 'successful': 1, 'failed': 0}, '_seq_no': 173, '_primary_term': 1}
# Entreprise data successfully: {'_index': 'senegal_entreprises_data', '_id': 'XDIcvY0BWWw3zxq3niYM', '_version': 1, 'result': 'created', '_shards': {'total': 1, 'successful': 1, 'failed': 0}, '_seq_no': 174, '_primary_term': 1}
# Entreprise data successfully: {'_index': 'senegal_entreprises_data', '_id': 'XTIcvY0BWWw3zxq3niYR', '_version': 1, 'result': 'created', '_shards': {'total': 1, 'successful': 1, 'failed': 0}, '_seq_no': 175, '_primary_term': 1}
# Entreprise data successfully: {'_index': 'senegal_entreprises_data', '_id': 'XjIcvY0BWWw3zxq3niYV', '_version': 1, 'result': 'created', '_shards': {'total': 1, 'successful': 1, 'failed': 0}, '_seq_no': 176, '_primary_term': 1}
# Entreprise data successfully: {'_index': 'senegal_entreprises_data', '_id': 'XzIcvY0BWWw3zxq3niYa', '_version': 1, 'result': 'created', '_shards': {'total': 1, 'successful': 1, 'failed': 0}, '_seq_no': 177, '_primary_term': 1}
# Entreprise data successfully: {'_index': 'senegal_entreprises_data', '_id': 'YDIcvY0BWWw3zxq3niYe', '_version': 1, 'result': 'created', '_shards': {'total': 1, 'successful': 1, 'failed': 0}, '_seq_no': 178, '_primary_term': 1}
# Entreprise data successfully: {'_index': 'senegal_entreprises_data', '_id': 'YTIcvY0BWWw3zxq3niYi', '_version': 1, 'result': 'created', '_shards': {'total': 1, 'successful': 1, 'failed': 0}, '_seq_no': 179, '_primary_term': 1}
# Entreprise data successfully: {'_index': 'senegal_entreprises_data', '_id': 'YjIcvY0BWWw3zxq3niYm', '_version': 1, 'result': 'created', '_shards': {'total': 1, 'successful': 1, 'failed': 0}, '_seq_no': 180, '_primary_term': 1}
# Entreprise data successfully: {'_index': 'senegal_entreprises_data', '_id': 'YzIcvY0BWWw3zxq3niYq', '_version': 1, 'result': 'created', '_shards': {'total': 1, 'successful': 1, 'failed': 0}, '_seq_no': 181, '_primary_term': 1}
# Entreprise data successfully: {'_index': 'senegal_entreprises_data', '_id': 'ZDIcvY0BWWw3zxq3niYu', '_version': 1, 'result': 'created', '_shards': {'total': 1, 'successful': 1, 'failed': 0}, '_seq_no': 182, '_primary_term': 1}
# Entreprise data successfully: {'_index': 'senegal_entreprises_data', '_id': 'ZTIcvY0BWWw3zxq3niYy', '_version': 1, 'result': 'created', '_shards': {'total': 1, 'successful': 1, 'failed': 0}, '_seq_no': 183, '_primary_term': 1}
# Entreprise data successfully: {'_index': 'senegal_entreprises_data', '_id': 'ZjIcvY0BWWw3zxq3niY3', '_version': 1, 'result': 'created', '_shards': {'total': 1, 'successful': 1, 'failed': 0}, '_seq_no': 184, '_primary_term': 1}
# Entreprise data successfully: {'_index': 'senegal_entreprises_data', '_id': 'ZzIcvY0BWWw3zxq3niY8', '_version': 1, 'result': 'created', '_shards': {'total': 1, 'successful': 1, 'failed': 0}, '_seq_no': 185, '_primary_term': 1}
# Entreprise data successfully: {'_index': 'senegal_entreprises_data', '_id': 'aDIcvY0BWWw3zxq3niZB', '_version': 1, 'result': 'created', '_shards': {'total': 1, 'successful': 1, 'failed': 0}, '_seq_no': 186, '_primary_term': 1}
# Entreprise data successfully: {'_index': 'senegal_entreprises_data', '_id': 'aTIcvY0BWWw3zxq3niZG', '_version': 1, 'result': 'created', '_shards': {'total': 1, 'successful': 1, 'failed': 0}, '_seq_no': 187, '_primary_term': 1}
# Entreprise data successfully: {'_index': 'senegal_entreprises_data', '_id': 'ajIcvY0BWWw3zxq3niZL', '_version': 1, 'result': 'created', '_shards': {'total': 1, 'successful': 1, 'failed': 0}, '_seq_no': 188, '_primary_term': 1}
# Entreprise data successfully: {'_index': 'senegal_entreprises_data', '_id': 'azIcvY0BWWw3zxq3niZP', '_version': 1, 'result': 'created', '_shards': {'total': 1, 'successful': 1, 'failed': 0}, '_seq_no': 189, '_primary_term': 1}
# Entreprise data successfully: {'_index': 'senegal_entreprises_data', '_id': 'bDIcvY0BWWw3zxq3niZT', '_version': 1, 'result': 'created', '_shards': {'total': 1, 'successful': 1, 'failed': 0}, '_seq_no': 190, '_primary_term': 1}
# Entreprise data successfully: {'_index': 'senegal_entreprises_data', '_id': 'bTIcvY0BWWw3zxq3niZX', '_version': 1, 'result': 'created', '_shards': {'total': 1, 'successful': 1, 'failed': 0}, '_seq_no': 191, '_primary_term': 1}
# Entreprise data successfully: {'_index': 'senegal_entreprises_data', '_id': 'bjIcvY0BWWw3zxq3niZb', '_version': 1, 'result': 'created', '_shards': {'total': 1, 'successful': 1, 'failed': 0}, '_seq_no': 192, '_primary_term': 1}
# Entreprise data successfully: {'_index': 'senegal_entreprises_data', '_id': 'bzIcvY0BWWw3zxq3niZw', '_version': 1, 'result': 'created', '_shards': {'total': 1, 'successful': 1, 'failed': 0}, '_seq_no': 193, '_primary_term': 1}
# Entreprise data successfully: {'_index': 'senegal_entreprises_data', '_id': 'cDIcvY0BWWw3zxq3niZ2', '_version': 1, 'result': 'created', '_shards': {'total': 1, 'successful': 1, 'failed': 0}, '_seq_no': 194, '_primary_term': 1}
# Entreprise data successfully: {'_index': 'senegal_entreprises_data', '_id': 'cTIcvY0BWWw3zxq3niZ7', '_version': 1, 'result': 'created', '_shards': {'total': 1, 'successful': 1, 'failed': 0}, '_seq_no': 195, '_primary_term': 1}
# Entreprise data successfully: {'_index': 'senegal_entreprises_data', '_id': 'cjIcvY0BWWw3zxq3niZ_', '_version': 1, 'result': 'created', '_shards': {'total': 1, 'successful': 1, 'failed': 0}, '_seq_no': 196, '_primary_term': 1}
# Entreprise data successfully: {'_index': 'senegal_entreprises_data', '_id': 'czIcvY0BWWw3zxq3niaE', '_version': 1, 'result': 'created', '_shards': {'total': 1, 'successful': 1, 'failed': 0}, '_seq_no': 197, '_primary_term': 1}
# Entreprise data successfully: {'_index': 'senegal_entreprises_data', '_id': 'dDIcvY0BWWw3zxq3niaJ', '_version': 1, 'result': 'created', '_shards': {'total': 1, 'successful': 1, 'failed': 0}, '_seq_no': 198, '_primary_term': 1}
# Entreprise data successfully: {'_index': 'senegal_entreprises_data', '_id': 'dTIcvY0BWWw3zxq3niaP', '_version': 1, 'result': 'created', '_shards': {'total': 1, 'successful': 1, 'failed': 0}, '_seq_no': 199, '_primary_term': 1}
# Entreprise data successfully: {'_index': 'senegal_entreprises_data', '_id': 'djIcvY0BWWw3zxq3niaW', '_version': 1, 'result': 'created', '_shards': {'total': 1, 'successful': 1, 'failed': 0}, '_seq_no': 200, '_primary_term': 1}
# Entreprise data successfully: {'_index': 'senegal_entreprises_data', '_id': 'dzIcvY0BWWw3zxq3niau', '_version': 1, 'result': 'created', '_shards': {'total': 1, 'successful': 1, 'failed': 0}, '_seq_no': 201, '_primary_term': 1}
# Entreprise data successfully: {'_index': 'senegal_entreprises_data', '_id': 'eDIcvY0BWWw3zxq3nia0', '_version': 1, 'result': 'created', '_shards': {'total': 1, 'successful': 1, 'failed': 0}, '_seq_no': 202, '_primary_term': 1}
# Entreprise data successfully: {'_index': 'senegal_entreprises_data', '_id': 'eTIcvY0BWWw3zxq3nia5', '_version': 1, 'result': 'created', '_shards': {'total': 1, 'successful': 1, 'failed': 0}, '_seq_no': 203, '_primary_term': 1}
# Entreprise data successfully: {'_index': 'senegal_entreprises_data', '_id': 'ejIcvY0BWWw3zxq3nibB', '_version': 1, 'result': 'created', '_shards': {'total': 1, 'successful': 1, 'failed': 0}, '_seq_no': 204, '_primary_term': 1}
# Entreprise data successfully: {'_index': 'senegal_entreprises_data', '_id': 'ezIcvY0BWWw3zxq3nibG', '_version': 1, 'result': 'created', '_shards': {'total': 1, 'successful': 1, 'failed': 0}, '_seq_no': 205, '_primary_term': 1}
# Entreprise data successfully: {'_index': 'senegal_entreprises_data', '_id': 'fDIcvY0BWWw3zxq3nibL', '_version': 1, 'result': 'created', '_shards': {'total': 1, 'successful': 1, 'failed': 0}, '_seq_no': 206, '_primary_term': 1}
# Entreprise data successfully: {'_index': 'senegal_entreprises_data', '_id': 'fTIcvY0BWWw3zxq3nibP', '_version': 1, 'result': 'created', '_shards': {'total': 1, 'successful': 1, 'failed': 0}, '_seq_no': 207, '_primary_term': 1}
# Entreprise data successfully: {'_index': 'senegal_entreprises_data', '_id': 'fjIcvY0BWWw3zxq3nibU', '_version': 1, 'result': 'created', '_shards': {'total': 1, 'successful': 1, 'failed': 0}, '_seq_no': 208, '_primary_term': 1}
# Entreprise data successfully: {'_index': 'senegal_entreprises_data', '_id': 'fzIcvY0BWWw3zxq3nibY', '_version': 1, 'result': 'created', '_shards': {'total': 1, 'successful': 1, 'failed': 0}, '_seq_no': 209, '_primary_term': 1}
# Entreprise data successfully: {'_index': 'senegal_entreprises_data', '_id': 'gDIcvY0BWWw3zxq3nibd', '_version': 1, 'result': 'created', '_shards': {'total': 1, 'successful': 1, 'failed': 0}, '_seq_no': 210, '_primary_term': 1}
# ...
# Entreprise data successfully: {'_index': 'senegal_entreprises_data', '_id': 'nDIcvY0BWWw3zxq32DY3', '_version': 1, 'result': 'created', '_shards': {'total': 1, 'successful': 1, 'failed': 0}, '_seq_no': 4334, '_primary_term': 1}
# Entreprise data successfully: {'_index': 'senegal_entreprises_data', '_id': 'nTIcvY0BWWw3zxq32DY7', '_version': 1, 'result': 'created', '_shards': {'total': 1, 'successful': 1, 'failed': 0}, '_seq_no': 4335, '_primary_term': 1}
# Entreprise data successfully: {'_index': 'senegal_entreprises_data', '_id': 'njIcvY0BWWw3zxq32DY-', '_version': 1, 'result': 'created', '_shards': {'total': 1, 'successful': 1, 'failed': 0}, '_seq_no': 4336, '_primary_term': 1}
# Entreprise data successfully: {'_index': 'senegal_entreprises_data', '_id': 'nzIcvY0BWWw3zxq32DZB', '_version': 1, 'result': 'created', '_shards': {'total': 1, 'successful': 1, 'failed': 0}, '_seq_no': 4337, '_primary_term': 1}
# Entreprise data successfully: {'_index': 'senegal_entreprises_data', '_id': 'oDIcvY0BWWw3zxq32DZD', '_version': 1, 'result': 'created', '_shards': {'total': 1, 'successful': 1, 'failed': 0}, '_seq_no': 4338, '_primary_term': 1}
# Entreprise data successfully: {'_index': 'senegal_entreprises_data', '_id': 'oTIcvY0BWWw3zxq32DZG', '_version': 1, 'result': 'created', '_shards': {'total': 1, 'successful': 1, 'failed': 0}, '_seq_no': 4339, '_primary_term': 1}
# Entreprise data successfully: {'_index': 'senegal_entreprises_data', '_id': 'ojIcvY0BWWw3zxq32DZJ', '_version': 1, 'result': 'created', '_shards': {'total': 1, 'successful': 1, 'failed': 0}, '_seq_no': 4340, '_primary_term': 1}
# Entreprise data successfully: {'_index': 'senegal_entreprises_data', '_id': 'ozIcvY0BWWw3zxq32DZM', '_version': 1, 'result': 'created', '_shards': {'total': 1, 'successful': 1, 'failed': 0}, '_seq_no': 4341, '_primary_term': 1}
# Entreprise data successfully: {'_index': 'senegal_entreprises_data', '_id': 'pDIcvY0BWWw3zxq32DZP', '_version': 1, 'result': 'created', '_shards': {'total': 1, 'successful': 1, 'failed': 0}, '_seq_no': 4342, '_primary_term': 1}
# Entreprise data successfully: {'_index': 'senegal_entreprises_data', '_id': 'pTIcvY0BWWw3zxq32DZS', '_version': 1, 'result': 'created', '_shards': {'total': 1, 'successful': 1, 'failed': 0}, '_seq_no': 4343, '_primary_term': 1}
# Entreprise data successfully: {'_index': 'senegal_entreprises_data', '_id': 'pjIcvY0BWWw3zxq32DZV', '_version': 1, 'result': 'created', '_shards': {'total': 1, 'successful': 1, 'failed': 0}, '_seq_no': 4344, '_primary_term': 1}
# Entreprise data successfully: {'_index': 'senegal_entreprises_data', '_id': 'pzIcvY0BWWw3zxq32DZY', '_version': 1, 'result': 'created', '_shards': {'total': 1, 'successful': 1, 'failed': 0}, '_seq_no': 4345, '_primary_term': 1}
# Entreprise data successfully: {'_index': 'senegal_entreprises_data', '_id': 'qDIcvY0BWWw3zxq32DZb', '_version': 1, 'result': 'created', '_shards': {'total': 1, 'successful': 1, 'failed': 0}, '_seq_no': 4346, '_primary_term': 1}
# Entreprise data successfully: {'_index': 'senegal_entreprises_data', '_id': 'qTIcvY0BWWw3zxq32DZf', '_version': 1, 'result': 'created', '_shards': {'total': 1, 'successful': 1, 'failed': 0}, '_seq_no': 4347, '_primary_term': 1}
# Entreprise data successfully: {'_index': 'senegal_entreprises_data', '_id': 'qjIcvY0BWWw3zxq32DZi', '_version': 1, 'result': 'created', '_shards': {'total': 1, 'successful': 1, 'failed': 0}, '_seq_no': 4348, '_primary_term': 1}
# Entreprise data successfully: {'_index': 'senegal_entreprises_data', '_id': 'qzIcvY0BWWw3zxq32DZl', '_version': 1, 'result': 'created', '_shards': {'total': 1, 'successful': 1, 'failed': 0}, '_seq_no': 4349, '_primary_term': 1}
# Entreprise data successfully: {'_index': 'senegal_entreprises_data', '_id': 'rDIcvY0BWWw3zxq32DZp', '_version': 1, 'result': 'created', '_shards': {'total': 1, 'successful': 1, 'failed': 0}, '_seq_no': 4350, '_primary_term': 1}
# Entreprise data successfully: {'_index': 'senegal_entreprises_data', '_id': 'rTIcvY0BWWw3zxq32DZs', '_version': 1, 'result': 'created', '_shards': {'total': 1, 'successful': 1, 'failed': 0}, '_seq_no': 4351, '_primary_term': 1}
# Entreprise data successfully: {'_index': 'senegal_entreprises_data', '_id': 'rjIcvY0BWWw3zxq32DZv', '_version': 1, 'result': 'created', '_shards': {'total': 1, 'successful': 1, 'failed': 0}, '_seq_no': 4352, '_primary_term': 1}
# Entreprise data successfully: {'_index': 'senegal_entreprises_data', '_id': 'rzIcvY0BWWw3zxq32DZy', '_version': 1, 'result': 'created', '_shards': {'total': 1, 'successful': 1, 'failed': 0}, '_seq_no': 4353, '_primary_term': 1}
# Entreprise data successfully: {'_index': 'senegal_entreprises_data', '_id': 'sDIcvY0BWWw3zxq32DZ0', '_version': 1, 'result': 'created', '_shards': {'total': 1, 'successful': 1, 'failed': 0}, '_seq_no': 4354, '_primary_term': 1}
# Entreprise data successfully: {'_index': 'senegal_entreprises_data', '_id': 'sTIcvY0BWWw3zxq32DZ3', '_version': 1, 'result': 'created', '_shards': {'total': 1, 'successful': 1, 'failed': 0}, '_seq_no': 4355, '_primary_term': 1}
# Entreprise data successfully: {'_index': 'senegal_entreprises_data', '_id': 'sjIcvY0BWWw3zxq32DZ6', '_version': 1, 'result': 'created', '_shards': {'total': 1, 'successful': 1, 'failed': 0}, '_seq_no': 4356, '_primary_term': 1}
# Entreprise data successfully: {'_index': 'senegal_entreprises_data', '_id': 'szIcvY0BWWw3zxq32DZ9', '_version': 1, 'result': 'created', '_shards': {'total': 1, 'successful': 1, 'failed': 0}, '_seq_no': 4357, '_primary_term': 1}
# Entreprise data successfully: {'_index': 'senegal_entreprises_data', '_id': 'tDIcvY0BWWw3zxq32DaA', '_version': 1, 'result': 'created', '_shards': {'total': 1, 'successful': 1, 'failed': 0}, '_seq_no': 4358, '_primary_term': 1}
# Entreprise data successfully: {'_index': 'senegal_entreprises_data', '_id': 'tTIcvY0BWWw3zxq32DaD', '_version': 1, 'result': 'created', '_shards': {'total': 1, 'successful': 1, 'failed': 0}, '_seq_no': 4359, '_primary_term': 1}
# Entreprise data successfully: {'_index': 'senegal_entreprises_data', '_id': 'tjIcvY0BWWw3zxq32DaF', '_version': 1, 'result': 'created', '_shards': {'total': 1, 'successful': 1, 'failed': 0}, '_seq_no': 4360, '_primary_term': 1}
# Entreprise data successfully: {'_index': 'senegal_entreprises_data', '_id': 'tzIcvY0BWWw3zxq32DaI', '_version': 1, 'result': 'created', '_shards': {'total': 1, 'successful': 1, 'failed': 0}, '_seq_no': 4361, '_primary_term': 1}
# Entreprise data successfully: {'_index': 'senegal_entreprises_data', '_id': 'uDIcvY0BWWw3zxq32DaK', '_version': 1, 'result': 'created', '_shards': {'total': 1, 'successful': 1, 'failed': 0}, '_seq_no': 4362, '_primary_term': 1}
# Entreprise data successfully: {'_index': 'senegal_entreprises_data', '_id': 'uTIcvY0BWWw3zxq32DaN', '_version': 1, 'result': 'created', '_shards': {'total': 1, 'successful': 1, 'failed': 0}, '_seq_no': 4363, '_primary_term': 1}
# Entreprise data successfully: {'_index': 'senegal_entreprises_data', '_id': 'ujIcvY0BWWw3zxq32DaP', '_version': 1, 'result': 'created', '_shards': {'total': 1, 'successful': 1, 'failed': 0}, '_seq_no': 4364, '_primary_term': 1}
# Entreprise data successfully: {'_index': 'senegal_entreprises_data', '_id': 'uzIcvY0BWWw3zxq32DaS', '_version': 1, 'result': 'created', '_shards': {'total': 1, 'successful': 1, 'failed': 0}, '_seq_no': 4365, '_primary_term': 1}
# Entreprise data successfully: {'_index': 'senegal_entreprises_data', '_id': 'vDIcvY0BWWw3zxq32DaV', '_version': 1, 'result': 'created', '_shards': {'total': 1, 'successful': 1, 'failed': 0}, '_seq_no': 4366, '_primary_term': 1}
# Entreprise data successfully: {'_index': 'senegal_entreprises_data', '_id': 'vTIcvY0BWWw3zxq32DaY', '_version': 1, 'result': 'created', '_shards': {'total': 1, 'successful': 1, 'failed': 0}, '_seq_no': 4367, '_primary_term': 1}
# Entreprise data successfully: {'_index': 'senegal_entreprises_data', '_id': 'vjIcvY0BWWw3zxq32Daa', '_version': 1, 'result': 'created', '_shards': {'total': 1, 'successful': 1, 'failed': 0}, '_seq_no': 4368, '_primary_term': 1}
# Entreprise data successfully: {'_index': 'senegal_entreprises_data', '_id': 'vzIcvY0BWWw3zxq32Dad', '_version': 1, 'result': 'created', '_shards': {'total': 1, 'successful': 1, 'failed': 0}, '_seq_no': 4369, '_primary_term': 1}
# Entreprise data successfully: {'_index': 'senegal_entreprises_data', '_id': 'wDIcvY0BWWw3zxq32Dag', '_version': 1, 'result': 'created', '_shards': {'total': 1, 'successful': 1, 'failed': 0}, '_seq_no': 4370, '_primary_term': 1}
# Entreprise data successfully: {'_index': 'senegal_entreprises_data', '_id': 'wTIcvY0BWWw3zxq32Daj', '_version': 1, 'result': 'created', '_shards': {'total': 1, 'successful': 1, 'failed': 0}, '_seq_no': 4371, '_primary_term': 1}
# Entreprise data successfully: {'_index': 'senegal_entreprises_data', '_id': 'wjIcvY0BWWw3zxq32Dal', '_version': 1, 'result': 'created', '_shards': {'total': 1, 'successful': 1, 'failed': 0}, '_seq_no': 4372, '_primary_term': 1}
# Entreprise data successfully: {'_index': 'senegal_entreprises_data', '_id': 'wzIcvY0BWWw3zxq32Dao', '_version': 1, 'result': 'created', '_shards': {'total': 1, 'successful': 1, 'failed': 0}, '_seq_no': 4373, '_primary_term': 1}
# Entreprise data successfully: {'_index': 'senegal_entreprises_data', '_id': 'xDIcvY0BWWw3zxq32Dar', '_version': 1, 'result': 'created', '_shards': {'total': 1, 'successful': 1, 'failed': 0}, '_seq_no': 4374, '_primary_term': 1}
# Entreprise data successfully: {'_index': 'senegal_entreprises_data', '_id': 'xTIcvY0BWWw3zxq32Dau', '_version': 1, 'result': 'created', '_shards': {'total': 1, 'successful': 1, 'failed': 0}, '_seq_no': 4375, '_primary_term': 1}
# Entreprise data successfully: {'_index': 'senegal_entreprises_data', '_id': 'xjIcvY0BWWw3zxq32Daw', '_version': 1, 'result': 'created', '_shards': {'total': 1, 'successful': 1, 'failed': 0}, '_seq_no': 4376, '_primary_term': 1}
# Entreprise data successfully: {'_index': 'senegal_entreprises_data', '_id': 'xzIcvY0BWWw3zxq32Daz', '_version': 1, 'result': 'created', '_shards': {'total': 1, 'successful': 1, 'failed': 0}, '_seq_no': 4377, '_primary_term': 1}
# Entreprise data successfully: {'_index': 'senegal_entreprises_data', '_id': 'yDIcvY0BWWw3zxq32Da2', '_version': 1, 'result': 'created', '_shards': {'total': 1, 'successful': 1, 'failed': 0}, '_seq_no': 4378, '_primary_term': 1}
# Entreprise data successfully: {'_index': 'senegal_entreprises_data', '_id': 'yTIcvY0BWWw3zxq32Da4', '_version': 1, 'result': 'created', '_shards': {'total': 1, 'successful': 1, 'failed': 0}, '_seq_no': 4379, '_primary_term': 1}
# Entreprise data successfully: {'_index': 'senegal_entreprises_data', '_id': 'yjIcvY0BWWw3zxq32Da7', '_version': 1, 'result': 'created', '_shards': {'total': 1, 'successful': 1, 'failed': 0}, '_seq_no': 4380, '_primary_term': 1}
# Entreprise data successfully: {'_index': 'senegal_entreprises_data', '_id': 'yzIcvY0BWWw3zxq32Da_', '_version': 1, 'result': 'created', '_shards': {'total': 1, 'successful': 1, 'failed': 0}, '_seq_no': 4381, '_primary_term': 1}
# Entreprise data successfully: {'_index': 'senegal_entreprises_data', '_id': 'zDIcvY0BWWw3zxq32DbB', '_version': 1, 'result': 'created', '_shards': {'total': 1, 'successful': 1, 'failed': 0}, '_seq_no': 4382, '_primary_term': 1}
# Entreprise data successfully: {'_index': 'senegal_entreprises_data', '_id': 'zTIcvY0BWWw3zxq32DbE', '_version': 1, 'result': 'created', '_shards': {'total': 1, 'successful': 1, 'failed': 0}, '_seq_no': 4383, '_primary_term': 1}
# Entreprise data successfully: {'_index': 'senegal_entreprises_data', '_id': 'zjIcvY0BWWw3zxq32DbG', '_version': 1, 'result': 'created', '_shards': {'total': 1, 'successful': 1, 'failed': 0}, '_seq_no': 4384, '_primary_term': 1}
# Entreprise data successfully: {'_index': 'senegal_entreprises_data', '_id': 'zzIcvY0BWWw3zxq32DbJ', '_version': 1, 'result': 'created', '_shards': {'total': 1, 'successful': 1, 'failed': 0}, '_seq_no': 4385, '_primary_term': 1}
# Entreprise data successfully: {'_index': 'senegal_entreprises_data', '_id': '0DIcvY0BWWw3zxq32DbL', '_version': 1, 'result': 'created', '_shards': {'total': 1, 'successful': 1, 'failed': 0}, '_seq_no': 4386, '_primary_term': 1}
# Entreprise data successfully: {'_index': 'senegal_entreprises_data', '_id': '0TIcvY0BWWw3zxq32DbO', '_version': 1, 'result': 'created', '_shards': {'total': 1, 'successful': 1, 'failed': 0}, '_seq_no': 4387, '_primary_term': 1}
# Entreprise data successfully: {'_index': 'senegal_entreprises_data', '_id': '0jIcvY0BWWw3zxq32DbR', '_version': 1, 'result': 'created', '_shards': {'total': 1, 'successful': 1, 'failed': 0}, '_seq_no': 4388, '_primary_term': 1}
# Entreprise data successfully: {'_index': 'senegal_entreprises_data', '_id': '0zIcvY0BWWw3zxq32DbT', '_version': 1, 'result': 'created', '_shards': {'total': 1, 'successful': 1, 'failed': 0}, '_seq_no': 4389, '_primary_term': 1}
# Entreprise data successfully: {'_index': 'senegal_entreprises_data', '_id': '1DIcvY0BWWw3zxq32DbW', '_version': 1, 'result': 'created', '_shards': {'total': 1, 'successful': 1, 'failed': 0}, '_seq_no': 4390, '_primary_term': 1}
# Entreprise data successfully: {'_index': 'senegal_entreprises_data', '_id': '1TIcvY0BWWw3zxq32DbY', '_version': 1, 'result': 'created', '_shards': {'total': 1, 'successful': 1, 'failed': 0}, '_seq_no': 4391, '_primary_term': 1}
# Entreprise data successfully: {'_index': 'senegal_entreprises_data', '_id': '1jIcvY0BWWw3zxq32Dbb', '_version': 1, 'result': 'created', '_shards': {'total': 1, 'successful': 1, 'failed': 0}, '_seq_no': 4392, '_primary_term': 1}
# Entreprise data successfully: {'_index': 'senegal_entreprises_data', '_id': '1zIcvY0BWWw3zxq32Dbe', '_version': 1, 'result': 'created', '_shards': {'total': 1, 'successful': 1, 'failed': 0}, '_seq_no': 4393, '_primary_term': 1}
# Entreprise data successfully: {'_index': 'senegal_entreprises_data', '_id': '2DIcvY0BWWw3zxq32Dbg', '_version': 1, 'result': 'created', '_shards': {'total': 1, 'successful': 1, 'failed': 0}, '_seq_no': 4394, '_primary_term': 1}
# Entreprise data successfully: {'_index': 'senegal_entreprises_data', '_id': '2TIcvY0BWWw3zxq32Dbj', '_version': 1, 'result': 'created', '_shards': {'total': 1, 'successful': 1, 'failed': 0}, '_seq_no': 4395, '_primary_term': 1}
# Entreprise data successfully: {'_index': 'senegal_entreprises_data', '_id': '2jIcvY0BWWw3zxq32Dbm', '_version': 1, 'result': 'created', '_shards': {'total': 1, 'successful': 1, 'failed': 0}, '_seq_no': 4396, '_primary_term': 1}
# Entreprise data successfully: {'_index': 'senegal_entreprises_data', '_id': '2zIcvY0BWWw3zxq32Dbp', '_version': 1, 'result': 'created', '_shards': {'total': 1, 'successful': 1, 'failed': 0}, '_seq_no': 4397, '_primary_term': 1}
# Entreprise data successfully: {'_index': 'senegal_entreprises_data', '_id': '3DIcvY0BWWw3zxq32Dbr', '_version': 1, 'result': 'created', '_shards': {'total': 1, 'successful': 1, 'failed': 0}, '_seq_no': 4398, '_primary_term': 1}
# Entreprise data successfully: {'_index': 'senegal_entreprises_data', '_id': '3TIcvY0BWWw3zxq32Dbu', '_version': 1, 'result': 'created', '_shards': {'total': 1, 'successful': 1, 'failed': 0}, '_seq_no': 4399, '_primary_term': 1}
# Entreprise data successfully: {'_index': 'senegal_entreprises_data', '_id': '3jIcvY0BWWw3zxq32Dbx', '_version': 1, 'result': 'created', '_shards': {'total': 1, 'successful': 1, 'failed': 0}, '_seq_no': 4400, '_primary_term': 1}
# Entreprise data successfully: {'_index': 'senegal_entreprises_data', '_id': '3zIcvY0BWWw3zxq32Db0', '_version': 1, 'result': 'created', '_shards': {'total': 1, 'successful': 1, 'failed': 0}, '_seq_no': 4401, '_primary_term': 1}
# Entreprise data successfully: {'_index': 'senegal_entreprises_data', '_id': '4DIcvY0BWWw3zxq32Db2', '_version': 1, 'result': 'created', '_shards': {'total': 1, 'successful': 1, 'failed': 0}, '_seq_no': 4402, '_primary_term': 1}
# Entreprise data successfully: {'_index': 'senegal_entreprises_data', '_id': '4TIcvY0BWWw3zxq32Db5', '_version': 1, 'result': 'created', '_shards': {'total': 1, 'successful': 1, 'failed': 0}, '_seq_no': 4403, '_primary_term': 1}

# %% [markdown]
# Retrieve all data from the index

# %%
# Define the search query to match all documents
query = {
    "query": {
        "match_all": {}
    }
}

# Send the search request
response = requests.get(
    f"{base_url}/{index_name}/_search",
    json=query,
    auth=(username, password)  # Include authentication parameters
)

# Check the response
if response.status_code == 200:
    data = response.json()
    hits = data.get("hits", {}).get("hits", [])

    if hits:
        for hit in hits:
            print(f"Document ID: {hit['_id']}")
            print(f"Document Content: {hit['_source']}")
    else:
        print("No documents found in the index.")
else:
    print(f"Error fetching data: {response.content}")
# Out:
# Document ID: rjIcvY0BWWw3zxq3miUQ
# Document Content: {'Nom': 'AMBASSADE ALGERIE', 'Type': '', 'Region': 'DAKAR', 'Arrondissement': 'DAKAR PLATEAU', 'Commune': 'G1-DAKAR MEDINA', 'Quartier': '.', 'Tél': '339211337', 'Statut ligne': 'Actif'}
# Document ID: rzIcvY0BWWw3zxq3miUp
# Document Content: {'Nom': 'RUFSAC', 'Type': 'EMBALLAGE', 'Region': 'DAKAR', 'Arrondissement': 'RUFISQUE', 'Commune': 'G1-RUFISQUE', 'Quartier': '.', 'Tél': '338363088', 'Statut ligne': 'Actif'}
# Document ID: sDIcvY0BWWw3zxq3miUy
# Document Content: {'Nom': 'MBAYE DEGUENE F MBENGUE MUTUELLE TAKKU LIGUEY', 'Type': 'MUTUELLE EPARGNE ET CREDIT', 'Region': 'DAKAR', 'Arrondissement': 'SANGALKAM', 'Commune': 'BAMBYLORE - GOROM - BAYAKH', 'Quartier': 'GOROM 2 VILLAGE', 'Tél': '338363254', 'Statut ligne': 'Actif'}
# Document ID: sTIcvY0BWWw3zxq3miU4
# Document Content: {'Nom': 'MBAYE DEGUENE F MBENGUE MUTUELLE TAKKU LIGUEY', 'Type': 'MUTUELLE EPARGNE ET CREDIT', 'Region': 'DAKAR', 'Arrondissement': 'SANGALKAM', 'Commune': 'BAMBYLORE - GOROM - BAYAKH', 'Quartier': 'GOROM 2 VILLAGE', 'Tél': '338363254', 'Statut ligne': 'Actif'}
# Document ID: sjIcvY0BWWw3zxq3miU-
# Document Content: {'Nom': 'IRRI AFRIQUE SARL', 'Type': 'AGRICULTURE', 'Region': 'DAKAR', 'Arrondissement': 'SANGALKAM', 'Commune': 'BAMBYLORE - GOROM - BAYAKH', 'Quartier': 'BAYAKH', 'Tél': '338364800', 'Statut ligne': 'Actif'}
# Document ID: szIcvY0BWWw3zxq3miVF
# Document Content: {'Nom': 'TOUBA BAMBILOR IMMOBILIER-SARL', 'Type': 'AGENCE IMMOBILIERE', 'Region': 'DAKAR', 'Arrondissement': 'SANGALKAM', 'Commune': 'BAMBYLORE - GOROM - BAYAKH', 'Quartier': 'BAMBYLORE VILLAGE', 'Tél': '338369977', 'Statut ligne': 'Actif'}
# Document ID: tDIcvY0BWWw3zxq3miVK
# Document Content: {'Nom': 'REGULATORIX PHARMA-SUARL', 'Type': 'PHARMACIES', 'Region': 'DAKAR', 'Arrondissement': 'SANGALKAM', 'Commune': 'BAMBYLORE - GOROM - BAYAKH', 'Quartier': 'BAMBYLORE VILLAGE', 'Tél': '338360091', 'Statut ligne': 'Actif'}
# Document ID: tTIcvY0BWWw3zxq3miVQ
# Document Content: {'Nom': 'SOUAIBOU SANE', 'Type': 'COMMERCE', 'Region': 'DAKAR', 'Arrondissement': 'SANGALKAM', 'Commune': 'BAMBYLORE - GOROM - BAYAKH', 'Quartier': 'BAMBYLORE VILLAGE', 'Tél': '338368608', 'Statut ligne': 'Actif'}
# Document ID: tjIcvY0BWWw3zxq3miVW
# Document Content: {'Nom': 'DIEME OUSMANE CHARLES', 'Type': '', 'Region': 'DAKAR', 'Arrondissement': 'SANGALKAM', 'Commune': 'BAMBYLORE - GOROM - BAYAKH', 'Quartier': 'BAMBYLORE VILLAGE', 'Tél': '338701919', 'Statut ligne': 'Actif'}
# Document ID: tzIcvY0BWWw3zxq3miVb
# Document Content: {'Nom': 'DIEME OUSMANE CHARLES', 'Type': '', 'Region': 'DAKAR', 'Arrondissement': 'SANGALKAM', 'Commune': 'BAMBYLORE - GOROM - BAYAKH', 'Quartier': 'BAMBYLORE VILLAGE', 'Tél': '338701919', 'Statut ligne': 'Actif'}

# %% [markdown]
# Eventually delete the index

# %%
response = requests.delete("http://localhost:9200/software_jobs", auth = (username, password))
response.text
# Out:
# '{"acknowledged":true}'
